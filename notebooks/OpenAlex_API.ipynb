# %%
import pandas as pd
import requests
import json
import numpy as np

# %%
def pretty_json(json_object): print(json.dumps(json_object, indent=2))

# %%
api_key = ""
with open ("apikey.txt", "r") as apikey_file:
    api_key=apikey_file.readlines()[0].strip()
api_endpoint = "https://api.core.ac.uk/v3/"

# %%
def query_api(url_fragment, query,is_scroll=False, limit=100, scrollId=None):
    headers={"Authorization":"Bearer "+api_key}
    query = {"q":query, "limit":limit}
    if not is_scroll:
        response = requests.post(f"{api_endpoint}{url_fragment}",data = json.dumps(query), headers=headers)
    elif not scrollId:
        query["scroll"]="true"
        response = requests.post(f"{api_endpoint}{url_fragment}",data = json.dumps(query),headers=headers)
    else:
        query["scrollId"]=scrollId
        response = requests.post(f"{api_endpoint}{url_fragment}",data = json.dumps(query),headers=headers)
    if response.status_code ==200:
        return response.json(), response.elapsed.total_seconds()
    else:
        print(f"Error code {response.status_code}, {response.content}")

def scroll(search_url, query, extract_info_callback=None):
    allresults = []
    count = 0
    scrollId=None
    while True:
        result, elapsed =query_api(search_url, query, is_scroll=True, scrollId=scrollId)
        scrollId=result["scrollId"]
        totalhits = result["totalHits"]
        result_size = len(result["results"])
        if result_size==0:
            break
        for hit in result["results"]:
            if extract_info_callback:
              allresults.append(extract_info_callback(hit))
            else:
              allresults.append(hit)
        count+=result_size
        print(f"{count}/{totalhits} {elapsed}s")
    return allresults

# %%
results , elapsed = query_api("search/works", "doi:10.1371/journal.pone.0019981")

pretty_json(results)
# Out:
# {
#   "totalHits": 1,
#   "limit": 100,
#   "offset": 0,
#   "scrollId": null,
#   "results": [
#     {
#       "acceptedDate": "2011-05-24T00:00:00",
#       "arxivId": null,
#       "authors": [
#         {
#           "name": "A Kacelnik"
#         },
#         {
#           "name": "A Papoulis"
#         },
#         {
#           "name": "AD Briscoe"
#         },
#         {
#           "name": "AJ Moore"
#         },
#         {
#           "name": "B Luttbeg"
#         },
#         {
#           "name": "BG Svensson"
#         },
#         {
#           "name": "BM Dowds"
#         },
#         {
#           "name": "CIM Healey"
#         },
#         {
#           "name": "EB Mallon"
#         },
#         {
#           "name": "EB Mallon"
#         },
#         {
#           "name": "EJH Robinson"
#         },
#         {
#           "name": "EJH Robinson"
#         },
#         {
#           "name": "EJH Robinson"
#         },
#         {
#           "name": "Elva J. H. Robinson"
#         },
#         {
#           "name": "EO Wilson"
#         },
#         {
#           "name": "F Ravary"
#         },
#         {
#           "name": "FR Adler"
#         },
#         {
#           "name": "Frederick R. Adler"
#         },
#         {
#           "name": "G Th\u00e9raulaz"
#         },
#         {
#           "name": "GE Robinson"
#         },
#         {
#           "name": "JAC Uy"
#         },
#         {
#           "name": "James A. R. Marshall"
#         },
#         {
#           "name": "JAR Marshall"
#         },
#         {
#           "name": "JAR Marshall"
#         },
#         {
#           "name": "JAR Marshall"
#         },
#         {
#           "name": "JC de Biseau"
#         },
#         {
#           "name": "JC Nieh"
#         },
#         {
#           "name": "JG Burns"
#         },
#         {
#           "name": "JH Fewell"
#         },
#         {
#           "name": "JM Am\u00e9"
#         },
#         {
#           "name": "JMC Hutchinson"
#         },
#         {
#           "name": "JR Doyle"
#         },
#         {
#           "name": "KE Mabry"
#         },
#         {
#           "name": "KM Passino"
#         },
#         {
#           "name": "L Chittka"
#         },
#         {
#           "name": "L Chittka"
#         },
#         {
#           "name": "L Conradt"
#         },
#         {
#           "name": "L Conradt"
#         },
#         {
#           "name": "L Real"
#         },
#         {
#           "name": "LM Kay"
#         },
#         {
#           "name": "M Bateson"
#         },
#         {
#           "name": "M M\u00f6glich"
#         },
#         {
#           "name": "N Stroeymeyt"
#         },
#         {
#           "name": "Nigel R. Franks"
#         },
#         {
#           "name": "NR Franks"
#         },
#         {
#           "name": "NR Franks"
#         },
#         {
#           "name": "NR Franks"
#         },
#         {
#           "name": "NR Franks"
#         },
#         {
#           "name": "NR Franks"
#         },
#         {
#           "name": "NW Calderone"
#         },
#         {
#           "name": "PK Visscher"
#         },
#         {
#           "name": "PK Visscher"
#         },
#         {
#           "name": "PM Todd"
#         },
#         {
#           "name": "PR Freeman"
#         },
#         {
#           "name": "R Beckers"
#         },
#         {
#           "name": "R Dhar"
#         },
#         {
#           "name": "R Planqu\u00e9"
#         },
#         {
#           "name": "RE Page"
#         },
#         {
#           "name": "S Edwards"
#         },
#         {
#           "name": "S Shafir"
#         },
#         {
#           "name": "SA Levin"
#         },
#         {
#           "name": "Saki Okuda"
#         },
#         {
#           "name": "Samuel Ellis"
#         },
#         {
#           "name": "SC Pratt"
#         },
#         {
#           "name": "SC Pratt"
#         },
#         {
#           "name": "SC Pratt"
#         },
#         {
#           "name": "SC Pratt"
#         },
#         {
#           "name": "SN Beshers"
#         },
#         {
#           "name": "T Sasaki"
#         },
#         {
#           "name": "TA Langen"
#         },
#         {
#           "name": "TD Seeley"
#         },
#         {
#           "name": "TD Seeley"
#         },
#         {
#           "name": "TD Seeley"
#         },
#         {
#           "name": "TD Seeley"
#         },
#         {
#           "name": "TD Seeley"
#         },
#         {
#           "name": "TD Seeley"
#         },
#         {
#           "name": "TD Seeley"
#         },
#         {
#           "name": "VM Schmidt"
#         }
#       ],
#       "citationCount": null,
#       "contributors": [
#         ""
#       ],
#       "outputs": [
#         "https://api.core.ac.uk/v3/outputs/223321058",
#         "https://api.core.ac.uk/v3/outputs/193838621",
#         "https://api.core.ac.uk/v3/outputs/5225915",
#         "https://api.core.ac.uk/v3/outputs/42624856",
#         "https://api.core.ac.uk/v3/outputs/90060283",
#         "https://api.core.ac.uk/v3/outputs/203720814"
#       ],
#       "createdDate": "2012-06-28T04:00:54",
#       "dataProviders": [
#         {
#           "id": 4785,
#           "name": "",
#           "url": "https://api.core.ac.uk/v3/data-providers/4785",
#           "logo": "https://api.core.ac.uk/data-providers/4785/logo"
#         },
#         {
#           "id": 145,
#           "name": "",
#           "url": "https://api.core.ac.uk/v3/data-providers/145",
#           "logo": "https://api.core.ac.uk/data-providers/145/logo"
#         },
#         {
#           "id": 4786,
#           "name": "",
#           "url": "https://api.core.ac.uk/v3/data-providers/4786",
#           "logo": "https://api.core.ac.uk/data-providers/4786/logo"
#         },
#         {
#           "id": 645,
#           "name": "",
#           "url": "https://api.core.ac.uk/v3/data-providers/645",
#           "logo": "https://api.core.ac.uk/data-providers/645/logo"
#         },
#         {
#           "id": 150,
#           "name": "",
#           "url": "https://api.core.ac.uk/v3/data-providers/150",
#           "logo": "https://api.core.ac.uk/data-providers/150/logo"
#         },
#         {
#           "id": 140,
#           "name": "",
#           "url": "https://api.core.ac.uk/v3/data-providers/140",
#           "logo": "https://api.core.ac.uk/data-providers/140/logo"
#         },
#         {
#           "id": 286,
#           "name": "",
#           "url": "https://api.core.ac.uk/v3/data-providers/286",
#           "logo": "https://api.core.ac.uk/data-providers/286/logo"
#         }
#       ],
#       "depositedDate": "2011-05-24T00:00:00",
#       "abstract": "Decision-making animals can use slow-but-accurate strategies, such as making multiple comparisons, or opt for simpler, faster strategies to find a 'good enough' option. Social animals make collective decisions about many group behaviours including foraging and migration. The key to the collective choice lies with individual behaviour. We present a case study of a collective decision-making process (house-hunting ants, Temnothorax albipennis), in which a previously proposed decision strategy involved both quality-dependent hesitancy and direct comparisons of nests by scouts. An alternative possible decision strategy is that scouting ants use a very simple quality-dependent threshold rule to decide whether to recruit nest-mates to a new site or search for alternatives. We use analytical and simulation modelling to demonstrate that this simple rule is sufficient to explain empirical patterns from three studies of collective decision-making in ants, and can account parsimoniously for apparent comparison by individuals and apparent hesitancy (recruitment latency) effects, when available nests differ strongly in quality. This highlights the need to carefully design experiments to detect individual comparison. We present empirical data strongly suggesting that best-of-n comparison is not used by individual ants, although individual sequential comparisons are not ruled out. However, by using a simple threshold rule, decision-making groups are able to effectively compare options, without relying on any form of direct comparison of alternatives by individuals. This parsimonious mechanism could promote collective rationality in group decision-making",
#       "documentType": "unknown",
#       "doi": "10.1371/journal.pone.0019981",
#       "downloadUrl": "https://core.ac.uk/download/5225915.pdf",
#       "fieldOfStudy": null,
#       "fullText": null,
#       "id": 2386657,
#       "identifiers": [
#         {
#           "identifier": "oai:research-information.bris.ac.uk:publications/0f3da01c-4f5c-43ee-af67-1358d550362c",
#           "type": "OAI_ID"
#         },
#         {
#           "identifier": "oai:pubmedcentral.nih.gov:3101226",
#           "type": "OAI_ID"
#         },
#         {
#           "identifier": "oai:research-information.bris.ac.uk:openaire_cris_publications/0f3da01c-4f5c-43ee-af67-1358d550362c",
#           "type": "OAI_ID"
#         },
#         {
#           "identifier": "oai:eprints.whiterose.ac.uk:99644",
#           "type": "OAI_ID"
#         },
#         {
#           "identifier": "3101226",
#           "type": "PUBMED_ID"
#         },
#         {
#           "identifier": "42624856",
#           "type": "CORE_ID"
#         },
#         {
#           "identifier": "2142581949",
#           "type": "MAG_ID"
#         },
#         {
#           "identifier": "193838621",
#           "type": "CORE_ID"
#         },
#         {
#           "identifier": "5225915",
#           "type": "CORE_ID"
#         },
#         {
#           "identifier": "oai:doaj.org/article:8f7583edf8534c329d87cdd0dda7af14",
#           "type": "OAI_ID"
#         },
#         {
#           "identifier": "oai:citeseerx.psu:10.1.1.290.2403",
#           "type": "OAI_ID"
#         },
#         {
#           "identifier": "385699218",
#           "type": "CORE_ID"
#         },
#         {
#           "identifier": "223321058",
#           "type": "CORE_ID"
#         },
#         {
#           "identifier": "203720814",
#           "type": "CORE_ID"
#         },
#         {
#           "identifier": "8569611",
#           "type": "CORE_ID"
#         },
#         {
#           "identifier": "oai:eprints.whiterose.ac.uk:63768",
#           "type": "OAI_ID"
#         },
#         {
#           "identifier": "22501927",
#           "type": "CORE_ID"
#         },
#         {
#           "identifier": "90060283",
#           "type": "CORE_ID"
#         },
#         {
#           "identifier": "10.1371/journal.pone.0019981",
#           "type": "DOI"
#         }
#       ],
#       "title": "A Simple Threshold Rule Is Sufficient to Explain Sophisticated Collective Decision-Making",
#       "language": null,
#       "magId": "2142581949",
#       "oaiIds": [
#         "oai:doaj.org/article:8f7583edf8534c329d87cdd0dda7af14",
#         "oai:citeseerx.psu:10.1.1.290.2403",
#         "oai:eprints.whiterose.ac.uk:63768",
#         "oai:research-information.bris.ac.uk:openaire_cris_publications/0f3da01c-4f5c-43ee-af67-1358d550362c",
#         "oai:research-information.bris.ac.uk:publications/0f3da01c-4f5c-43ee-af67-1358d550362c",
#         "oai:eprints.whiterose.ac.uk:99644",
#         "oai:pubmedcentral.nih.gov:3101226"
#       ],
#       "publishedDate": "2010-01-01T00:00:00",
#       "publisher": "'Public Library of Science (PLoS)'",
#       "pubmedId": "3101226",
#       "references": [
#         {
#           "id": 27283274,
#           "title": "(in press) Experience-dependent flexibility in collective decision-making by househunting ants. Behav Ecol Sociobiol.",
#           "authors": [],
#           "date": null,
#           "doi": null,
#           "raw": "Stroeymeyt N, Robinson EJH, Hogan PM, Marshall JAR, Giurfa M, et al. (in press) Experience-dependent flexibility in collective decision-making by househunting ants. Behav Ecol Sociobiol.",
#           "cites": null
#         },
#         {
#           "id": 27283240,
#           "title": "A Comparative Bayes tactic for mate assessment and choice.",
#           "authors": [],
#           "date": "1996",
#           "doi": null,
#           "raw": "Luttbeg B (1996) A Comparative Bayes tactic for mate assessment and choice. Behav Ecol 7: 451\u2013460.",
#           "cites": null
#         },
#         {
#           "id": 27283251,
#           "title": "A negative feedback signal that Is triggered by peril curbs honey bee recruitment.",
#           "authors": [],
#           "date": "2010",
#           "doi": null,
#           "raw": "Nieh JC (2010) A negative feedback signal that Is triggered by peril curbs honey bee recruitment. Curr Biol 20: 310\u2013315.",
#           "cites": null
#         },
#         {
#           "id": 27283216,
#           "title": "A tunable algorithm for collective decision making.",
#           "authors": [],
#           "date": "2006",
#           "doi": null,
#           "raw": "Pratt SC, Sumpter DJT (2006) A tunable algorithm for collective decision making. Proc Natl Acad Sci USA 103: 15906\u201315910.",
#           "cites": null
#         },
#         {
#           "id": 27283218,
#           "title": "An agent-based model of collective nest site choice by the ant Temnothorax albipennis.",
#           "authors": [],
#           "date": "2005",
#           "doi": null,
#           "raw": "Pratt SC, Sumpter DJT, Mallon EB, Franks NR (2005) An agent-based model of collective nest site choice by the ant Temnothorax albipennis. Anim Behav 70: 1023\u20131036.",
#           "cites": null
#         },
#         {
#           "id": 27283242,
#           "title": "Ants estimate area using Buffon\u2019s needle.",
#           "authors": [],
#           "date": "2000",
#           "doi": null,
#           "raw": "Mallon EB, Franks NR (2000) Ants estimate area using Buffon\u2019s needle. Proc R Soc Lond B 267: 765\u2013770.",
#           "cites": null
#         },
#         {
#           "id": 27283261,
#           "title": "Are bigger brains better?",
#           "authors": [],
#           "date": "2010",
#           "doi": null,
#           "raw": "Chittka L, Niven J (2010) Are bigger brains better? Curr Biol 19: R995\u2013R1008.",
#           "cites": null
#         },
#         {
#           "id": 27283222,
#           "title": "Behavioral mechanisms of collective nest-site choice by the ant Temnothorax curvispinosus.",
#           "authors": [],
#           "date": "2005",
#           "doi": null,
#           "raw": "Pratt SC (2005) Behavioral mechanisms of collective nest-site choice by the ant Temnothorax curvispinosus. Insect Soc 52: 383\u2013392.",
#           "cites": null
#         },
#         {
#           "id": 27283221,
#           "title": "Can ant colonies choose a far-and-away better nest over an in-the-way poor one?",
#           "authors": [],
#           "date": "2008",
#           "doi": null,
#           "raw": "Franks NR, Hardcastle KA, Collins S, Smith FD, Sullivan KME, et al. (2008) Can ant colonies choose a far-and-away better nest over an in-the-way poor one? Anim Behav 76: 323\u2013334.",
#           "cites": null
#         },
#         {
#           "id": 27283256,
#           "title": "Chemical communication among workers of the fire ant Solenopsis saevissima (Fr. Smith) 1. The organization of mass-foraging.",
#           "authors": [],
#           "date": "1962",
#           "doi": null,
#           "raw": "Wilson EO (1962) Chemical communication among workers of the fire ant Solenopsis saevissima (Fr. Smith) 1. The organization of mass-foraging. Anim Behav 10: 134\u2013147.",
#           "cites": null
#         },
#         {
#           "id": 27283248,
#           "title": "Collective decision making in honey bees: how colonies choose among nectar sources.",
#           "authors": [],
#           "date": "1991",
#           "doi": null,
#           "raw": "Seeley TD, Camazine S, Sneyd J (1991) Collective decision making in honey bees: how colonies choose among nectar sources. Behav Ecol Sociobiol 28: 277\u2013290.",
#           "cites": null
#         },
#         {
#           "id": 27283245,
#           "title": "Collective decisions and cognition in bees.",
#           "authors": [],
#           "date": "1999",
#           "doi": null,
#           "raw": "Visscher PK, Camazine S (1999) Collective decisions and cognition in bees. Nature 397: 400.",
#           "cites": null
#         },
#         {
#           "id": 27283254,
#           "title": "Collective flexibility during mass recruitment in the ant Myrmica sabuleti (Hymenoptera: Formicidae).",
#           "authors": [],
#           "date": "1991",
#           "doi": null,
#           "raw": "de Biseau JC, Deneubourg JL, Pasteels JM (1991) Collective flexibility during mass recruitment in the ant Myrmica sabuleti (Hymenoptera: Formicidae). Psyche 98: 323\u2013336.",
#           "cites": null
#         },
#         {
#           "id": 27283253,
#           "title": "Collective foraging in a stingless bee: dependence on food profitability and sequence of discovery.",
#           "authors": [],
#           "date": "2006",
#           "doi": null,
#           "raw": "Schmidt VM, Schorkopf DLP, Hrncir M, Zucchi R, Barth FG (2006) Collective foraging in a stingless bee: dependence on food profitability and sequence of discovery. Anim Behav 72: 1309\u20131317.",
#           "cites": null
#         },
#         {
#           "id": 27283204,
#           "title": "Collegial decision making based on social amplification leads to optimal group formation.",
#           "authors": [],
#           "date": "2006",
#           "doi": null,
#           "raw": "Ame \u00b4 JM, Halloy J, Rivault C, Detrain C, Deneubourg JL (2006) Collegial decision making based on social amplification leads to optimal group formation. Proc Natl Acad Sci USA 103: 5835\u20135840.",
#           "cites": null
#         },
#         {
#           "id": 27283264,
#           "title": "Colony-level cognition.",
#           "authors": [],
#           "date": "2009",
#           "doi": null,
#           "raw": "Marshall JAR, Franks NR (2009) Colony-level cognition. Curr Biol 19: R395\u2013R396.",
#           "cites": null
#         },
#         {
#           "id": 27283268,
#           "title": "Comparative evolution and its implications for mate choice.",
#           "authors": [],
#           "date": "2005",
#           "doi": null,
#           "raw": "Bateson M, Healy SD (2005) Comparative evolution and its implications for mate choice. Trends Ecol Evol 20: 659\u2013664.",
#           "cites": null
#         },
#         {
#           "id": 27283207,
#           "title": "Conflicts of interest and the evolution of decision sharing.",
#           "authors": [],
#           "date": "2009",
#           "doi": null,
#           "raw": "Conradt L, Roper TJ (2009) Conflicts of interest and the evolution of decision sharing. Philos Trans R Soc B-Biol Sci 364: 807\u2013819.",
#           "cites": null
#         },
#         {
#           "id": 27283205,
#           "title": "Consensus decision-making in animals.",
#           "authors": [],
#           "date": "2005",
#           "doi": null,
#           "raw": "Conradt L, Roper TJ (2005) Consensus decision-making in animals. Trends Ecol Evol 20: 449\u2013456.",
#           "cites": null
#         },
#         {
#           "id": 27283257,
#           "title": "Consumer preference for a no-choice option.",
#           "authors": [],
#           "date": "1997",
#           "doi": null,
#           "raw": "Dhar R (1997) Consumer preference for a no-choice option. J Consum Res 24: 215\u2013231.",
#           "cites": null
#         },
#         {
#           "id": 27283208,
#           "title": "Crossing scales, crossing disciplines: collective motion and collective action in the Global Commons.",
#           "authors": [],
#           "date": "2010",
#           "doi": null,
#           "raw": "Levin SA (2010) Crossing scales, crossing disciplines: collective motion and collective action in the Global Commons. Philos Trans R Soc B-Biol Sci 365: 13\u201318.",
#           "cites": null
#         },
#         {
#           "id": 27283250,
#           "title": "Dancing bees tune both duration and rate of waggle-run production in relation to nectar-source profitability.",
#           "authors": [],
#           "date": "2000",
#           "doi": null,
#           "raw": "Seeley TD, Mikheyev AS, Pagano GJ (2000) Dancing bees tune both duration and rate of waggle-run production in relation to nectar-source profitability. J Comp Physiol A 186: 813\u2013819.",
#           "cites": null
#         },
#         {
#           "id": 27283267,
#           "title": "Decision making by small and large house-hunting ant colonies: one size fits all.",
#           "authors": [],
#           "date": "2006",
#           "doi": null,
#           "raw": "Franks NR, Dornhaus A, Best CS, Jones EL (2006) Decision making by small and large house-hunting ant colonies: one size fits all. Anim Behav 72: 611\u2013616.",
#           "cites": null
#         },
#         {
#           "id": 27283255,
#           "title": "Distance effects on resource profitability and recruitment in the giant tropical ant, Paraponera clavata.",
#           "authors": [],
#           "date": "1992",
#           "doi": null,
#           "raw": "Fewell JH, Harrison JF, Stiller TM, Breed MD (1992) Distance effects on resource profitability and recruitment in the giant tropical ant, Paraponera clavata. Oecologia 92: 542\u2013547.",
#           "cites": null
#         },
#         {
#           "id": 27283220,
#           "title": "Do ants make direct comparisons?",
#           "authors": [],
#           "date": "2009",
#           "doi": null,
#           "raw": "Robinson EJH, Smith FD, Sullivan KME, Franks NR (2009) Do ants make direct comparisons? Proc R Soc Lond B 276: 2635\u20132641.",
#           "cites": null
#         },
#         {
#           "id": 27283200,
#           "title": "Dornhaus A",
#           "authors": [],
#           "date": "2003",
#           "doi": null,
#           "raw": "Chittka L, Dyer AG, Bock F, Dornhaus A (2003) Bees trade off foraging speed for accuracy. Nature 424: 388\u2013388.",
#           "cites": null
#         },
#         {
#           "id": 27283258,
#           "title": "Dynamic mate-searching tactic allows female satin bowerbirds Ptilonorhynchus violaceus to reduce searching.",
#           "authors": [],
#           "date": "2000",
#           "doi": null,
#           "raw": "Uy JAC, Patricelli GL, Borgia G (2000) Dynamic mate-searching tactic allows female satin bowerbirds Ptilonorhynchus violaceus to reduce searching. Proc R Soc Lond B 267: 251\u2013256.",
#           "cites": null
#         },
#         {
#           "id": 27283219,
#           "title": "Emergence of group rationality from irrational individuals. Behav Ecol",
#           "authors": [],
#           "date": "2011",
#           "doi": null,
#           "raw": "Sasaki T, Pratt SC (2011) Emergence of group rationality from irrational individuals. Behav Ecol in press.",
#           "cites": null
#         },
#         {
#           "id": 27283203,
#           "title": "Female strategy during mate choice - threshold assessment.",
#           "authors": [],
#           "date": "1988",
#           "doi": null,
#           "raw": "Moore AJ, Moore PJ (1988) Female strategy during mate choice - threshold assessment. Evolution 42: 387\u2013391.",
#           "cites": null
#         },
#         {
#           "id": 27283238,
#           "title": "Flexible task allocation and the organisation of work in ants.",
#           "authors": [],
#           "date": "2009",
#           "doi": null,
#           "raw": "Robinson EJH, Feinerman O, Franks NR (2009) Flexible task allocation and the organisation of work in ants. Proc R Soc Lond B 276: 4373\u20134380.",
#           "cites": null
#         },
#         {
#           "id": 27283263,
#           "title": "From Pride and Prejudice to Persuasion: Satisficing",
#           "authors": [],
#           "date": "1999",
#           "doi": null,
#           "raw": "Todd PM, Miller GF (1999) From Pride and Prejudice to Persuasion: Satisficing in Mate Search. In: Gigerenzer G, Todd PM, eds. Simple Heuristics That Make Us Smart. Oxford: Oxford University Press. pp 287\u2013308.",
#           "cites": null
#         },
#         {
#           "id": 27283271,
#           "title": "Genetic structure and division of labor in honeybee societies.",
#           "authors": [],
#           "date": "1989",
#           "doi": null,
#           "raw": "Calderone NW, Robinson GE, Page RE (1989) Genetic structure and division of labor in honeybee societies. Experientia 45: 765\u2013767.",
#           "cites": null
#         },
#         {
#           "id": 27283243,
#           "title": "Group decision making in nest-site selection among social insects.",
#           "authors": [],
#           "date": "2007",
#           "doi": null,
#           "raw": "Visscher PK (2007) Group decision making in nest-site selection among social insects. Annual Review of Entomology 52: 255\u2013275.",
#           "cites": null
#         },
#         {
#           "id": 27283209,
#           "title": "Group decision making in swarms of honey bees.",
#           "authors": [],
#           "date": "1999",
#           "doi": null,
#           "raw": "Seeley TD, Buhrman SC (1999) Group decision making in swarms of honey bees. Behav Ecol Sociobiol 45: 19\u201331.",
#           "cites": null
#         },
#         {
#           "id": 27283202,
#           "title": "How western scrub-jays (Aphelocoma californica) select a nut: effects of the number of options, variation in nut size, and social competition among foragers.",
#           "authors": [],
#           "date": "1999",
#           "doi": null,
#           "raw": "Langen TA (1999) How western scrub-jays (Aphelocoma californica) select a nut: effects of the number of options, variation in nut size, and social competition among foragers. Anim Cognition 2: 223\u2013233.",
#           "cites": null
#         },
#         {
#           "id": 27283201,
#           "title": "Impulsive bees forage better: the advantage of quick, sometimes inaccurate foraging decisions. Anim Behav 70: e1\u20135. A Threshold Rule for Collective Decisions PLoS",
#           "authors": [],
#           "date": "2007",
#           "doi": null,
#           "raw": "Burns JG (2007) Impulsive bees forage better: the advantage of quick, sometimes inaccurate foraging decisions. Anim Behav 70: e1\u20135. A Threshold Rule for Collective Decisions PLoS ONE | www.plosone.org 10 May 2011 | Volume 6 | Issue 5 | e199817. Kacelnik A, Vasconcelos M, Monteiro T, Aw J (2011) Darwin\u2019s \u2018Tug-of-War\u2019 vs. Starlings\u2019 \u2018Horse-Racing\u2019: how adaptations for sequential encounters drive simultaneous choice. Behav Ecol Sociobiol 65: 547\u2013558.",
#           "cites": null
#         },
#         {
#           "id": 27283214,
#           "title": "Individual and collective decisionmaking during nest site selection by the ant Leptothorax albipennis.",
#           "authors": [],
#           "date": "2001",
#           "doi": null,
#           "raw": "Mallon EB, Pratt SC, Franks NR (2001) Individual and collective decisionmaking during nest site selection by the ant Leptothorax albipennis. Behav Ecol Sociobiol 50: 352\u2013359.",
#           "cites": null
#         },
#         {
#           "id": 27283278,
#           "title": "Individual experience alone can generate lasting division of labor in ants.",
#           "authors": [],
#           "date": "2007",
#           "doi": null,
#           "raw": "Ravary F, Lecoutey E, Kaminski G, Cha \u02c6line N, Jaisson P (2007) Individual experience alone can generate lasting division of labor in ants. Curr Biol 17: 1308\u20131312.",
#           "cites": null
#         },
#         {
#           "id": 27283262,
#           "title": "Intransitivity of performance in honey bees: support for \u2018comparative\u2019 evaluation of foraging options.",
#           "authors": [],
#           "date": "1994",
#           "doi": null,
#           "raw": "Shafir S (1994) Intransitivity of performance in honey bees: support for \u2018comparative\u2019 evaluation of foraging options. Anim Behav 48: 55\u201367.",
#           "cites": null
#         },
#         {
#           "id": 27283196,
#           "title": "Is more choice always desirable? Evidence and arguments from leks, food selection, and environmental enrichment.",
#           "authors": [],
#           "date": "2005",
#           "doi": null,
#           "raw": "Hutchinson JMC (2005) Is more choice always desirable? Evidence and arguments from leks, food selection, and environmental enrichment. Biol Rev 80: 73\u201392.",
#           "cites": null
#         },
#         {
#           "id": 27283235,
#           "title": "IUCN Red List of Threatened Species.",
#           "authors": [],
#           "date": "2008",
#           "doi": null,
#           "raw": "IUCN (2008) IUCN Red List of Threatened Species.",
#           "cites": null
#         },
#         {
#           "id": 27283277,
#           "title": "Levels of behavioral organization and the evolution of division of labor.",
#           "authors": [],
#           "date": "2002",
#           "doi": null,
#           "raw": "Page RE, Erber J (2002) Levels of behavioral organization and the evolution of division of labor. Naturwissenschaften 89: 91\u2013106.",
#           "cites": null
#         },
#         {
#           "id": 27283244,
#           "title": "Modeling and analysis of nest-site selection by honeybee swarms: the speed and accuracy trade-off.",
#           "authors": [],
#           "date": "2006",
#           "doi": null,
#           "raw": "Passino KM, Seeley TD (2006) Modeling and analysis of nest-site selection by honeybee swarms: the speed and accuracy trade-off. Behav Ecol Sociobiol 59: 427\u2013442.",
#           "cites": null
#         },
#         {
#           "id": 27283273,
#           "title": "Models of division of labor in insect societies.",
#           "authors": [],
#           "date": "2001",
#           "doi": null,
#           "raw": "Beshers SN, Fewell JH (2001) Models of division of labor in insect societies. Ann Rev Entomol 46: 413\u2013430.",
#           "cites": null
#         },
#         {
#           "id": 27283272,
#           "title": "Modulation of alarm pheromone perception in the honey bee - evidence for division of labor based on hormonally regulated response thresholds.",
#           "authors": [],
#           "date": "1987",
#           "doi": null,
#           "raw": "Robinson GE (1987) Modulation of alarm pheromone perception in the honey bee - evidence for division of labor based on hormonally regulated response thresholds. J Comp Physiol A 160: 613\u2013619.",
#           "cites": null
#         },
#         {
#           "id": 27283252,
#           "title": "Modulation of trail laying in the ant Lasius niger (Hymenoptera, Formicidae) and its role in the collective selection of a food source.",
#           "authors": [],
#           "date": "1993",
#           "doi": null,
#           "raw": "Beckers R, Deneubourg JL, Goss S (1993) Modulation of trail laying in the ant Lasius niger (Hymenoptera, Formicidae) and its role in the collective selection of a food source. J Insect Behav 6: 751\u2013759.",
#           "cites": null
#         },
#         {
#           "id": 27283247,
#           "title": "Nest-site selection in honeybees: how well do swarms implement the \u2018\u2018best-of-N\u2019\u2019 decision rule?",
#           "authors": [],
#           "date": "2001",
#           "doi": null,
#           "raw": "Seeley TD, Buhrman SC (2001) Nest-site selection in honeybees: how well do swarms implement the \u2018\u2018best-of-N\u2019\u2019 decision rule? Behav Ecol Sociobiol 49: 416\u2013427.",
#           "cites": null
#         },
#         {
#           "id": 27283215,
#           "title": "Noise, cost and speedaccuracy trade-offs: decision-making in a decentralised system.",
#           "authors": [],
#           "date": "2005",
#           "doi": null,
#           "raw": "Marshall JAR, Dornhaus A, Franks NR, Kovacs T (2005) Noise, cost and speedaccuracy trade-offs: decision-making in a decentralised system. J Roy Soc: Interface 3: 243\u2013254.",
#           "cites": null
#         },
#         {
#           "id": 27283213,
#           "title": "Not everything that counts can be counted: ants use multiple metrics for a single nest trait.",
#           "authors": [],
#           "date": "2006",
#           "doi": null,
#           "raw": "Franks NR, Dornhaus A, Metherell B, Nelson T, Lanfear SA, et al. (2006) Not everything that counts can be counted: ants use multiple metrics for a single nest trait. Proc R Soc Lond B 273: 165\u2013169.",
#           "cites": null
#         },
#         {
#           "id": 27283266,
#           "title": "On optimal decision making in brains and social insect colonies.",
#           "authors": [],
#           "date": "2009",
#           "doi": null,
#           "raw": "Marshall JAR, Bogacz R, Dornhaus A, Planque \u00b4 R, Kovacs T, et al. (2009) On optimal decision making in brains and social insect colonies. J Roy Soc: Interface 6: 1065\u20131074.",
#           "cites": null
#         },
#         {
#           "id": 27283206,
#           "title": "Optimization, conflict and nonoverlapping foraging ranges in ants.",
#           "authors": [],
#           "date": "2003",
#           "doi": null,
#           "raw": "Adler FR, Gordon DM (2003) Optimization, conflict and nonoverlapping foraging ranges in ants. Am Nat 162: 529\u2013543.",
#           "cites": null
#         },
#         {
#           "id": 27283224,
#           "title": "Probability, Random Variables and Stochastic Processes.",
#           "authors": [],
#           "date": "2002",
#           "doi": null,
#           "raw": "Papoulis A, Pillai SU (2002) Probability, Random Variables and Stochastic Processes. New York: McGraw Hill. 666 p.",
#           "cites": null
#         },
#         {
#           "id": 27283265,
#           "title": "Quorum sensing during nest-site selection by honeybee swarms.",
#           "authors": [],
#           "date": "2004",
#           "doi": null,
#           "raw": "Seeley TD, Visscher PK (2004) Quorum sensing during nest-site selection by honeybee swarms. Behav Ecol Sociobiol 56: 594\u2013601.",
#           "cites": null
#         },
#         {
#           "id": 27283212,
#           "title": "Quorum sensing, recruitment, and collective decision-making during colony emigration by the ant Leptothorax albipennis.",
#           "authors": [],
#           "date": "2002",
#           "doi": null,
#           "raw": "Pratt SC, Mallon EB, Sumpter DJT, Franks NR (2002) Quorum sensing, recruitment, and collective decision-making during colony emigration by the ant Leptothorax albipennis. Behav Ecol Sociobiol 52: 117\u2013127.",
#           "cites": null
#         },
#         {
#           "id": 27283237,
#           "title": "Radio-tagging reveals the roles of corpulence, experience and social information in ant decision making.",
#           "authors": [],
#           "date": "2009",
#           "doi": null,
#           "raw": "Robinson EJH, Richardson TO, Sendova-Franks AB, Feinerman O, Franks NR (2009) Radio-tagging reveals the roles of corpulence, experience and social information in ant decision making. Behav Ecol Sociobiol 63: 627\u2013636.",
#           "cites": null
#         },
#         {
#           "id": 27283270,
#           "title": "Rationality in collective decision-making by ant colonies.",
#           "authors": [],
#           "date": "2009",
#           "doi": null,
#           "raw": "Edwards S, Pratt SC (2009) Rationality in collective decision-making by ant colonies. Proc R Soc Lond B 276: 3655\u20133661.",
#           "cites": null
#         },
#         {
#           "id": 27283276,
#           "title": "Response threshold reinforcement and division of labour in insect societies.",
#           "authors": [],
#           "date": "1998",
#           "doi": null,
#           "raw": "The \u00b4raulaz G, Bonabeau E, Deneubourg JL (1998) Response threshold reinforcement and division of labour in insect societies. Proc R Soc Lond B 265: 327\u2013332.",
#           "cites": null
#         },
#         {
#           "id": 27283236,
#           "title": "Responsibility in the use of animals in bioscience research: Expectations of the major research council and charitable funding bodies.",
#           "authors": [],
#           "date": "2010",
#           "doi": null,
#           "raw": "National-Centre-for-the-Replacement-Refinement-and-Reduction-of-Animalsin-Research (2010) Responsibility in the use of animals in bioscience research: Expectations of the major research council and charitable funding bodies. London: Tradewinds.",
#           "cites": null
#         },
#         {
#           "id": 27283197,
#           "title": "Search theory and mate choice. I. Models of single-sex discrimination.",
#           "authors": [],
#           "date": "1990",
#           "doi": null,
#           "raw": "Real L (1990) Search theory and mate choice. I. Models of single-sex discrimination. Am Nat 136: 376\u2013405.",
#           "cites": null
#         },
#         {
#           "id": 27283198,
#           "title": "Searching for a new home: decision making by dispersing brush mice.",
#           "authors": [],
#           "date": "2008",
#           "doi": null,
#           "raw": "Mabry KE, Stamps JA (2008) Searching for a new home: decision making by dispersing brush mice. Am Nat 172: 625\u2013634.",
#           "cites": null
#         },
#         {
#           "id": 27283246,
#           "title": "Sensory coding of nest-site value in honeybee swarms.",
#           "authors": [],
#           "date": "2008",
#           "doi": null,
#           "raw": "Seeley TD, Visscher PK (2008) Sensory coding of nest-site value in honeybee swarms. J Exp Biol 211: 3691\u20133697.",
#           "cites": null
#         },
#         {
#           "id": 27283260,
#           "title": "Shell wars - assessment strategies and the timing of decisions in hermit crab shell fights.",
#           "authors": [],
#           "date": "1983",
#           "doi": null,
#           "raw": "Dowds BM, Elwood RW (1983) Shell wars - assessment strategies and the timing of decisions in hermit crab shell fights. Behaviour 85: 1\u201324.",
#           "cites": null
#         },
#         {
#           "id": 27283211,
#           "title": "Social organization of nest emigration in Leptothorax (Hym.",
#           "authors": [],
#           "date": "1978",
#           "doi": null,
#           "raw": "Mo \u00a8glich M (1978) Social organization of nest emigration in Leptothorax (Hym. Form.). Insect Soc 25: 205\u2013225.",
#           "cites": null
#         },
#         {
#           "id": 27283210,
#           "title": "Strategies for choosing between alternatives with different attributes: exemplified by househunting ants.",
#           "authors": [],
#           "date": "2003",
#           "doi": null,
#           "raw": "Franks NR, Mallon EB, Bray HE, Hamilton MJ, Mischler TC (2003) Strategies for choosing between alternatives with different attributes: exemplified by househunting ants. Anim Behav 65: 215\u2013223.",
#           "cites": null
#         },
#         {
#           "id": 27283249,
#           "title": "Tactics of dance choice in honey bees: do foragers compare dances?",
#           "authors": [],
#           "date": "1992",
#           "doi": null,
#           "raw": "Seeley TD, Towne WF (1992) Tactics of dance choice in honey bees: do foragers compare dances? Behav Ecol Sociobiol 30: 59\u201369.",
#           "cites": null
#         },
#         {
#           "id": 27283279,
#           "title": "Teaching in tandem-running ants. Nature 439: 153. A Threshold Rule for Collective Decisions",
#           "authors": [],
#           "date": "2006",
#           "doi": null,
#           "raw": "Franks NR, Richardson TO (2006) Teaching in tandem-running ants. Nature 439: 153. A Threshold Rule for Collective Decisions PLoS ONE | www.plosone.org 11 May 2011 | Volume 6 | Issue 5 | e19981",
#           "cites": null
#         },
#         {
#           "id": 27283275,
#           "title": "The effect of prior experience on nest site evaluation by the ant Temnothorax curvispinosus.",
#           "authors": [],
#           "date": "2008",
#           "doi": null,
#           "raw": "Healey CIM, Pratt SC (2008) The effect of prior experience on nest site evaluation by the ant Temnothorax curvispinosus. Anim Behav 76: 893\u2013899.",
#           "cites": null
#         },
#         {
#           "id": 27283239,
#           "title": "The evolution of color vision in insects.",
#           "authors": [],
#           "date": "2001",
#           "doi": null,
#           "raw": "Briscoe AD, Chittka L (2001) The evolution of color vision in insects. Ann Rev Entomol 46: 471\u2013510.",
#           "cites": null
#         },
#         {
#           "id": 27283269,
#           "title": "The robustness of the asymmetrically dominated effect: Buying frames, phantom alternatives, and in-store purchases.",
#           "authors": [],
#           "date": "1999",
#           "doi": null,
#           "raw": "Doyle JR, O\u2019Connor DJ, Reynolds GM, Bottomley PA (1999) The robustness of the asymmetrically dominated effect: Buying frames, phantom alternatives, and in-store purchases. Psychol Mark 16: 225\u2013243.",
#           "cites": null
#         },
#         {
#           "id": 27283241,
#           "title": "The Secretary Problem and Its Extensions: A Review.",
#           "authors": [],
#           "date": "1983",
#           "doi": null,
#           "raw": "Freeman PR (1983) The Secretary Problem and Its Extensions: A Review. Int Stat Rev 51: 189\u2013206.",
#           "cites": null
#         },
#         {
#           "id": 27283217,
#           "title": "Weighted waiting in collective decision-making.",
#           "authors": [],
#           "date": "2007",
#           "doi": null,
#           "raw": "Planque \u00b4 R, Dornhaus A, Franks NR, Kovacs T, Marshall JAR (2007) Weighted waiting in collective decision-making. Behav Ecol Sociobiol 61: 347\u2013356.",
#           "cites": null
#         },
#         {
#           "id": 27283199,
#           "title": "When good enough is best.",
#           "authors": [],
#           "date": "2006",
#           "doi": null,
#           "raw": "Kay LM, Beshel J, Martin C (2006) When good enough is best. Neuron 51: 277\u2013278.",
#           "cites": null
#         },
#         {
#           "id": 27283259,
#           "title": "Why do males of the dance fly Empis borealis refuse to mate? The importance of female age and size.",
#           "authors": [],
#           "date": "1989",
#           "doi": null,
#           "raw": "Svensson BG, Petersson E, Forsgren E (1989) Why do males of the dance fly Empis borealis refuse to mate? The importance of female age and size. J Insect Behav 2: 387\u2013395.",
#           "cites": null
#         }
#       ],
#       "sourceFulltextUrls": [
#         "file:///data/remote/core/dit/data/public_library_of_science/pdf/086/ZnRwOi8vZnRwLm5jYmkubmxtLm5paC5nb3YvcHViL3BtYy9vYV9wYWNrYWdlL2Q4Lzk0L1BNQzMxMDEyMjYudGFyLmd6.pdf",
#         "https://eprints.whiterose.ac.uk/99644/1/A%20simple%20threshold%20rule%20is%20sufficient%20to%20explain%20sophisticated%20collective%20decision-making.pdf",
#         "https://eprints.whiterose.ac.uk/63768/1/Robinson2011ThresholdModel.pdf",
#         "http://citeseerx.ist.psu.edu/viewdoc/summary?doi=10.1.1.290.2403",
#         "https://doaj.org/toc/1932-6203",
#         "http://www.pubmedcentral.nih.gov/articlerender.fcgi?artid=3101226"
#       ],
#       "updatedDate": "2022-02-01T23:42:32",
#       "yearPublished": 2010,
#       "journals": [
#         {
#           "title": "PLoS ONE",
#           "identifiers": [
#             "1932-6203"
#           ]
#         }
#       ],
#       "links": [
#         {
#           "type": "download",
#           "url": "https://core.ac.uk/download/5225915.pdf"
#         },
#         {
#           "type": "reader",
#           "url": "https://core.ac.uk/reader/5225915"
#         },
#         {
#           "type": "thumbnail_m",
#           "url": "https://core.ac.uk/image/5225915/medium"
#         },
#         {
#           "type": "thumbnail_l",
#           "url": "https://core.ac.uk/image/5225915/large"
#         },
#         {
#           "type": "display",
#           "url": "https://core.ac.uk/works/2386657"
#         }
#       ]
#     }
#   ],
#   "tooks": null,
#   "esTook": null
# }

# %%
results , elapsed = query_api("search/outputs", "doi:10.1371/journal.pone.0019981")

pretty_json(results)
# Out:
# {
#   "totalHits": 9,
#   "limit": 100,
#   "offset": 0,
#   "scrollId": null,
#   "results": [
#     {
#       "acceptedDate": "",
#       "authors": [
#         {
#           "name": "Robinson, Elva J. H."
#         },
#         {
#           "name": "Franks, Nigel R."
#         },
#         {
#           "name": "Ellis, Samuel"
#         },
#         {
#           "name": "Okuda, Saki"
#         },
#         {
#           "name": "Marshall, James A. R."
#         }
#       ],
#       "contributors": [],
#       "createdDate": "2012-07-08T14:39:10+01:00",
#       "dataProvider": {
#         "id": 150,
#         "name": "PubMed Central",
#         "url": "https://api.core.ac.uk/v3/data-providers/150",
#         "logo": "https://api.core.ac.uk/data-providers/150/logo"
#       },
#       "depositedDate": "",
#       "documentType": "research",
#       "doi": "10.1371/journal.pone.0019981",
#       "downloadUrl": "https://core.ac.uk/download/8569611.pdf",
#       "fullText": "",
#       "id": 8569611,
#       "identifiers": {
#         "doi": "10.1371/journal.pone.0019981",
#         "oai": "oai:pubmedcentral.nih.gov:3101226"
#       },
#       "title": "A Simple Threshold Rule Is Sufficient to Explain Sophisticated Collective Decision-Making",
#       "language": {
#         "code": "en",
#         "name": "English"
#       },
#       "publishedDate": "2011-05-24T01:00:00+01:00",
#       "publisher": "'Public Library of Science (PLoS)'",
#       "references": [
#         {
#           "id": 27283274,
#           "title": "(in press) Experience-dependent flexibility in collective decision-making by househunting ants. Behav Ecol Sociobiol.",
#           "authors": [],
#           "date": null,
#           "doi": null,
#           "raw": "Stroeymeyt N, Robinson EJH, Hogan PM, Marshall JAR, Giurfa M, et al. (in press) Experience-dependent flexibility in collective decision-making by househunting ants. Behav Ecol Sociobiol.",
#           "cites": null
#         },
#         {
#           "id": 27283240,
#           "title": "A Comparative Bayes tactic for mate assessment and choice.",
#           "authors": [],
#           "date": "1996",
#           "doi": null,
#           "raw": "Luttbeg B (1996) A Comparative Bayes tactic for mate assessment and choice. Behav Ecol 7: 451\u2013460.",
#           "cites": null
#         },
#         {
#           "id": 27283251,
#           "title": "A negative feedback signal that Is triggered by peril curbs honey bee recruitment.",
#           "authors": [],
#           "date": "2010",
#           "doi": null,
#           "raw": "Nieh JC (2010) A negative feedback signal that Is triggered by peril curbs honey bee recruitment. Curr Biol 20: 310\u2013315.",
#           "cites": null
#         },
#         {
#           "id": 27283216,
#           "title": "A tunable algorithm for collective decision making.",
#           "authors": [],
#           "date": "2006",
#           "doi": null,
#           "raw": "Pratt SC, Sumpter DJT (2006) A tunable algorithm for collective decision making. Proc Natl Acad Sci USA 103: 15906\u201315910.",
#           "cites": null
#         },
#         {
#           "id": 27283218,
#           "title": "An agent-based model of collective nest site choice by the ant Temnothorax albipennis.",
#           "authors": [],
#           "date": "2005",
#           "doi": null,
#           "raw": "Pratt SC, Sumpter DJT, Mallon EB, Franks NR (2005) An agent-based model of collective nest site choice by the ant Temnothorax albipennis. Anim Behav 70: 1023\u20131036.",
#           "cites": null
#         },
#         {
#           "id": 27283242,
#           "title": "Ants estimate area using Buffon\u2019s needle.",
#           "authors": [],
#           "date": "2000",
#           "doi": null,
#           "raw": "Mallon EB, Franks NR (2000) Ants estimate area using Buffon\u2019s needle. Proc R Soc Lond B 267: 765\u2013770.",
#           "cites": null
#         },
#         {
#           "id": 27283261,
#           "title": "Are bigger brains better?",
#           "authors": [],
#           "date": "2010",
#           "doi": null,
#           "raw": "Chittka L, Niven J (2010) Are bigger brains better? Curr Biol 19: R995\u2013R1008.",
#           "cites": null
#         },
#         {
#           "id": 27283222,
#           "title": "Behavioral mechanisms of collective nest-site choice by the ant Temnothorax curvispinosus.",
#           "authors": [],
#           "date": "2005",
#           "doi": null,
#           "raw": "Pratt SC (2005) Behavioral mechanisms of collective nest-site choice by the ant Temnothorax curvispinosus. Insect Soc 52: 383\u2013392.",
#           "cites": null
#         },
#         {
#           "id": 27283221,
#           "title": "Can ant colonies choose a far-and-away better nest over an in-the-way poor one?",
#           "authors": [],
#           "date": "2008",
#           "doi": null,
#           "raw": "Franks NR, Hardcastle KA, Collins S, Smith FD, Sullivan KME, et al. (2008) Can ant colonies choose a far-and-away better nest over an in-the-way poor one? Anim Behav 76: 323\u2013334.",
#           "cites": null
#         },
#         {
#           "id": 27283256,
#           "title": "Chemical communication among workers of the fire ant Solenopsis saevissima (Fr. Smith) 1. The organization of mass-foraging.",
#           "authors": [],
#           "date": "1962",
#           "doi": null,
#           "raw": "Wilson EO (1962) Chemical communication among workers of the fire ant Solenopsis saevissima (Fr. Smith) 1. The organization of mass-foraging. Anim Behav 10: 134\u2013147.",
#           "cites": null
#         },
#         {
#           "id": 27283248,
#           "title": "Collective decision making in honey bees: how colonies choose among nectar sources.",
#           "authors": [],
#           "date": "1991",
#           "doi": null,
#           "raw": "Seeley TD, Camazine S, Sneyd J (1991) Collective decision making in honey bees: how colonies choose among nectar sources. Behav Ecol Sociobiol 28: 277\u2013290.",
#           "cites": null
#         },
#         {
#           "id": 27283245,
#           "title": "Collective decisions and cognition in bees.",
#           "authors": [],
#           "date": "1999",
#           "doi": null,
#           "raw": "Visscher PK, Camazine S (1999) Collective decisions and cognition in bees. Nature 397: 400.",
#           "cites": null
#         },
#         {
#           "id": 27283254,
#           "title": "Collective flexibility during mass recruitment in the ant Myrmica sabuleti (Hymenoptera: Formicidae).",
#           "authors": [],
#           "date": "1991",
#           "doi": null,
#           "raw": "de Biseau JC, Deneubourg JL, Pasteels JM (1991) Collective flexibility during mass recruitment in the ant Myrmica sabuleti (Hymenoptera: Formicidae). Psyche 98: 323\u2013336.",
#           "cites": null
#         },
#         {
#           "id": 27283253,
#           "title": "Collective foraging in a stingless bee: dependence on food profitability and sequence of discovery.",
#           "authors": [],
#           "date": "2006",
#           "doi": null,
#           "raw": "Schmidt VM, Schorkopf DLP, Hrncir M, Zucchi R, Barth FG (2006) Collective foraging in a stingless bee: dependence on food profitability and sequence of discovery. Anim Behav 72: 1309\u20131317.",
#           "cites": null
#         },
#         {
#           "id": 27283204,
#           "title": "Collegial decision making based on social amplification leads to optimal group formation.",
#           "authors": [],
#           "date": "2006",
#           "doi": null,
#           "raw": "Ame \u00b4 JM, Halloy J, Rivault C, Detrain C, Deneubourg JL (2006) Collegial decision making based on social amplification leads to optimal group formation. Proc Natl Acad Sci USA 103: 5835\u20135840.",
#           "cites": null
#         },
#         {
#           "id": 27283264,
#           "title": "Colony-level cognition.",
#           "authors": [],
#           "date": "2009",
#           "doi": null,
#           "raw": "Marshall JAR, Franks NR (2009) Colony-level cognition. Curr Biol 19: R395\u2013R396.",
#           "cites": null
#         },
#         {
#           "id": 27283268,
#           "title": "Comparative evolution and its implications for mate choice.",
#           "authors": [],
#           "date": "2005",
#           "doi": null,
#           "raw": "Bateson M, Healy SD (2005) Comparative evolution and its implications for mate choice. Trends Ecol Evol 20: 659\u2013664.",
#           "cites": null
#         },
#         {
#           "id": 27283207,
#           "title": "Conflicts of interest and the evolution of decision sharing.",
#           "authors": [],
#           "date": "2009",
#           "doi": null,
#           "raw": "Conradt L, Roper TJ (2009) Conflicts of interest and the evolution of decision sharing. Philos Trans R Soc B-Biol Sci 364: 807\u2013819.",
#           "cites": null
#         },
#         {
#           "id": 27283205,
#           "title": "Consensus decision-making in animals.",
#           "authors": [],
#           "date": "2005",
#           "doi": null,
#           "raw": "Conradt L, Roper TJ (2005) Consensus decision-making in animals. Trends Ecol Evol 20: 449\u2013456.",
#           "cites": null
#         },
#         {
#           "id": 27283257,
#           "title": "Consumer preference for a no-choice option.",
#           "authors": [],
#           "date": "1997",
#           "doi": null,
#           "raw": "Dhar R (1997) Consumer preference for a no-choice option. J Consum Res 24: 215\u2013231.",
#           "cites": null
#         },
#         {
#           "id": 27283208,
#           "title": "Crossing scales, crossing disciplines: collective motion and collective action in the Global Commons.",
#           "authors": [],
#           "date": "2010",
#           "doi": null,
#           "raw": "Levin SA (2010) Crossing scales, crossing disciplines: collective motion and collective action in the Global Commons. Philos Trans R Soc B-Biol Sci 365: 13\u201318.",
#           "cites": null
#         },
#         {
#           "id": 27283250,
#           "title": "Dancing bees tune both duration and rate of waggle-run production in relation to nectar-source profitability.",
#           "authors": [],
#           "date": "2000",
#           "doi": null,
#           "raw": "Seeley TD, Mikheyev AS, Pagano GJ (2000) Dancing bees tune both duration and rate of waggle-run production in relation to nectar-source profitability. J Comp Physiol A 186: 813\u2013819.",
#           "cites": null
#         },
#         {
#           "id": 27283267,
#           "title": "Decision making by small and large house-hunting ant colonies: one size fits all.",
#           "authors": [],
#           "date": "2006",
#           "doi": null,
#           "raw": "Franks NR, Dornhaus A, Best CS, Jones EL (2006) Decision making by small and large house-hunting ant colonies: one size fits all. Anim Behav 72: 611\u2013616.",
#           "cites": null
#         },
#         {
#           "id": 27283255,
#           "title": "Distance effects on resource profitability and recruitment in the giant tropical ant, Paraponera clavata.",
#           "authors": [],
#           "date": "1992",
#           "doi": null,
#           "raw": "Fewell JH, Harrison JF, Stiller TM, Breed MD (1992) Distance effects on resource profitability and recruitment in the giant tropical ant, Paraponera clavata. Oecologia 92: 542\u2013547.",
#           "cites": null
#         },
#         {
#           "id": 27283220,
#           "title": "Do ants make direct comparisons?",
#           "authors": [],
#           "date": "2009",
#           "doi": null,
#           "raw": "Robinson EJH, Smith FD, Sullivan KME, Franks NR (2009) Do ants make direct comparisons? Proc R Soc Lond B 276: 2635\u20132641.",
#           "cites": null
#         },
#         {
#           "id": 27283200,
#           "title": "Dornhaus A",
#           "authors": [],
#           "date": "2003",
#           "doi": null,
#           "raw": "Chittka L, Dyer AG, Bock F, Dornhaus A (2003) Bees trade off foraging speed for accuracy. Nature 424: 388\u2013388.",
#           "cites": null
#         },
#         {
#           "id": 27283258,
#           "title": "Dynamic mate-searching tactic allows female satin bowerbirds Ptilonorhynchus violaceus to reduce searching.",
#           "authors": [],
#           "date": "2000",
#           "doi": null,
#           "raw": "Uy JAC, Patricelli GL, Borgia G (2000) Dynamic mate-searching tactic allows female satin bowerbirds Ptilonorhynchus violaceus to reduce searching. Proc R Soc Lond B 267: 251\u2013256.",
#           "cites": null
#         },
#         {
#           "id": 27283219,
#           "title": "Emergence of group rationality from irrational individuals. Behav Ecol",
#           "authors": [],
#           "date": "2011",
#           "doi": null,
#           "raw": "Sasaki T, Pratt SC (2011) Emergence of group rationality from irrational individuals. Behav Ecol in press.",
#           "cites": null
#         },
#         {
#           "id": 27283203,
#           "title": "Female strategy during mate choice - threshold assessment.",
#           "authors": [],
#           "date": "1988",
#           "doi": null,
#           "raw": "Moore AJ, Moore PJ (1988) Female strategy during mate choice - threshold assessment. Evolution 42: 387\u2013391.",
#           "cites": null
#         },
#         {
#           "id": 27283238,
#           "title": "Flexible task allocation and the organisation of work in ants.",
#           "authors": [],
#           "date": "2009",
#           "doi": null,
#           "raw": "Robinson EJH, Feinerman O, Franks NR (2009) Flexible task allocation and the organisation of work in ants. Proc R Soc Lond B 276: 4373\u20134380.",
#           "cites": null
#         },
#         {
#           "id": 27283263,
#           "title": "From Pride and Prejudice to Persuasion: Satisficing",
#           "authors": [],
#           "date": "1999",
#           "doi": null,
#           "raw": "Todd PM, Miller GF (1999) From Pride and Prejudice to Persuasion: Satisficing in Mate Search. In: Gigerenzer G, Todd PM, eds. Simple Heuristics That Make Us Smart. Oxford: Oxford University Press. pp 287\u2013308.",
#           "cites": null
#         },
#         {
#           "id": 27283271,
#           "title": "Genetic structure and division of labor in honeybee societies.",
#           "authors": [],
#           "date": "1989",
#           "doi": null,
#           "raw": "Calderone NW, Robinson GE, Page RE (1989) Genetic structure and division of labor in honeybee societies. Experientia 45: 765\u2013767.",
#           "cites": null
#         },
#         {
#           "id": 27283243,
#           "title": "Group decision making in nest-site selection among social insects.",
#           "authors": [],
#           "date": "2007",
#           "doi": null,
#           "raw": "Visscher PK (2007) Group decision making in nest-site selection among social insects. Annual Review of Entomology 52: 255\u2013275.",
#           "cites": null
#         },
#         {
#           "id": 27283209,
#           "title": "Group decision making in swarms of honey bees.",
#           "authors": [],
#           "date": "1999",
#           "doi": null,
#           "raw": "Seeley TD, Buhrman SC (1999) Group decision making in swarms of honey bees. Behav Ecol Sociobiol 45: 19\u201331.",
#           "cites": null
#         },
#         {
#           "id": 27283202,
#           "title": "How western scrub-jays (Aphelocoma californica) select a nut: effects of the number of options, variation in nut size, and social competition among foragers.",
#           "authors": [],
#           "date": "1999",
#           "doi": null,
#           "raw": "Langen TA (1999) How western scrub-jays (Aphelocoma californica) select a nut: effects of the number of options, variation in nut size, and social competition among foragers. Anim Cognition 2: 223\u2013233.",
#           "cites": null
#         },
#         {
#           "id": 27283201,
#           "title": "Impulsive bees forage better: the advantage of quick, sometimes inaccurate foraging decisions. Anim Behav 70: e1\u20135. A Threshold Rule for Collective Decisions PLoS",
#           "authors": [],
#           "date": "2007",
#           "doi": null,
#           "raw": "Burns JG (2007) Impulsive bees forage better: the advantage of quick, sometimes inaccurate foraging decisions. Anim Behav 70: e1\u20135. A Threshold Rule for Collective Decisions PLoS ONE | www.plosone.org 10 May 2011 | Volume 6 | Issue 5 | e199817. Kacelnik A, Vasconcelos M, Monteiro T, Aw J (2011) Darwin\u2019s \u2018Tug-of-War\u2019 vs. Starlings\u2019 \u2018Horse-Racing\u2019: how adaptations for sequential encounters drive simultaneous choice. Behav Ecol Sociobiol 65: 547\u2013558.",
#           "cites": null
#         },
#         {
#           "id": 27283214,
#           "title": "Individual and collective decisionmaking during nest site selection by the ant Leptothorax albipennis.",
#           "authors": [],
#           "date": "2001",
#           "doi": null,
#           "raw": "Mallon EB, Pratt SC, Franks NR (2001) Individual and collective decisionmaking during nest site selection by the ant Leptothorax albipennis. Behav Ecol Sociobiol 50: 352\u2013359.",
#           "cites": null
#         },
#         {
#           "id": 27283278,
#           "title": "Individual experience alone can generate lasting division of labor in ants.",
#           "authors": [],
#           "date": "2007",
#           "doi": null,
#           "raw": "Ravary F, Lecoutey E, Kaminski G, Cha \u02c6line N, Jaisson P (2007) Individual experience alone can generate lasting division of labor in ants. Curr Biol 17: 1308\u20131312.",
#           "cites": null
#         },
#         {
#           "id": 27283262,
#           "title": "Intransitivity of performance in honey bees: support for \u2018comparative\u2019 evaluation of foraging options.",
#           "authors": [],
#           "date": "1994",
#           "doi": null,
#           "raw": "Shafir S (1994) Intransitivity of performance in honey bees: support for \u2018comparative\u2019 evaluation of foraging options. Anim Behav 48: 55\u201367.",
#           "cites": null
#         },
#         {
#           "id": 27283196,
#           "title": "Is more choice always desirable? Evidence and arguments from leks, food selection, and environmental enrichment.",
#           "authors": [],
#           "date": "2005",
#           "doi": null,
#           "raw": "Hutchinson JMC (2005) Is more choice always desirable? Evidence and arguments from leks, food selection, and environmental enrichment. Biol Rev 80: 73\u201392.",
#           "cites": null
#         },
#         {
#           "id": 27283235,
#           "title": "IUCN Red List of Threatened Species.",
#           "authors": [],
#           "date": "2008",
#           "doi": null,
#           "raw": "IUCN (2008) IUCN Red List of Threatened Species.",
#           "cites": null
#         },
#         {
#           "id": 27283277,
#           "title": "Levels of behavioral organization and the evolution of division of labor.",
#           "authors": [],
#           "date": "2002",
#           "doi": null,
#           "raw": "Page RE, Erber J (2002) Levels of behavioral organization and the evolution of division of labor. Naturwissenschaften 89: 91\u2013106.",
#           "cites": null
#         },
#         {
#           "id": 27283244,
#           "title": "Modeling and analysis of nest-site selection by honeybee swarms: the speed and accuracy trade-off.",
#           "authors": [],
#           "date": "2006",
#           "doi": null,
#           "raw": "Passino KM, Seeley TD (2006) Modeling and analysis of nest-site selection by honeybee swarms: the speed and accuracy trade-off. Behav Ecol Sociobiol 59: 427\u2013442.",
#           "cites": null
#         },
#         {
#           "id": 27283273,
#           "title": "Models of division of labor in insect societies.",
#           "authors": [],
#           "date": "2001",
#           "doi": null,
#           "raw": "Beshers SN, Fewell JH (2001) Models of division of labor in insect societies. Ann Rev Entomol 46: 413\u2013430.",
#           "cites": null
#         },
#         {
#           "id": 27283272,
#           "title": "Modulation of alarm pheromone perception in the honey bee - evidence for division of labor based on hormonally regulated response thresholds.",
#           "authors": [],
#           "date": "1987",
#           "doi": null,
#           "raw": "Robinson GE (1987) Modulation of alarm pheromone perception in the honey bee - evidence for division of labor based on hormonally regulated response thresholds. J Comp Physiol A 160: 613\u2013619.",
#           "cites": null
#         },
#         {
#           "id": 27283252,
#           "title": "Modulation of trail laying in the ant Lasius niger (Hymenoptera, Formicidae) and its role in the collective selection of a food source.",
#           "authors": [],
#           "date": "1993",
#           "doi": null,
#           "raw": "Beckers R, Deneubourg JL, Goss S (1993) Modulation of trail laying in the ant Lasius niger (Hymenoptera, Formicidae) and its role in the collective selection of a food source. J Insect Behav 6: 751\u2013759.",
#           "cites": null
#         },
#         {
#           "id": 27283247,
#           "title": "Nest-site selection in honeybees: how well do swarms implement the \u2018\u2018best-of-N\u2019\u2019 decision rule?",
#           "authors": [],
#           "date": "2001",
#           "doi": null,
#           "raw": "Seeley TD, Buhrman SC (2001) Nest-site selection in honeybees: how well do swarms implement the \u2018\u2018best-of-N\u2019\u2019 decision rule? Behav Ecol Sociobiol 49: 416\u2013427.",
#           "cites": null
#         },
#         {
#           "id": 27283215,
#           "title": "Noise, cost and speedaccuracy trade-offs: decision-making in a decentralised system.",
#           "authors": [],
#           "date": "2005",
#           "doi": null,
#           "raw": "Marshall JAR, Dornhaus A, Franks NR, Kovacs T (2005) Noise, cost and speedaccuracy trade-offs: decision-making in a decentralised system. J Roy Soc: Interface 3: 243\u2013254.",
#           "cites": null
#         },
#         {
#           "id": 27283213,
#           "title": "Not everything that counts can be counted: ants use multiple metrics for a single nest trait.",
#           "authors": [],
#           "date": "2006",
#           "doi": null,
#           "raw": "Franks NR, Dornhaus A, Metherell B, Nelson T, Lanfear SA, et al. (2006) Not everything that counts can be counted: ants use multiple metrics for a single nest trait. Proc R Soc Lond B 273: 165\u2013169.",
#           "cites": null
#         },
#         {
#           "id": 27283266,
#           "title": "On optimal decision making in brains and social insect colonies.",
#           "authors": [],
#           "date": "2009",
#           "doi": null,
#           "raw": "Marshall JAR, Bogacz R, Dornhaus A, Planque \u00b4 R, Kovacs T, et al. (2009) On optimal decision making in brains and social insect colonies. J Roy Soc: Interface 6: 1065\u20131074.",
#           "cites": null
#         },
#         {
#           "id": 27283206,
#           "title": "Optimization, conflict and nonoverlapping foraging ranges in ants.",
#           "authors": [],
#           "date": "2003",
#           "doi": null,
#           "raw": "Adler FR, Gordon DM (2003) Optimization, conflict and nonoverlapping foraging ranges in ants. Am Nat 162: 529\u2013543.",
#           "cites": null
#         },
#         {
#           "id": 27283224,
#           "title": "Probability, Random Variables and Stochastic Processes.",
#           "authors": [],
#           "date": "2002",
#           "doi": null,
#           "raw": "Papoulis A, Pillai SU (2002) Probability, Random Variables and Stochastic Processes. New York: McGraw Hill. 666 p.",
#           "cites": null
#         },
#         {
#           "id": 27283265,
#           "title": "Quorum sensing during nest-site selection by honeybee swarms.",
#           "authors": [],
#           "date": "2004",
#           "doi": null,
#           "raw": "Seeley TD, Visscher PK (2004) Quorum sensing during nest-site selection by honeybee swarms. Behav Ecol Sociobiol 56: 594\u2013601.",
#           "cites": null
#         },
#         {
#           "id": 27283212,
#           "title": "Quorum sensing, recruitment, and collective decision-making during colony emigration by the ant Leptothorax albipennis.",
#           "authors": [],
#           "date": "2002",
#           "doi": null,
#           "raw": "Pratt SC, Mallon EB, Sumpter DJT, Franks NR (2002) Quorum sensing, recruitment, and collective decision-making during colony emigration by the ant Leptothorax albipennis. Behav Ecol Sociobiol 52: 117\u2013127.",
#           "cites": null
#         },
#         {
#           "id": 27283237,
#           "title": "Radio-tagging reveals the roles of corpulence, experience and social information in ant decision making.",
#           "authors": [],
#           "date": "2009",
#           "doi": null,
#           "raw": "Robinson EJH, Richardson TO, Sendova-Franks AB, Feinerman O, Franks NR (2009) Radio-tagging reveals the roles of corpulence, experience and social information in ant decision making. Behav Ecol Sociobiol 63: 627\u2013636.",
#           "cites": null
#         },
#         {
#           "id": 27283270,
#           "title": "Rationality in collective decision-making by ant colonies.",
#           "authors": [],
#           "date": "2009",
#           "doi": null,
#           "raw": "Edwards S, Pratt SC (2009) Rationality in collective decision-making by ant colonies. Proc R Soc Lond B 276: 3655\u20133661.",
#           "cites": null
#         },
#         {
#           "id": 27283276,
#           "title": "Response threshold reinforcement and division of labour in insect societies.",
#           "authors": [],
#           "date": "1998",
#           "doi": null,
#           "raw": "The \u00b4raulaz G, Bonabeau E, Deneubourg JL (1998) Response threshold reinforcement and division of labour in insect societies. Proc R Soc Lond B 265: 327\u2013332.",
#           "cites": null
#         },
#         {
#           "id": 27283236,
#           "title": "Responsibility in the use of animals in bioscience research: Expectations of the major research council and charitable funding bodies.",
#           "authors": [],
#           "date": "2010",
#           "doi": null,
#           "raw": "National-Centre-for-the-Replacement-Refinement-and-Reduction-of-Animalsin-Research (2010) Responsibility in the use of animals in bioscience research: Expectations of the major research council and charitable funding bodies. London: Tradewinds.",
#           "cites": null
#         },
#         {
#           "id": 27283197,
#           "title": "Search theory and mate choice. I. Models of single-sex discrimination.",
#           "authors": [],
#           "date": "1990",
#           "doi": null,
#           "raw": "Real L (1990) Search theory and mate choice. I. Models of single-sex discrimination. Am Nat 136: 376\u2013405.",
#           "cites": null
#         },
#         {
#           "id": 27283198,
#           "title": "Searching for a new home: decision making by dispersing brush mice.",
#           "authors": [],
#           "date": "2008",
#           "doi": null,
#           "raw": "Mabry KE, Stamps JA (2008) Searching for a new home: decision making by dispersing brush mice. Am Nat 172: 625\u2013634.",
#           "cites": null
#         },
#         {
#           "id": 27283246,
#           "title": "Sensory coding of nest-site value in honeybee swarms.",
#           "authors": [],
#           "date": "2008",
#           "doi": null,
#           "raw": "Seeley TD, Visscher PK (2008) Sensory coding of nest-site value in honeybee swarms. J Exp Biol 211: 3691\u20133697.",
#           "cites": null
#         },
#         {
#           "id": 27283260,
#           "title": "Shell wars - assessment strategies and the timing of decisions in hermit crab shell fights.",
#           "authors": [],
#           "date": "1983",
#           "doi": null,
#           "raw": "Dowds BM, Elwood RW (1983) Shell wars - assessment strategies and the timing of decisions in hermit crab shell fights. Behaviour 85: 1\u201324.",
#           "cites": null
#         },
#         {
#           "id": 27283211,
#           "title": "Social organization of nest emigration in Leptothorax (Hym.",
#           "authors": [],
#           "date": "1978",
#           "doi": null,
#           "raw": "Mo \u00a8glich M (1978) Social organization of nest emigration in Leptothorax (Hym. Form.). Insect Soc 25: 205\u2013225.",
#           "cites": null
#         },
#         {
#           "id": 27283210,
#           "title": "Strategies for choosing between alternatives with different attributes: exemplified by househunting ants.",
#           "authors": [],
#           "date": "2003",
#           "doi": null,
#           "raw": "Franks NR, Mallon EB, Bray HE, Hamilton MJ, Mischler TC (2003) Strategies for choosing between alternatives with different attributes: exemplified by househunting ants. Anim Behav 65: 215\u2013223.",
#           "cites": null
#         },
#         {
#           "id": 27283249,
#           "title": "Tactics of dance choice in honey bees: do foragers compare dances?",
#           "authors": [],
#           "date": "1992",
#           "doi": null,
#           "raw": "Seeley TD, Towne WF (1992) Tactics of dance choice in honey bees: do foragers compare dances? Behav Ecol Sociobiol 30: 59\u201369.",
#           "cites": null
#         },
#         {
#           "id": 27283279,
#           "title": "Teaching in tandem-running ants. Nature 439: 153. A Threshold Rule for Collective Decisions",
#           "authors": [],
#           "date": "2006",
#           "doi": null,
#           "raw": "Franks NR, Richardson TO (2006) Teaching in tandem-running ants. Nature 439: 153. A Threshold Rule for Collective Decisions PLoS ONE | www.plosone.org 11 May 2011 | Volume 6 | Issue 5 | e19981",
#           "cites": null
#         },
#         {
#           "id": 27283275,
#           "title": "The effect of prior experience on nest site evaluation by the ant Temnothorax curvispinosus.",
#           "authors": [],
#           "date": "2008",
#           "doi": null,
#           "raw": "Healey CIM, Pratt SC (2008) The effect of prior experience on nest site evaluation by the ant Temnothorax curvispinosus. Anim Behav 76: 893\u2013899.",
#           "cites": null
#         },
#         {
#           "id": 27283239,
#           "title": "The evolution of color vision in insects.",
#           "authors": [],
#           "date": "2001",
#           "doi": null,
#           "raw": "Briscoe AD, Chittka L (2001) The evolution of color vision in insects. Ann Rev Entomol 46: 471\u2013510.",
#           "cites": null
#         },
#         {
#           "id": 27283269,
#           "title": "The robustness of the asymmetrically dominated effect: Buying frames, phantom alternatives, and in-store purchases.",
#           "authors": [],
#           "date": "1999",
#           "doi": null,
#           "raw": "Doyle JR, O\u2019Connor DJ, Reynolds GM, Bottomley PA (1999) The robustness of the asymmetrically dominated effect: Buying frames, phantom alternatives, and in-store purchases. Psychol Mark 16: 225\u2013243.",
#           "cites": null
#         },
#         {
#           "id": 27283241,
#           "title": "The Secretary Problem and Its Extensions: A Review.",
#           "authors": [],
#           "date": "1983",
#           "doi": null,
#           "raw": "Freeman PR (1983) The Secretary Problem and Its Extensions: A Review. Int Stat Rev 51: 189\u2013206.",
#           "cites": null
#         },
#         {
#           "id": 27283217,
#           "title": "Weighted waiting in collective decision-making.",
#           "authors": [],
#           "date": "2007",
#           "doi": null,
#           "raw": "Planque \u00b4 R, Dornhaus A, Franks NR, Kovacs T, Marshall JAR (2007) Weighted waiting in collective decision-making. Behav Ecol Sociobiol 61: 347\u2013356.",
#           "cites": null
#         },
#         {
#           "id": 27283199,
#           "title": "When good enough is best.",
#           "authors": [],
#           "date": "2006",
#           "doi": null,
#           "raw": "Kay LM, Beshel J, Martin C (2006) When good enough is best. Neuron 51: 277\u2013278.",
#           "cites": null
#         },
#         {
#           "id": 27283259,
#           "title": "Why do males of the dance fly Empis borealis refuse to mate? The importance of female age and size.",
#           "authors": [],
#           "date": "1989",
#           "doi": null,
#           "raw": "Svensson BG, Petersson E, Forsgren E (1989) Why do males of the dance fly Empis borealis refuse to mate? The importance of female age and size. J Insect Behav 2: 387\u2013395.",
#           "cites": null
#         }
#       ],
#       "sourceFulltextUrls": [
#         "http://www.pubmedcentral.nih.gov/articlerender.fcgi?artid=3101226"
#       ],
#       "updatedDate": "",
#       "yearPublished": "2011",
#       "links": [
#         {
#           "type": "download",
#           "url": "https://core.ac.uk/download/8569611.pdf"
#         },
#         {
#           "type": "reader",
#           "url": "https://core.ac.uk/reader/8569611"
#         },
#         {
#           "type": "thumbnail_m",
#           "url": "https://core.ac.uk/image/8569611/medium"
#         },
#         {
#           "type": "thumbnail_l",
#           "url": "https://core.ac.uk/image/8569611/large"
#         },
#         {
#           "type": "display",
#           "url": "https://core.ac.uk/outputs/8569611"
#         }
#       ],
#       "abstract": "Decision-making animals can use slow-but-accurate strategies, such as making multiple comparisons, or opt for simpler, faster strategies to find a \u2018good enough\u2019 option. Social animals make collective decisions about many group behaviours including foraging and migration. The key to the collective choice lies with individual behaviour. We present a case study of a collective decision-making process (house-hunting ants, Temnothorax albipennis), in which a previously proposed decision strategy involved both quality-dependent hesitancy and direct comparisons of nests by scouts. An alternative possible decision strategy is that scouting ants use a very simple quality-dependent threshold rule to decide whether to recruit nest-mates to a new site or search for alternatives. We use analytical and simulation modelling to demonstrate that this simple rule is sufficient to explain empirical patterns from three studies of collective decision-making in ants, and can account parsimoniously for apparent comparison by individuals and apparent hesitancy (recruitment latency) effects, when available nests differ strongly in quality. This highlights the need to carefully design experiments to detect individual comparison. We present empirical data strongly suggesting that best-of-n comparison is not used by individual ants, although individual sequential comparisons are not ruled out. However, by using a simple threshold rule, decision-making groups are able to effectively compare options, without relying on any form of direct comparison of alternatives by individuals. This parsimonious mechanism could promote collective rationality in group decision-making",
#       "tags": [
#         "Text",
#         "Research Article"
#       ],
#       "fulltextStatus": "disabled",
#       "subjects": [
#         "Text"
#       ],
#       "oai": "oai:pubmedcentral.nih.gov:3101226",
#       "deleted": "DELETED",
#       "disabled": true,
#       "journals": null,
#       "repositories": {
#         "id": "150",
#         "openDoarId": 0,
#         "name": "PubMed Central",
#         "urlHomepage": null,
#         "uriJournals": null,
#         "physicalName": "noname",
#         "roarId": 0,
#         "baseId": 0,
#         "pdfStatus": null,
#         "nrUpdates": 0,
#         "lastUpdateTime": null
#       },
#       "repositoryDocument": {
#         "id": 8569611,
#         "depositedDate": null,
#         "publishedDate": "2011-05-24T01:00:00+01:00",
#         "updatedDate": "2019-12-02T21:52:26+00:00",
#         "acceptedDate": null,
#         "createdDate": "2012-07-08T14:39:10+01:00"
#       },
#       "urls": [
#         "http://dx.doi.org/10.1371/journal.pone.0019981"
#       ],
#       "lastUpdate": "2019-12-02T21:52:26+00:00"
#     },
#     {
#       "acceptedDate": "",
#       "authors": [
#         {
#           "name": "Robinson, E.J.H."
#         },
#         {
#           "name": "Franks, N.R."
#         },
#         {
#           "name": "Ellis, S."
#         },
#         {
#           "name": "Okuda, S."
#         },
#         {
#           "name": "Marshall, J.A.R."
#         }
#       ],
#       "contributors": [],
#       "createdDate": "2016-08-02T14:39:49+01:00",
#       "dataProvider": {
#         "id": 140,
#         "name": "White Rose Research Online",
#         "url": "https://api.core.ac.uk/v3/data-providers/140",
#         "logo": "https://api.core.ac.uk/data-providers/140/logo"
#       },
#       "depositedDate": "2011-05-24T00:00:00+01:00",
#       "documentType": "research",
#       "doi": "10.1371/journal.pone.0019981",
#       "downloadUrl": "https://core.ac.uk/download/42624856.pdf",
#       "fullText": "A Simple Threshold Rule Is Sufficient to ExplainSophisticated Collective Decision-MakingElva J. H. Robinson1,2*, Nigel R. Franks1, Samuel Ellis1, Saki Okuda1, James A. R. Marshall31 School of Biological Sciences, University of Bristol, Bristol, United Kingdom, 2 York Centre for Complex Systems Analysis, Department of Biology, University of York, York,United Kingdom, 3Department of Computer Science and Kroto Research Institute, University of Sheffield, Sheffield, United KingdomAbstractDecision-making animals can use slow-but-accurate strategies, such as making multiple comparisons, or opt for simpler,faster strategies to find a \u2018good enough\u2019 option. Social animals make collective decisions about many group behavioursincluding foraging and migration. The key to the collective choice lies with individual behaviour. We present a case study ofa collective decision-making process (house-hunting ants, Temnothorax albipennis), in which a previously proposed decisionstrategy involved both quality-dependent hesitancy and direct comparisons of nests by scouts. An alternative possibledecision strategy is that scouting ants use a very simple quality-dependent threshold rule to decide whether to recruit nest-mates to a new site or search for alternatives. We use analytical and simulation modelling to demonstrate that this simplerule is sufficient to explain empirical patterns from three studies of collective decision-making in ants, and can accountparsimoniously for apparent comparison by individuals and apparent hesitancy (recruitment latency) effects, when availablenests differ strongly in quality. This highlights the need to carefully design experiments to detect individual comparison. Wepresent empirical data strongly suggesting that best-of-n comparison is not used by individual ants, although individualsequential comparisons are not ruled out. However, by using a simple threshold rule, decision-making groups are able toeffectively compare options, without relying on any form of direct comparison of alternatives by individuals. Thisparsimonious mechanism could promote collective rationality in group decision-making.Citation: Robinson EJH, Franks NR, Ellis S, Okuda S, Marshall JAR (2011) A Simple Threshold Rule Is Sufficient to Explain Sophisticated Collective Decision-Making. PLoS ONE 6(5): e19981. doi:10.1371/journal.pone.0019981Editor: Frederick R. Adler, University of Utah, United States of AmericaReceived December 6, 2010; Accepted April 22, 2011; Published May 24, 2011Copyright: \u0002 2011 Robinson et al. This is an open-access article distributed under the terms of the Creative Commons Attribution License, which permitsunrestricted use, distribution, and reproduction in any medium, provided the original author and source are credited.Funding: EJHR and NRF acknowledge support from EPSRC grant EP/D076226/1 http://www.epsrc.ac.uk/Pages/default.aspx. SO was supported by a NuffieldUndergraduate Bursary http://users.ecs.soton.ac.uk/saw/nuffield.html; SE was supported by a University of Bristol Summer Studentship http://www.bristol.ac.uk/biology. The funders had no role in study design, data collection and analysis, decision to publish, or preparation of the manuscript.Competing Interests: Author James Marshall is an Academic Editor for PLoS.* E-mail: Elva.Robinson@yccsa.orgIntroductionAnimals need to make choices between multiple available op-tions at many stages in their life histories, such as during mateselection, foraging, or when deciding where to shelter or to build anest. The fitness benefits of choosing the best option mean thatdecision-making strategies will be subject to natural selection. Mul-tiple comparison or \u2018best of n\u2019 strategies perform most accurately,and are likely to be optimal when searching and sampling costs arelow, e.g. on a lek [1,2] and when long-term fitness implications ofthe decision are high, e.g. in home range selection [3]. In othersituations, e.g. during foraging, ...
#       "id": 42624856,
#       "identifiers": {
#         "doi": "10.1371/journal.pone.0019981",
#         "oai": "oai:eprints.whiterose.ac.uk:99644"
#       },
#       "title": "A Simple Threshold Rule Is Sufficient to Explain Sophisticated Collective Decision-Making",
#       "language": null,
#       "publishedDate": "2011-05-24T01:00:00+01:00",
#       "publisher": "'Public Library of Science (PLoS)'",
#       "references": [],
#       "sourceFulltextUrls": [
#         "https://eprints.whiterose.ac.uk/99644/1/A%20simple%20threshold%20rule%20is%20sufficient%20to%20explain%20sophisticated%20collective%20decision-making.pdf"
#       ],
#       "updatedDate": "",
#       "yearPublished": "2011",
#       "links": [
#         {
#           "type": "download",
#           "url": "https://core.ac.uk/download/42624856.pdf"
#         },
#         {
#           "type": "reader",
#           "url": "https://core.ac.uk/reader/42624856"
#         },
#         {
#           "type": "thumbnail_m",
#           "url": "https://core.ac.uk/image/42624856/medium"
#         },
#         {
#           "type": "thumbnail_l",
#           "url": "https://core.ac.uk/image/42624856/large"
#         },
#         {
#           "type": "display",
#           "url": "https://core.ac.uk/outputs/42624856"
#         }
#       ],
#       "abstract": "Decision-making animals can use slow-but-accurate strategies, such as making multiple comparisons, or opt for simpler, faster strategies to find a \u2018good enough\u2019 option. Social animals make collective decisions about many group behaviours including foraging and migration. The key to the collective choice lies with individual behaviour. We present a case study of a collective decision-making process (house-hunting ants, Temnothorax albipennis), in which a previously proposed decision strategy involved both quality-dependent hesitancy and direct comparisons of nests by scouts. An alternative possible decision strategy is that scouting ants use a very simple quality-dependent threshold rule to decide whether to recruit nest-mates to a new site or search for alternatives. We use analytical and simulation modelling to demonstrate that this simple rule is sufficient to explain empirical patterns from three studies of collective decision-making in ants, and can account parsimoniously for apparent comparison by individuals and apparent hesitancy (recruitment latency) effects, when available nests differ strongly in quality. This highlights the need to carefully design experiments to detect individual comparison. We present empirical data strongly suggesting that best-of-n comparison is not used by individual ants, although individual sequential comparisons are not ruled out. However, by using a simple threshold rule, decision-making groups are able to effectively compare options, without relying on any form of direct comparison of alternatives by individuals. This parsimonious mechanism could promote collective rationality in group decision-making",
#       "tags": [],
#       "fulltextStatus": "disabled",
#       "subjects": [],
#       "oai": "oai:eprints.whiterose.ac.uk:99644",
#       "deleted": "ALLOWED",
#       "disabled": false,
#       "journals": null,
#       "repositories": {
#         "id": "140",
#         "openDoarId": 0,
#         "name": "White Rose Research Online",
#         "urlHomepage": null,
#         "uriJournals": null,
#         "physicalName": "noname",
#         "roarId": 0,
#         "baseId": 0,
#         "pdfStatus": null,
#         "nrUpdates": 0,
#         "lastUpdateTime": null
#       },
#       "repositoryDocument": {
#         "id": 42624856,
#         "depositedDate": "2011-05-24T00:00:00+01:00",
#         "publishedDate": "2011-05-24T01:00:00+01:00",
#         "updatedDate": "2023-07-10T13:39:52+01:00",
#         "acceptedDate": null,
#         "createdDate": "2016-08-02T14:39:49+01:00"
#       },
#       "urls": [
#         "https://eprints.whiterose.ac.uk/99644/1/A%20simple%20threshold%20rule%20is%20sufficient%20to%20explain%20sophisticated%20collective%20decision-making.pdf"
#       ],
#       "lastUpdate": "2023-07-10T13:39:52+01:00"
#     },
#     {
#       "acceptedDate": "2011-05-24T00:00:00+01:00",
#       "authors": [
#         {
#           "name": "Robinson, Elva J. H."
#         },
#         {
#           "name": "Franks, Nigel R."
#         },
#         {
#           "name": "Ellis, Samuel"
#         },
#         {
#           "name": "Okuda, Saki"
#         },
#         {
#           "name": "Marshall, James A. R."
#         }
#       ],
#       "contributors": [],
#       "createdDate": "2012-06-28T04:00:54+01:00",
#       "dataProvider": {
#         "id": 140,
#         "name": "White Rose Research Online",
#         "url": "https://api.core.ac.uk/v3/data-providers/140",
#         "logo": "https://api.core.ac.uk/data-providers/140/logo"
#       },
#       "depositedDate": "2011-05-24T00:00:00+01:00",
#       "documentType": "unknown",
#       "doi": "10.1371/journal.pone.0019981",
#       "downloadUrl": "https://core.ac.uk/download/5225915.pdf",
# ...
#         },
#         {
#           "name": "Okuda, S"
#         },
#         {
#           "name": "Marshall, JAR"
#         }
#       ],
#       "contributors": [],
#       "createdDate": "2019-08-10T10:54:01+01:00",
#       "dataProvider": {
#         "id": 286,
#         "name": "Explore Bristol Research",
#         "url": "https://api.core.ac.uk/v3/data-providers/286",
#         "logo": "https://api.core.ac.uk/data-providers/286/logo"
#       },
#       "depositedDate": "",
#       "documentType": "",
#       "doi": "10.1371/journal.pone.0019981",
#       "downloadUrl": "https://doi.org/10.1371/journal.pone.0019981",
#       "fullText": "",
#       "id": 223321058,
#       "identifiers": {
#         "doi": "10.1371/journal.pone.0019981",
#         "oai": "oai:research-information.bris.ac.uk:publications/0f3da01c-4f5c-43ee-af67-1358d550362c"
#       },
#       "title": "A simple threshold rule is sufficient to explain sophisticated collective decision-making",
#       "language": null,
#       "publishedDate": "2011-01-01T00:00:00+00:00",
#       "publisher": "'Public Library of Science (PLoS)'",
#       "references": [],
#       "sourceFulltextUrls": [],
#       "updatedDate": "",
#       "yearPublished": "2011",
#       "links": [
#         {
#           "type": "display",
#           "url": "https://core.ac.uk/outputs/223321058"
#         }
#       ],
#       "abstract": "",
#       "tags": [
#         "article"
#       ],
#       "fulltextStatus": "disabled",
#       "subjects": [
#         "article"
#       ],
#       "oai": "oai:research-information.bris.ac.uk:publications/0f3da01c-4f5c-43ee-af67-1358d550362c",
#       "deleted": "ALLOWED",
#       "disabled": false,
#       "journals": null,
#       "repositories": {
#         "id": "286",
#         "openDoarId": 0,
#         "name": "Explore Bristol Research",
#         "urlHomepage": null,
#         "uriJournals": null,
#         "physicalName": "noname",
#         "roarId": 0,
#         "baseId": 0,
#         "pdfStatus": null,
#         "nrUpdates": 0,
#         "lastUpdateTime": null
#       },
#       "repositoryDocument": {
#         "id": 223321058,
#         "depositedDate": null,
#         "publishedDate": "2011-01-01T00:00:00+00:00",
#         "updatedDate": "2022-12-14T02:51:01+00:00",
#         "acceptedDate": null,
#         "createdDate": "2019-08-10T10:54:01+01:00"
#       },
#       "urls": [
#         "https://doi.org/10.1371/journal.pone.0019981",
#         "https://research-information.bris.ac.uk/en/publications/0f3da01c-4f5c-43ee-af67-1358d550362c",
#         "https://hdl.handle.net/1983/0f3da01c-4f5c-43ee-af67-1358d550362c"
#       ],
#       "lastUpdate": "2022-12-14T02:51:01+00:00"
#     },
#     {
#       "acceptedDate": "2011-05-24T00:00:00+01:00",
#       "authors": [
#         {
#           "name": "Elva J. H. Robinson"
#         },
#         {
#           "name": "Nigel R. Franks"
#         },
#         {
#           "name": "Samuel Ellis"
#         },
#         {
#           "name": "Saki Okuda"
#         },
#         {
#           "name": "James A. R. Marshall"
#         },
#         {
#           "name": "Frederick R. Adler"
#         },
#         {
#           "name": "JMC Hutchinson"
#         },
#         {
#           "name": "L Real"
#         },
#         {
#           "name": "KE Mabry"
#         },
#         {
#           "name": "LM Kay"
#         },
#         {
#           "name": "L Chittka"
#         },
#         {
#           "name": "JG Burns"
#         },
#         {
#           "name": "A Kacelnik"
#         },
#         {
#           "name": "TA Langen"
#         },
#         {
#           "name": "AJ Moore"
#         },
#         {
#           "name": "JM Am\u00e9"
#         },
#         {
#           "name": "L Conradt"
#         },
#         {
#           "name": "FR Adler"
#         },
#         {
#           "name": "L Conradt"
#         },
#         {
#           "name": "SA Levin"
#         },
#         {
#           "name": "TD Seeley"
#         },
#         {
#           "name": "NR Franks"
#         },
#         {
#           "name": "M M\u00f6glich"
#         },
#         {
#           "name": "SC Pratt"
#         },
#         {
#           "name": "NR Franks"
#         },
#         {
#           "name": "EB Mallon"
#         },
#         {
#           "name": "JAR Marshall"
#         },
#         {
#           "name": "SC Pratt"
#         },
#         {
#           "name": "R Planqu\u00e9"
#         },
#         {
#           "name": "SC Pratt"
#         },
#         {
#           "name": "T Sasaki"
#         },
#         {
#           "name": "EJH Robinson"
#         },
#         {
#           "name": "NR Franks"
#         },
#         {
#           "name": "SC Pratt"
#         },
#         {
#           "name": "A Papoulis"
#         },
#         {
#           "name": "EJH Robinson"
#         },
#         {
#           "name": "EJH Robinson"
#         },
#         {
#           "name": "AD Briscoe"
#         },
#         {
#           "name": "B Luttbeg"
#         },
#         {
#           "name": "PR Freeman"
#         },
#         {
#           "name": "EB Mallon"
#         },
#         {
#           "name": "PK Visscher"
#         },
#         {
#           "name": "KM Passino"
#         },
#         {
#           "name": "PK Visscher"
#         },
#         {
#           "name": "TD Seeley"
#         },
#         {
#           "name": "TD Seeley"
#         },
#         {
#           "name": "TD Seeley"
#         },
#         {
#           "name": "TD Seeley"
#         },
#         {
#           "name": "TD Seeley"
#         },
#         {
#           "name": "JC Nieh"
#         },
#         {
#           "name": "R Beckers"
#         },
#         {
#           "name": "VM Schmidt"
#         },
#         {
#           "name": "JC de Biseau"
#         },
#         {
#           "name": "JH Fewell"
#         },
#         {
#           "name": "EO Wilson"
#         },
#         {
#           "name": "R Dhar"
#         },
#         {
#           "name": "JAC Uy"
#         },
#         {
#           "name": "BG Svensson"
#         },
#         {
#           "name": "BM Dowds"
#         },
#         {
#           "name": "L Chittka"
#         },
#         {
#           "name": "S Shafir"
#         },
#         {
#           "name": "PM Todd"
#         },
#         {
#           "name": "JAR Marshall"
#         },
#         {
#           "name": "TD Seeley"
#         },
#         {
#           "name": "JAR Marshall"
#         },
#         {
#           "name": "NR Franks"
#         },
#         {
#           "name": "M Bateson"
#         },
#         {
#           "name": "JR Doyle"
#         },
#         {
#           "name": "S Edwards"
#         },
#         {
#           "name": "NW Calderone"
#         },
#         {
#           "name": "GE Robinson"
#         },
#         {
#           "name": "SN Beshers"
#         },
#         {
#           "name": "N Stroeymeyt"
#         },
#         {
#           "name": "CIM Healey"
#         },
#         {
#           "name": "G Th\u00e9raulaz"
#         },
#         {
#           "name": "RE Page"
#         },
#         {
#           "name": "F Ravary"
#         },
#         {
#           "name": "NR Franks"
#         }
#       ],
#       "contributors": [
#         ""
#       ],
#       "createdDate": "2019-04-01T18:19:00+01:00",
#       "dataProvider": {
#         "id": 4786,
#         "name": "Crossref",
#         "url": "https://api.core.ac.uk/v3/data-providers/4786",
#         "logo": "https://api.core.ac.uk/data-providers/4786/logo"
#       },
#       "depositedDate": "2011-05-24T00:00:00+01:00",
#       "documentType": "",
#       "doi": "10.1371/journal.pone.0019981",
#       "downloadUrl": "",
#       "fullText": "",
#       "id": 193838621,
#       "identifiers": {
#         "doi": "10.1371/journal.pone.0019981",
#         "oai": null
#       },
#       "title": "A Simple Threshold Rule Is Sufficient to Explain Sophisticated Collective Decision-Making",
#       "language": null,
#       "publishedDate": "",
#       "publisher": "'Public Library of Science (PLoS)'",
#       "references": [],
#       "sourceFulltextUrls": [],
#       "updatedDate": "",
#       "yearPublished": "",
#       "links": [
#         {
#           "type": "display",
#           "url": "https://core.ac.uk/outputs/193838621"
#         }
#       ],
#       "abstract": "",
#       "tags": [],
#       "fulltextStatus": "disabled",
#       "subjects": [],
#       "oai": "",
#       "deleted": "ALLOWED",
#       "disabled": false,
#       "journals": null,
#       "repositories": {
#         "id": "4786",
#         "openDoarId": 0,
#         "name": "Crossref",
#         "urlHomepage": null,
#         "uriJournals": null,
#         "physicalName": "noname",
#         "roarId": 0,
#         "baseId": 0,
#         "pdfStatus": null,
#         "nrUpdates": 0,
#         "lastUpdateTime": null
#       },
#       "repositoryDocument": {
#         "id": 193838621,
#         "depositedDate": "2011-05-24T00:00:00+01:00",
#         "publishedDate": null,
#         "updatedDate": "2021-04-30T13:50:01+01:00",
#         "acceptedDate": "2011-05-24T00:00:00+01:00",
#         "createdDate": "2019-04-01T18:19:00+01:00"
#       },
#       "urls": [],
#       "lastUpdate": "2021-04-30T13:50:01+01:00"
#     },
#     {
#       "acceptedDate": "",
#       "authors": [
#         {
#           "name": "Elva J H Robinson"
#         },
#         {
#           "name": "Nigel R Franks"
#         },
#         {
#           "name": "Samuel Ellis"
#         },
#         {
#           "name": "Saki Okuda"
#         },
#         {
#           "name": "James A R Marshall"
#         }
#       ],
#       "contributors": [],
#       "createdDate": "2017-10-13T17:10:42+01:00",
#       "dataProvider": {
#         "id": 645,
#         "name": "Directory of Open Access Journals",
#         "url": "https://api.core.ac.uk/v3/data-providers/645",
#         "logo": "https://api.core.ac.uk/data-providers/645/logo"
#       },
#       "depositedDate": "",
#       "documentType": "",
#       "doi": "10.1371/journal.pone.0019981",
#       "downloadUrl": "https://doaj.org/article/8f7583edf8534c329d87cdd0dda7af14",
#       "fullText": "",
#       "id": 90060283,
#       "identifiers": {
#         "doi": "10.1371/journal.pone.0019981",
#         "oai": "oai:doaj.org/article:8f7583edf8534c329d87cdd0dda7af14"
#       },
#       "title": "A simple threshold rule is sufficient to explain sophisticated collective decision-making.",
#       "language": null,
#       "publishedDate": "2011-01-01T00:00:00+00:00",
#       "publisher": "'Public Library of Science (PLoS)'",
#       "references": [],
#       "sourceFulltextUrls": [
#         "https://doaj.org/toc/1932-6203"
#       ],
#       "updatedDate": "",
#       "yearPublished": "2011",
#       "links": [
#         {
#           "type": "display",
#           "url": "https://core.ac.uk/outputs/90060283"
#         }
#       ],
#       "abstract": "Decision-making animals can use slow-but-accurate strategies, such as making multiple comparisons, or opt for simpler, faster strategies to find a 'good enough' option. Social animals make collective decisions about many group behaviours including foraging and migration. The key to the collective choice lies with individual behaviour. We present a case study of a collective decision-making process (house-hunting ants, Temnothorax albipennis), in which a previously proposed decision strategy involved both quality-dependent hesitancy and direct comparisons of nests by scouts. An alternative possible decision strategy is that scouting ants use a very simple quality-dependent threshold rule to decide whether to recruit nest-mates to a new site or search for alternatives. We use analytical and simulation modelling to demonstrate that this simple rule is sufficient to explain empirical patterns from three studies of collective decision-making in ants, and can account parsimoniously for apparent comparison by individuals and apparent hesitancy (recruitment latency) effects, when available nests differ strongly in quality. This highlights the need to carefully design experiments to detect individual comparison. We present empirical data strongly suggesting that best-of-n comparison is not used by individual ants, although individual sequential comparisons are not ruled out. However, by using a simple threshold rule, decision-making groups are able to effectively compare options, without relying on any form of direct comparison of alternatives by individuals. This parsimonious mechanism could promote collective rationality in group decision-making",
#       "tags": [
#         "article",
#         "Medicine",
#         "R",
#         "Science",
#         "Q"
#       ],
#       "fulltextStatus": "disabled",
#       "subjects": [
#         "article"
#       ],
#       "oai": "oai:doaj.org/article:8f7583edf8534c329d87cdd0dda7af14",
#       "deleted": "ALLOWED",
#       "disabled": false,
#       "journals": [
#         {
#           "title": "PLoS ONE",
#           "identifiers": [
#             "issn:1932-6203",
#             "1932-6203"
#           ]
#         }
#       ],
#       "repositories": {
#         "id": "645",
#         "openDoarId": 0,
#         "name": "Directory of Open Access Journals",
#         "urlHomepage": null,
#         "uriJournals": null,
#         "physicalName": "noname",
#         "roarId": 0,
#         "baseId": 0,
#         "pdfStatus": null,
#         "nrUpdates": 0,
#         "lastUpdateTime": null
#       },
#       "repositoryDocument": {
#         "id": 90060283,
#         "depositedDate": null,
#         "publishedDate": "2011-01-01T00:00:00+00:00",
#         "updatedDate": "2022-11-09T14:23:07+00:00",
#         "acceptedDate": null,
#         "createdDate": "2017-10-13T17:10:42+01:00"
#       },
#       "urls": [
#         "https://doaj.org/article/8f7583edf8534c329d87cdd0dda7af14"
#       ],
#       "lastUpdate": "2022-11-09T14:23:07+00:00"
#     },
#     {
#       "acceptedDate": "",
#       "authors": [
#         {
#           "name": "Robinson, EJH"
#         },
#         {
#           "name": "Franks, NR"
#         },
#         {
#           "name": "Ellis, S"
#         },
#         {
#           "name": "Okuda, S"
#         },
#         {
#           "name": "Marshall, JAR"
#         }
#       ],
#       "contributors": [],
#       "createdDate": "2021-02-18T18:14:41+00:00",
#       "dataProvider": {
#         "id": 286,
#         "name": "Explore Bristol Research",
#         "url": "https://api.core.ac.uk/v3/data-providers/286",
#         "logo": "https://api.core.ac.uk/data-providers/286/logo"
#       },
#       "depositedDate": "",
#       "documentType": "",
#       "doi": "10.1371/journal.pone.0019981",
#       "downloadUrl": "https://doi.org/10.1371/journal.pone.0019981",
#       "fullText": "",
#       "id": 385699218,
#       "identifiers": {
#         "doi": "10.1371/journal.pone.0019981",
#         "oai": "oai:research-information.bris.ac.uk:openaire_cris_publications/0f3da01c-4f5c-43ee-af67-1358d550362c"
#       },
#       "title": "A simple threshold rule is sufficient to explain sophisticated collective decision-making",
#       "language": null,
#       "publishedDate": "2011-01-01T00:00:00+00:00",
#       "publisher": "'Public Library of Science (PLoS)'",
#       "references": [],
#       "sourceFulltextUrls": [],
#       "updatedDate": "",
#       "yearPublished": "2011",
#       "links": [
#         {
#           "type": "display",
#           "url": "https://core.ac.uk/outputs/385699218"
#         }
#       ],
#       "abstract": "",
#       "tags": [
#         "article"
#       ],
#       "fulltextStatus": "disabled",
#       "subjects": [
#         "article"
#       ],
#       "oai": "oai:research-information.bris.ac.uk:openaire_cris_publications/0f3da01c-4f5c-43ee-af67-1358d550362c",
#       "deleted": "DELETED",
#       "disabled": true,
#       "journals": null,
#       "repositories": {
#         "id": "286",
#         "openDoarId": 0,
#         "name": "Explore Bristol Research",
#         "urlHomepage": null,
#         "uriJournals": null,
#         "physicalName": "noname",
#         "roarId": 0,
#         "baseId": 0,
#         "pdfStatus": null,
#         "nrUpdates": 0,
#         "lastUpdateTime": null
#       },
#       "repositoryDocument": {
#         "id": 385699218,
#         "depositedDate": null,
#         "publishedDate": "2011-01-01T00:00:00+00:00",
#         "updatedDate": "2021-10-13T18:56:17+01:00",
#         "acceptedDate": null,
#         "createdDate": "2021-02-18T18:14:41+00:00"
#       },
#       "urls": [
#         "https://doi.org/10.1371/journal.pone.0019981",
#         "http://hdl.handle.net/1983/0f3da01c-4f5c-43ee-af67-1358d550362c",
#         "https://research-information.bris.ac.uk/en/publications/0f3da01c-4f5c-43ee-af67-1358d550362c"
#       ],
#       "lastUpdate": "2021-10-13T18:56:17+01:00"
#     }
#   ],
#   "tooks": null,
#   "esTook": null
# }

# %%
results.keys()
# Out:
# dict_keys(['totalHits', 'limit', 'offset', 'scrollId', 'results', 'tooks', 'esTook'])

# %%
results['results']
# Out:
# [{'acceptedDate': '',
#   'authors': [{'name': 'Robinson, Elva J. H.'},
#    {'name': 'Franks, Nigel R.'},
#    {'name': 'Ellis, Samuel'},
#    {'name': 'Okuda, Saki'},
#    {'name': 'Marshall, James A. R.'}],
#   'contributors': [],
#   'createdDate': '2012-07-08T14:39:10+01:00',
#   'dataProvider': {'id': 150,
#    'name': 'PubMed Central',
#    'url': 'https://api.core.ac.uk/v3/data-providers/150',
#    'logo': 'https://api.core.ac.uk/data-providers/150/logo'},
#   'depositedDate': '',
#   'documentType': 'research',
#   'doi': '10.1371/journal.pone.0019981',
#   'downloadUrl': 'https://core.ac.uk/download/8569611.pdf',
#   'fullText': '',
#   'id': 8569611,
#   'identifiers': {'doi': '10.1371/journal.pone.0019981',
#    'oai': 'oai:pubmedcentral.nih.gov:3101226'},
#   'title': 'A Simple Threshold Rule Is Sufficient to Explain Sophisticated Collective Decision-Making',
#   'language': {'code': 'en', 'name': 'English'},
#   'publishedDate': '2011-05-24T01:00:00+01:00',
#   'publisher': "'Public Library of Science (PLoS)'",
#   'references': [{'id': 27283274,
#     'title': '(in press) Experience-dependent flexibility in collective decision-making by househunting ants. Behav Ecol Sociobiol.',
#     'authors': [],
#     'date': None,
#     'doi': None,
#     'raw': 'Stroeymeyt N, Robinson EJH, Hogan PM, Marshall JAR, Giurfa M, et al. (in press) Experience-dependent flexibility in collective decision-making by househunting ants. Behav Ecol Sociobiol.',
#     'cites': None},
#    {'id': 27283240,
#     'title': 'A Comparative Bayes tactic for mate assessment and choice.',
#     'authors': [],
#     'date': '1996',
#     'doi': None,
#     'raw': 'Luttbeg B (1996) A Comparative Bayes tactic for mate assessment and choice. Behav Ecol 7: 451–460.',
#     'cites': None},
#    {'id': 27283251,
#     'title': 'A negative feedback signal that Is triggered by peril curbs honey bee recruitment.',
#     'authors': [],
#     'date': '2010',
#     'doi': None,
#     'raw': 'Nieh JC (2010) A negative feedback signal that Is triggered by peril curbs honey bee recruitment. Curr Biol 20: 310–315.',
#     'cites': None},
#    {'id': 27283216,
#     'title': 'A tunable algorithm for collective decision making.',
#     'authors': [],
#     'date': '2006',
#     'doi': None,
#     'raw': 'Pratt SC, Sumpter DJT (2006) A tunable algorithm for collective decision making. Proc Natl Acad Sci USA 103: 15906–15910.',
#     'cites': None},
#    {'id': 27283218,
#     'title': 'An agent-based model of collective nest site choice by the ant Temnothorax albipennis.',
#     'authors': [],
#     'date': '2005',
#     'doi': None,
#     'raw': 'Pratt SC, Sumpter DJT, Mallon EB, Franks NR (2005) An agent-based model of collective nest site choice by the ant Temnothorax albipennis. Anim Behav 70: 1023–1036.',
#     'cites': None},
#    {'id': 27283242,
#     'title': 'Ants estimate area using Buffon’s needle.',
#     'authors': [],
#     'date': '2000',
#     'doi': None,
#     'raw': 'Mallon EB, Franks NR (2000) Ants estimate area using Buffon’s needle. Proc R Soc Lond B 267: 765–770.',
#     'cites': None},
#    {'id': 27283261,
#     'title': 'Are bigger brains better?',
#     'authors': [],
#     'date': '2010',
#     'doi': None,
#     'raw': 'Chittka L, Niven J (2010) Are bigger brains better? Curr Biol 19: R995–R1008.',
#     'cites': None},
#    {'id': 27283222,
#     'title': 'Behavioral mechanisms of collective nest-site choice by the ant Temnothorax curvispinosus.',
#     'authors': [],
#     'date': '2005',
#     'doi': None,
#     'raw': 'Pratt SC (2005) Behavioral mechanisms of collective nest-site choice by the ant Temnothorax curvispinosus. Insect Soc 52: 383–392.',
#     'cites': None},
#    {'id': 27283221,
#     'title': 'Can ant colonies choose a far-and-away better nest over an in-the-way poor one?',
#     'authors': [],
#     'date': '2008',
#     'doi': None,
#     'raw': 'Franks NR, Hardcastle KA, Collins S, Smith FD, Sullivan KME, et al. (2008) Can ant colonies choose a far-and-away better nest over an in-the-way poor one? Anim Behav 76: 323–334.',
#     'cites': None},
#    {'id': 27283256,
#     'title': 'Chemical communication among workers of the fire ant Solenopsis saevissima (Fr. Smith) 1. The organization of mass-foraging.',
#     'authors': [],
#     'date': '1962',
#     'doi': None,
#     'raw': 'Wilson EO (1962) Chemical communication among workers of the fire ant Solenopsis saevissima (Fr. Smith) 1. The organization of mass-foraging. Anim Behav 10: 134–147.',
#     'cites': None},
#    {'id': 27283248,
#     'title': 'Collective decision making in honey bees: how colonies choose among nectar sources.',
#     'authors': [],
#     'date': '1991',
#     'doi': None,
#     'raw': 'Seeley TD, Camazine S, Sneyd J (1991) Collective decision making in honey bees: how colonies choose among nectar sources. Behav Ecol Sociobiol 28: 277–290.',
#     'cites': None},
#    {'id': 27283245,
#     'title': 'Collective decisions and cognition in bees.',
#     'authors': [],
#     'date': '1999',
#     'doi': None,
#     'raw': 'Visscher PK, Camazine S (1999) Collective decisions and cognition in bees. Nature 397: 400.',
#     'cites': None},
#    {'id': 27283254,
#     'title': 'Collective flexibility during mass recruitment in the ant Myrmica sabuleti (Hymenoptera: Formicidae).',
#     'authors': [],
#     'date': '1991',
#     'doi': None,
#     'raw': 'de Biseau JC, Deneubourg JL, Pasteels JM (1991) Collective flexibility during mass recruitment in the ant Myrmica sabuleti (Hymenoptera: Formicidae). Psyche 98: 323–336.',
#     'cites': None},
#    {'id': 27283253,
#     'title': 'Collective foraging in a stingless bee: dependence on food profitability and sequence of discovery.',
#     'authors': [],
#     'date': '2006',
#     'doi': None,
#     'raw': 'Schmidt VM, Schorkopf DLP, Hrncir M, Zucchi R, Barth FG (2006) Collective foraging in a stingless bee: dependence on food profitability and sequence of discovery. Anim Behav 72: 1309–1317.',
#     'cites': None},
#    {'id': 27283204,
#     'title': 'Collegial decision making based on social amplification leads to optimal group formation.',
#     'authors': [],
#     'date': '2006',
#     'doi': None,
#     'raw': 'Ame ´ JM, Halloy J, Rivault C, Detrain C, Deneubourg JL (2006) Collegial decision making based on social amplification leads to optimal group formation. Proc Natl Acad Sci USA 103: 5835–5840.',
#     'cites': None},
#    {'id': 27283264,
#     'title': 'Colony-level cognition.',
#     'authors': [],
#     'date': '2009',
#     'doi': None,
#     'raw': 'Marshall JAR, Franks NR (2009) Colony-level cognition. Curr Biol 19: R395–R396.',
#     'cites': None},
#    {'id': 27283268,
#     'title': 'Comparative evolution and its implications for mate choice.',
#     'authors': [],
#     'date': '2005',
#     'doi': None,
#     'raw': 'Bateson M, Healy SD (2005) Comparative evolution and its implications for mate choice. Trends Ecol Evol 20: 659–664.',
#     'cites': None},
#    {'id': 27283207,
#     'title': 'Conflicts of interest and the evolution of decision sharing.',
#     'authors': [],
#     'date': '2009',
#     'doi': None,
#     'raw': 'Conradt L, Roper TJ (2009) Conflicts of interest and the evolution of decision sharing. Philos Trans R Soc B-Biol Sci 364: 807–819.',
#     'cites': None},
#    {'id': 27283205,
#     'title': 'Consensus decision-making in animals.',
#     'authors': [],
#     'date': '2005',
#     'doi': None,
#     'raw': 'Conradt L, Roper TJ (2005) Consensus decision-making in animals. Trends Ecol Evol 20: 449–456.',
#     'cites': None},
#    {'id': 27283257,
#     'title': 'Consumer preference for a no-choice option.',
#     'authors': [],
#     'date': '1997',
#     'doi': None,
#     'raw': 'Dhar R (1997) Consumer preference for a no-choice option. J Consum Res 24: 215–231.',
#     'cites': None},
#    {'id': 27283208,
#     'title': 'Crossing scales, crossing disciplines: collective motion and collective action in the Global Commons.',
#     'authors': [],
#     'date': '2010',
#     'doi': None,
#     'raw': 'Levin SA (2010) Crossing scales, crossing disciplines: collective motion and collective action in the Global Commons. Philos Trans R Soc B-Biol Sci 365: 13–18.',
#     'cites': None},
#    {'id': 27283250,
#     'title': 'Dancing bees tune both duration and rate of waggle-run production in relation to nectar-source profitability.',
#     'authors': [],
#     'date': '2000',
#     'doi': None,
#     'raw': 'Seeley TD, Mikheyev AS, Pagano GJ (2000) Dancing bees tune both duration and rate of waggle-run production in relation to nectar-source profitability. J Comp Physiol A 186: 813–819.',
#     'cites': None},
#    {'id': 27283267,
#     'title': 'Decision making by small and large house-hunting ant colonies: one size fits all.',
#     'authors': [],
#     'date': '2006',
#     'doi': None,
#     'raw': 'Franks NR, Dornhaus A, Best CS, Jones EL (2006) Decision making by small and large house-hunting ant colonies: one size fits all. Anim Behav 72: 611–616.',
#     'cites': None},
#    {'id': 27283255,
#     'title': 'Distance effects on resource profitability and recruitment in the giant tropical ant, Paraponera clavata.',
#     'authors': [],
#     'date': '1992',
#     'doi': None,
#     'raw': 'Fewell JH, Harrison JF, Stiller TM, Breed MD (1992) Distance effects on resource profitability and recruitment in the giant tropical ant, Paraponera clavata. Oecologia 92: 542–547.',
#     'cites': None},
#    {'id': 27283220,
#     'title': 'Do ants make direct comparisons?',
#     'authors': [],
#     'date': '2009',
#     'doi': None,
#     'raw': 'Robinson EJH, Smith FD, Sullivan KME, Franks NR (2009) Do ants make direct comparisons? Proc R Soc Lond B 276: 2635–2641.',
#     'cites': None},
#    {'id': 27283200,
#     'title': 'Dornhaus A',
#     'authors': [],
#     'date': '2003',
#     'doi': None,
#     'raw': 'Chittka L, Dyer AG, Bock F, Dornhaus A (2003) Bees trade off foraging speed for accuracy. Nature 424: 388–388.',
#     'cites': None},
#    {'id': 27283258,
#     'title': 'Dynamic mate-searching tactic allows female satin bowerbirds Ptilonorhynchus violaceus to reduce searching.',
#     'authors': [],
#     'date': '2000',
#     'doi': None,
#     'raw': 'Uy JAC, Patricelli GL, Borgia G (2000) Dynamic mate-searching tactic allows female satin bowerbirds Ptilonorhynchus violaceus to reduce searching. Proc R Soc Lond B 267: 251–256.',
#     'cites': None},
#    {'id': 27283219,
#     'title': 'Emergence of group rationality from irrational individuals. Behav Ecol',
#     'authors': [],
#     'date': '2011',
#     'doi': None,
#     'raw': 'Sasaki T, Pratt SC (2011) Emergence of group rationality from irrational individuals. Behav Ecol in press.',
#     'cites': None},
#    {'id': 27283203,
#     'title': 'Female strategy during mate choice - threshold assessment.',
#     'authors': [],
#     'date': '1988',
#     'doi': None,
#     'raw': 'Moore AJ, Moore PJ (1988) Female strategy during mate choice - threshold assessment. Evolution 42: 387–391.',
#     'cites': None},
#    {'id': 27283238,
#     'title': 'Flexible task allocation and the organisation of work in ants.',
#     'authors': [],
#     'date': '2009',
#     'doi': None,
#     'raw': 'Robinson EJH, Feinerman O, Franks NR (2009) Flexible task allocation and the organisation of work in ants. Proc R Soc Lond B 276: 4373–4380.',
#     'cites': None},
#    {'id': 27283263,
#     'title': 'From Pride and Prejudice to Persuasion: Satisficing',
#     'authors': [],
#     'date': '1999',
#     'doi': None,
#     'raw': 'Todd PM, Miller GF (1999) From Pride and Prejudice to Persuasion: Satisficing in Mate Search. In: Gigerenzer G, Todd PM, eds. Simple Heuristics That Make Us Smart. Oxford: Oxford University Press. pp 287–308.',
#     'cites': None},
#    {'id': 27283271,
#     'title': 'Genetic structure and division of labor in honeybee societies.',
#     'authors': [],
#     'date': '1989',
#     'doi': None,
#     'raw': 'Calderone NW, Robinson GE, Page RE (1989) Genetic structure and division of labor in honeybee societies. Experientia 45: 765–767.',
#     'cites': None},
#    {'id': 27283243,
#     'title': 'Group decision making in nest-site selection among social insects.',
#     'authors': [],
#     'date': '2007',
#     'doi': None,
#     'raw': 'Visscher PK (2007) Group decision making in nest-site selection among social insects. Annual Review of Entomology 52: 255–275.',
#     'cites': None},
#    {'id': 27283209,
#     'title': 'Group decision making in swarms of honey bees.',
#     'authors': [],
#     'date': '1999',
#     'doi': None,
#     'raw': 'Seeley TD, Buhrman SC (1999) Group decision making in swarms of honey bees. Behav Ecol Sociobiol 45: 19–31.',
#     'cites': None},
#    {'id': 27283202,
#     'title': 'How western scrub-jays (Aphelocoma californica) select a nut: effects of the number of options, variation in nut size, and social competition among foragers.',
#     'authors': [],
#     'date': '1999',
#     'doi': None,
#     'raw': 'Langen TA (1999) How western scrub-jays (Aphelocoma californica) select a nut: effects of the number of options, variation in nut size, and social competition among foragers. Anim Cognition 2: 223–233.',
#     'cites': None},
#    {'id': 27283201,
#     'title': 'Impulsive bees forage better: the advantage of quick, sometimes inaccurate foraging decisions. Anim Behav 70: e1–5. A Threshold Rule for Collective Decisions PLoS',
#     'authors': [],
#     'date': '2007',
#     'doi': None,
#     'raw': 'Burns JG (2007) Impulsive bees forage better: the advantage of quick, sometimes inaccurate foraging decisions. Anim Behav 70: e1–5. A Threshold Rule for Collective Decisions PLoS ONE | www.plosone.org 10 May 2011 | Volume 6 | Issue 5 | e199817. Kacelnik A, Vasconcelos M, Monteiro T, Aw J (2011) Darwin’s ‘Tug-of-War’ vs. Starlings’ ‘Horse-Racing’: how adaptations for sequential encounters drive simultaneous choice. Behav Ecol Sociobiol 65: 547–558.',
#     'cites': None},
#    {'id': 27283214,
#     'title': 'Individual and collective decisionmaking during nest site selection by the ant Leptothorax albipennis.',
#     'authors': [],
#     'date': '2001',
#     'doi': None,
#     'raw': 'Mallon EB, Pratt SC, Franks NR (2001) Individual and collective decisionmaking during nest site selection by the ant Leptothorax albipennis. Behav Ecol Sociobiol 50: 352–359.',
#     'cites': None},
#    {'id': 27283278,
#     'title': 'Individual experience alone can generate lasting division of labor in ants.',
#     'authors': [],
#     'date': '2007',
#     'doi': None,
#     'raw': 'Ravary F, Lecoutey E, Kaminski G, Cha ˆline N, Jaisson P (2007) Individual experience alone can generate lasting division of labor in ants. Curr Biol 17: 1308–1312.',
#     'cites': None},
#    {'id': 27283262,
#     'title': 'Intransitivity of performance in honey bees: support for ‘comparative’ evaluation of foraging options.',
#     'authors': [],
#     'date': '1994',
#     'doi': None,
#     'raw': 'Shafir S (1994) Intransitivity of performance in honey bees: support for ‘comparative’ evaluation of foraging options. Anim Behav 48: 55–67.',
#     'cites': None},
#    {'id': 27283196,
#     'title': 'Is more choice always desirable? Evidence and arguments from leks, food selection, and environmental enrichment.',
#     'authors': [],
#     'date': '2005',
#     'doi': None,
#     'raw': 'Hutchinson JMC (2005) Is more choice always desirable? Evidence and arguments from leks, food selection, and environmental enrichment. Biol Rev 80: 73–92.',
#     'cites': None},
#    {'id': 27283235,
#     'title': 'IUCN Red List of Threatened Species.',
#     'authors': [],
#     'date': '2008',
#     'doi': None,
#     'raw': 'IUCN (2008) IUCN Red List of Threatened Species.',
#     'cites': None},
#    {'id': 27283277,
#     'title': 'Levels of behavioral organization and the evolution of division of labor.',
#     'authors': [],
#     'date': '2002',
#     'doi': None,
#     'raw': 'Page RE, Erber J (2002) Levels of behavioral organization and the evolution of division of labor. Naturwissenschaften 89: 91–106.',
#     'cites': None},
#    {'id': 27283244,
#     'title': 'Modeling and analysis of nest-site selection by honeybee swarms: the speed and accuracy trade-off.',
#     'authors': [],
#     'date': '2006',
#     'doi': None,
#     'raw': 'Passino KM, Seeley TD (2006) Modeling and analysis of nest-site selection by honeybee swarms: the speed and accuracy trade-off. Behav Ecol Sociobiol 59: 427–442.',
#     'cites': None},
#    {'id': 27283273,
#     'title': 'Models of division of labor in insect societies.',
#     'authors': [],
#     'date': '2001',
#     'doi': None,
#     'raw': 'Beshers SN, Fewell JH (2001) Models of division of labor in insect societies. Ann Rev Entomol 46: 413–430.',
#     'cites': None},
#    {'id': 27283272,
#     'title': 'Modulation of alarm pheromone perception in the honey bee - evidence for division of labor based on hormonally regulated response thresholds.',
#     'authors': [],
#     'date': '1987',
#     'doi': None,
#     'raw': 'Robinson GE (1987) Modulation of alarm pheromone perception in the honey bee - evidence for division of labor based on hormonally regulated response thresholds. J Comp Physiol A 160: 613–619.',
#     'cites': None},
#    {'id': 27283252,
#     'title': 'Modulation of trail laying in the ant Lasius niger (Hymenoptera, Formicidae) and its role in the collective selection of a food source.',
#     'authors': [],
#     'date': '1993',
#     'doi': None,
#     'raw': 'Beckers R, Deneubourg JL, Goss S (1993) Modulation of trail laying in the ant Lasius niger (Hymenoptera, Formicidae) and its role in the collective selection of a food source. J Insect Behav 6: 751–759.',
#     'cites': None},
#    {'id': 27283247,
#     'title': 'Nest-site selection in honeybees: how well do swarms implement the ‘‘best-of-N’’ decision rule?',
#     'authors': [],
#     'date': '2001',
#     'doi': None,
#     'raw': 'Seeley TD, Buhrman SC (2001) Nest-site selection in honeybees: how well do swarms implement the ‘‘best-of-N’’ decision rule? Behav Ecol Sociobiol 49: 416–427.',
#     'cites': None},
#    {'id': 27283215,
#     'title': 'Noise, cost and speedaccuracy trade-offs: decision-making in a decentralised system.',
#     'authors': [],
#     'date': '2005',
#     'doi': None,
#     'raw': 'Marshall JAR, Dornhaus A, Franks NR, Kovacs T (2005) Noise, cost and speedaccuracy trade-offs: decision-making in a decentralised system. J Roy Soc: Interface 3: 243–254.',
#     'cites': None},
#    {'id': 27283213,
#     'title': 'Not everything that counts can be counted: ants use multiple metrics for a single nest trait.',
#     'authors': [],
#     'date': '2006',
#     'doi': None,
#     'raw': 'Franks NR, Dornhaus A, Metherell B, Nelson T, Lanfear SA, et al. (2006) Not everything that counts can be counted: ants use multiple metrics for a single nest trait. Proc R Soc Lond B 273: 165–169.',
#     'cites': None},
#    {'id': 27283266,
#     'title': 'On optimal decision making in brains and social insect colonies.',
#     'authors': [],
#     'date': '2009',
#     'doi': None,
#     'raw': 'Marshall JAR, Bogacz R, Dornhaus A, Planque ´ R, Kovacs T, et al. (2009) On optimal decision making in brains and social insect colonies. J Roy Soc: Interface 6: 1065–1074.',
#     'cites': None},
#    {'id': 27283206,
#     'title': 'Optimization, conflict and nonoverlapping foraging ranges in ants.',
#     'authors': [],
#     'date': '2003',
#     'doi': None,
#     'raw': 'Adler FR, Gordon DM (2003) Optimization, conflict and nonoverlapping foraging ranges in ants. Am Nat 162: 529–543.',
#     'cites': None},
#    {'id': 27283224,
#     'title': 'Probability, Random Variables and Stochastic Processes.',
#     'authors': [],
#     'date': '2002',
#     'doi': None,
#     'raw': 'Papoulis A, Pillai SU (2002) Probability, Random Variables and Stochastic Processes. New York: McGraw Hill. 666 p.',
#     'cites': None},
#    {'id': 27283265,
#     'title': 'Quorum sensing during nest-site selection by honeybee swarms.',
#     'authors': [],
#     'date': '2004',
#     'doi': None,
#     'raw': 'Seeley TD, Visscher PK (2004) Quorum sensing during nest-site selection by honeybee swarms. Behav Ecol Sociobiol 56: 594–601.',
#     'cites': None},
#    {'id': 27283212,
#     'title': 'Quorum sensing, recruitment, and collective decision-making during colony emigration by the ant Leptothorax albipennis.',
#     'authors': [],
#     'date': '2002',
#     'doi': None,
#     'raw': 'Pratt SC, Mallon EB, Sumpter DJT, Franks NR (2002) Quorum sensing, recruitment, and collective decision-making during colony emigration by the ant Leptothorax albipennis. Behav Ecol Sociobiol 52: 117–127.',
#     'cites': None},
#    {'id': 27283237,
#     'title': 'Radio-tagging reveals the roles of corpulence, experience and social information in ant decision making.',
#     'authors': [],
#     'date': '2009',
#     'doi': None,
#     'raw': 'Robinson EJH, Richardson TO, Sendova-Franks AB, Feinerman O, Franks NR (2009) Radio-tagging reveals the roles of corpulence, experience and social information in ant decision making. Behav Ecol Sociobiol 63: 627–636.',
#     'cites': None},
#    {'id': 27283270,
#     'title': 'Rationality in collective decision-making by ant colonies.',
#     'authors': [],
#     'date': '2009',
#     'doi': None,
#     'raw': 'Edwards S, Pratt SC (2009) Rationality in collective decision-making by ant colonies. Proc R Soc Lond B 276: 3655–3661.',
#     'cites': None},
#    {'id': 27283276,
#     'title': 'Response threshold reinforcement and division of labour in insect societies.',
#     'authors': [],
#     'date': '1998',
#     'doi': None,
#     'raw': 'The ´raulaz G, Bonabeau E, Deneubourg JL (1998) Response threshold reinforcement and division of labour in insect societies. Proc R Soc Lond B 265: 327–332.',
#     'cites': None},
#    {'id': 27283236,
#     'title': 'Responsibility in the use of animals in bioscience research: Expectations of the major research council and charitable funding bodies.',
#     'authors': [],
#     'date': '2010',
#     'doi': None,
#     'raw': 'National-Centre-for-the-Replacement-Refinement-and-Reduction-of-Animalsin-Research (2010) Responsibility in the use of animals in bioscience research: Expectations of the major research council and charitable funding bodies. London: Tradewinds.',
#     'cites': None},
#    {'id': 27283197,
#     'title': 'Search theory and mate choice. I. Models of single-sex discrimination.',
#     'authors': [],
#     'date': '1990',
#     'doi': None,
#     'raw': 'Real L (1990) Search theory and mate choice. I. Models of single-sex discrimination. Am Nat 136: 376–405.',
#     'cites': None},
#    {'id': 27283198,
#     'title': 'Searching for a new home: decision making by dispersing brush mice.',
#     'authors': [],
#     'date': '2008',
#     'doi': None,
#     'raw': 'Mabry KE, Stamps JA (2008) Searching for a new home: decision making by dispersing brush mice. Am Nat 172: 625–634.',
#     'cites': None},
#    {'id': 27283246,
#     'title': 'Sensory coding of nest-site value in honeybee swarms.',
#     'authors': [],
#     'date': '2008',
#     'doi': None,
#     'raw': 'Seeley TD, Visscher PK (2008) Sensory coding of nest-site value in honeybee swarms. J Exp Biol 211: 3691–3697.',
#     'cites': None},
#    {'id': 27283260,
#     'title': 'Shell wars - assessment strategies and the timing of decisions in hermit crab shell fights.',
#     'authors': [],
#     'date': '1983',
#     'doi': None,
#     'raw': 'Dowds BM, Elwood RW (1983) Shell wars - assessment strategies and the timing of decisions in hermit crab shell fights. Behaviour 85: 1–24.',
#     'cites': None},
#    {'id': 27283211,
#     'title': 'Social organization of nest emigration in Leptothorax (Hym.',
#     'authors': [],
#     'date': '1978',
#     'doi': None,
#     'raw': 'Mo ¨glich M (1978) Social organization of nest emigration in Leptothorax (Hym. Form.). Insect Soc 25: 205–225.',
#     'cites': None},
#    {'id': 27283210,
#     'title': 'Strategies for choosing between alternatives with different attributes: exemplified by househunting ants.',
#     'authors': [],
#     'date': '2003',
#     'doi': None,
#     'raw': 'Franks NR, Mallon EB, Bray HE, Hamilton MJ, Mischler TC (2003) Strategies for choosing between alternatives with different attributes: exemplified by househunting ants. Anim Behav 65: 215–223.',
#     'cites': None},
#    {'id': 27283249,
#     'title': 'Tactics of dance choice in honey bees: do foragers compare dances?',
#     'authors': [],
#     'date': '1992',
#     'doi': None,
#     'raw': 'Seeley TD, Towne WF (1992) Tactics of dance choice in honey bees: do foragers compare dances? Behav Ecol Sociobiol 30: 59–69.',
#     'cites': None},
#    {'id': 27283279,
#     'title': 'Teaching in tandem-running ants. Nature 439: 153. A Threshold Rule for Collective Decisions',
#     'authors': [],
#     'date': '2006',
#     'doi': None,
#     'raw': 'Franks NR, Richardson TO (2006) Teaching in tandem-running ants. Nature 439: 153. A Threshold Rule for Collective Decisions PLoS ONE | www.plosone.org 11 May 2011 | Volume 6 | Issue 5 | e19981',
#     'cites': None},
#    {'id': 27283275,
#     'title': 'The effect of prior experience on nest site evaluation by the ant Temnothorax curvispinosus.',
#     'authors': [],
#     'date': '2008',
#     'doi': None,
#     'raw': 'Healey CIM, Pratt SC (2008) The effect of prior experience on nest site evaluation by the ant Temnothorax curvispinosus. Anim Behav 76: 893–899.',
#     'cites': None},
#    {'id': 27283239,
#     'title': 'The evolution of color vision in insects.',
#     'authors': [],
#     'date': '2001',
#     'doi': None,
#     'raw': 'Briscoe AD, Chittka L (2001) The evolution of color vision in insects. Ann Rev Entomol 46: 471–510.',
#     'cites': None},
#    {'id': 27283269,
#     'title': 'The robustness of the asymmetrically dominated effect: Buying frames, phantom alternatives, and in-store purchases.',
#     'authors': [],
#     'date': '1999',
#     'doi': None,
#     'raw': 'Doyle JR, O’Connor DJ, Reynolds GM, Bottomley PA (1999) The robustness of the asymmetrically dominated effect: Buying frames, phantom alternatives, and in-store purchases. Psychol Mark 16: 225–243.',
#     'cites': None},
#    {'id': 27283241,
#     'title': 'The Secretary Problem and Its Extensions: A Review.',
#     'authors': [],
#     'date': '1983',
#     'doi': None,
#     'raw': 'Freeman PR (1983) The Secretary Problem and Its Extensions: A Review. Int Stat Rev 51: 189–206.',
#     'cites': None},
#    {'id': 27283217,
#     'title': 'Weighted waiting in collective decision-making.',
#     'authors': [],
#     'date': '2007',
#     'doi': None,
#     'raw': 'Planque ´ R, Dornhaus A, Franks NR, Kovacs T, Marshall JAR (2007) Weighted waiting in collective decision-making. Behav Ecol Sociobiol 61: 347–356.',
#     'cites': None},
#    {'id': 27283199,
#     'title': 'When good enough is best.',
#     'authors': [],
#     'date': '2006',
#     'doi': None,
#     'raw': 'Kay LM, Beshel J, Martin C (2006) When good enough is best. Neuron 51: 277–278.',
#     'cites': None},
#    {'id': 27283259,
#     'title': 'Why do males of the dance fly Empis borealis refuse to mate? The importance of female age and size.',
#     'authors': [],
#     'date': '1989',
#     'doi': None,
#     'raw': 'Svensson BG, Petersson E, Forsgren E (1989) Why do males of the dance fly Empis borealis refuse to mate? The importance of female age and size. J Insect Behav 2: 387–395.',
#     'cites': None}],
#   'sourceFulltextUrls': ['http://www.pubmedcentral.nih.gov/articlerender.fcgi?artid=3101226'],
#   'updatedDate': '',
#   'yearPublished': '2011',
#   'links': [{'type': 'download',
#     'url': 'https://core.ac.uk/download/8569611.pdf'},
#    {'type': 'reader', 'url': 'https://core.ac.uk/reader/8569611'},
#    {'type': 'thumbnail_m', 'url': 'https://core.ac.uk/image/8569611/medium'},
#    {'type': 'thumbnail_l', 'url': 'https://core.ac.uk/image/8569611/large'},
#    {'type': 'display', 'url': 'https://core.ac.uk/outputs/8569611'}],
#   'abstract': 'Decision-making animals can use slow-but-accurate strategies, such as making multiple comparisons, or opt for simpler, faster strategies to find a ‘good enough’ option. Social animals make collective decisions about many group behaviours including foraging and migration. The key to the collective choice lies with individual behaviour. We present a case study of a collective decision-making process (house-hunting ants, Temnothorax albipennis), in which a previously proposed decision strategy involved both quality-dependent hesitancy and direct comparisons of nests by scouts. An alternative possible decision strategy is that scouting ants use a very simple quality-dependent threshold rule to decide whether to recruit nest-mates to a new site or search for alternatives. We use analytical and simulation modelling to demonstrate that this simple rule is sufficient to explain empirical patterns from three studies of collective decision-making in ants, and can account parsimoniously for apparent comparison by individuals and apparent hesitancy (recruitment latency) effects, when available nests differ strongly in quality. This highlights the need to carefully design experiments to detect individual comparison. We present empirical data strongly suggesting that best-of-n comparison is not used by individual ants, although individual sequential comparisons are not ruled out. However, by using a simple threshold rule, decision-making groups are able to effectively compare options, without relying on any form of direct comparison of alternatives by individuals. This parsimonious mechanism could promote collective rationality in group decision-making',
#   'tags': ['Text', 'Research Article'],
#   'fulltextStatus': 'disabled',
#   'subjects': ['Text'],
#   'oai': 'oai:pubmedcentral.nih.gov:3101226',
#   'deleted': 'DELETED',
#   'disabled': True,
#   'journals': None,
#   'repositories': {'id': '150',
#    'openDoarId': 0,
#    'name': 'PubMed Central',
#    'urlHomepage': None,
#    'uriJournals': None,
#    'physicalName': 'noname',
#    'roarId': 0,
#    'baseId': 0,
#    'pdfStatus': None,
#    'nrUpdates': 0,
#    'lastUpdateTime': None},
#   'repositoryDocument': {'id': 8569611,
#    'depositedDate': None,
#    'publishedDate': '2011-05-24T01:00:00+01:00',
#    'updatedDate': '2019-12-02T21:52:26+00:00',
#    'acceptedDate': None,
#    'createdDate': '2012-07-08T14:39:10+01:00'},
#   'urls': ['http://dx.doi.org/10.1371/journal.pone.0019981'],
#   'lastUpdate': '2019-12-02T21:52:26+00:00'},
#  {'acceptedDate': '',
#   'authors': [{'name': 'Robinson, E.J.H.'},
#    {'name': 'Franks, N.R.'},
#    {'name': 'Ellis, S.'},
#    {'name': 'Okuda, S.'},
#    {'name': 'Marshall, J.A.R.'}],
#   'contributors': [],
#   'createdDate': '2016-08-02T14:39:49+01:00',
#   'dataProvider': {'id': 140,
#    'name': 'White Rose Research Online',
#    'url': 'https://api.core.ac.uk/v3/data-providers/140',
#    'logo': 'https://api.core.ac.uk/data-providers/140/logo'},
#   'depositedDate': '2011-05-24T00:00:00+01:00',
#   'documentType': 'research',
#   'doi': '10.1371/journal.pone.0019981',
#   'downloadUrl': 'https://core.ac.uk/download/42624856.pdf',
#   'fullText': 'A Simple Threshold Rule Is Sufficient to ExplainSophisticated Collective Decision-MakingElva J. H. Robinson1,2*, Nigel R. Franks1, Samuel Ellis1, Saki Okuda1, James A. R. Marshall31 School of Biological Sciences, University of Bristol, Bristol, United Kingdom, 2 York Centre for Complex Systems Analysis, Department of Biology, University of York, York,United Kingdom, 3Department of Computer Science and Kroto Research Institute, University of Sheffield, Sheffield, United KingdomAbstractDecision-making animals can use slow-but-accurate strategies, such as making multiple comparisons, or opt for simpler,faster strategies to find a ‘good enough’ option. Social animals make collective decisions about many group behavioursincluding foraging and migration. The key to the collective choice lies with individual behaviour. We present a case study ofa collective decision-making process (house-hunting ants, Temnothorax albipennis), in which a previously proposed decisionstrategy involved both quality-dependent hesitancy and direct comparisons of nests by scouts. An alternative possibledecision strategy is that scouting ants use a very simple quality-dependent threshold rule to decide whether to recruit nest-mates to a new site or search for alternatives. We use analytical and simulation modelling to demonstrate that this simplerule is sufficient to explain empirical patterns from three studies of collective decision-making in ants, and can accountparsimoniously for apparent comparison by individuals and apparent hesitancy (recruitment latency) effects, when availablenests differ strongly in quality. This highlights the need to carefully design experiments to detect individual comparison. Wepresent empirical data strongly suggesting that best-of-n comparison is not used by individual ants, although individualsequential comparisons are not ruled out. However, by using a simple threshold rule, decision-making groups are able toeffectively compare options, without relying on any form of direct comparison of alternatives by individuals. Thisparsimonious mechanism could promote collective rationality in group decision-making.Citation: Robinson EJH, Franks NR, Ellis S, Okuda S, Marshall JAR (2011) A Simple Threshold Rule Is Sufficient to Explain Sophisticated Collective Decision-Making. PLoS ONE 6(5): e19981. doi:10.1371/journal.pone.0019981Editor: Frederick R. Adler, University of Utah, United States of AmericaReceived December 6, 2010; Accepted April 22, 2011; Published May 24, 2011Copyright: \x02 2011 Robinson et al. This is an open-access article distributed under the terms of the Creative Commons Attribution License, which permitsunrestricted use, distribution, and reproduction in any medium, provided the original author and source are credited.Funding: EJHR and NRF acknowledge support from EPSRC grant EP/D076226/1 http://www.epsrc.ac.uk/Pages/default.aspx. SO was supported by a NuffieldUndergraduate Bursary http://users.ecs.soton.ac.uk/saw/nuffield.html; SE was supported by a University of Bristol Summer Studentship http://www.bristol.ac.uk/biology. The funders had no role in study design, data collection and analysis, decision to publish, or preparation of the manuscript.Competing Interests: Author James Marshall is an Academic Editor for PLoS.* E-mail: Elva.Robinson@yccsa.orgIntroductionAnimals need to make choices between multiple available op-tions at many stages in their life histories, such as during mateselection, foraging, or when deciding where to shelter or to build anest. The fitness benefits of choosing the best option mean thatdecision-making strategies will be subject to natural selection. Mul-tiple comparison or ‘best of n’ strategies perform most accurately,and are likely to be optimal when searching and sampling costs arelow, e.g. on a lek [1,2] and when long-term fitness implications ofthe decision are high, e.g. in home range selection [3]. In othersituations, e.g. during foraging, there can be substantial  ...
#   'id': 42624856,
#   'identifiers': {'doi': '10.1371/journal.pone.0019981',
#    'oai': 'oai:eprints.whiterose.ac.uk:99644'},
#   'title': 'A Simple Threshold Rule Is Sufficient to Explain Sophisticated Collective Decision-Making',
#   'language': None,
#   'publishedDate': '2011-05-24T01:00:00+01:00',
#   'publisher': "'Public Library of Science (PLoS)'",
#   'references': [],
#   'sourceFulltextUrls': ['https://eprints.whiterose.ac.uk/99644/1/A%20simple%20threshold%20rule%20is%20sufficient%20to%20explain%20sophisticated%20collective%20decision-making.pdf'],
#   'updatedDate': '',
#   'yearPublished': '2011',
#   'links': [{'type': 'download',
#     'url': 'https://core.ac.uk/download/42624856.pdf'},
#    {'type': 'reader', 'url': 'https://core.ac.uk/reader/42624856'},
#    {'type': 'thumbnail_m', 'url': 'https://core.ac.uk/image/42624856/medium'},
#    {'type': 'thumbnail_l', 'url': 'https://core.ac.uk/image/42624856/large'},
#    {'type': 'display', 'url': 'https://core.ac.uk/outputs/42624856'}],
#   'abstract': 'Decision-making animals can use slow-but-accurate strategies, such as making multiple comparisons, or opt for simpler, faster strategies to find a ‘good enough’ option. Social animals make collective decisions about many group behaviours including foraging and migration. The key to the collective choice lies with individual behaviour. We present a case study of a collective decision-making process (house-hunting ants, Temnothorax albipennis), in which a previously proposed decision strategy involved both quality-dependent hesitancy and direct comparisons of nests by scouts. An alternative possible decision strategy is that scouting ants use a very simple quality-dependent threshold rule to decide whether to recruit nest-mates to a new site or search for alternatives. We use analytical and simulation modelling to demonstrate that this simple rule is sufficient to explain empirical patterns from three studies of collective decision-making in ants, and can account parsimoniously for apparent comparison by individuals and apparent hesitancy (recruitment latency) effects, when available nests differ strongly in quality. This highlights the need to carefully design experiments to detect individual comparison. We present empirical data strongly suggesting that best-of-n comparison is not used by individual ants, although individual sequential comparisons are not ruled out. However, by using a simple threshold rule, decision-making groups are able to effectively compare options, without relying on any form of direct comparison of alternatives by individuals. This parsimonious mechanism could promote collective rationality in group decision-making',
#   'tags': [],
#   'fulltextStatus': 'disabled',
#   'subjects': [],
#   'oai': 'oai:eprints.whiterose.ac.uk:99644',
#   'deleted': 'ALLOWED',
#   'disabled': False,
#   'journals': None,
#   'repositories': {'id': '140',
#    'openDoarId': 0,
#    'name': 'White Rose Research Online',
#    'urlHomepage': None,
#    'uriJournals': None,
#    'physicalName': 'noname',
#    'roarId': 0,
#    'baseId': 0,
#    'pdfStatus': None,
#    'nrUpdates': 0,
#    'lastUpdateTime': None},
#   'repositoryDocument': {'id': 42624856,
#    'depositedDate': '2011-05-24T00:00:00+01:00',
#    'publishedDate': '2011-05-24T01:00:00+01:00',
#    'updatedDate': '2023-06-15T08:09:11+01:00',
#    'acceptedDate': None,
#    'createdDate': '2016-08-02T14:39:49+01:00'},
#   'urls': ['https://eprints.whiterose.ac.uk/99644/1/A%20simple%20threshold%20rule%20is%20sufficient%20to%20explain%20sophisticated%20collective%20decision-making.pdf'],
#   'lastUpdate': '2023-06-15T08:09:11+01:00'},
#  {'acceptedDate': '2011-05-24T00:00:00+01:00',
#   'authors': [{'name': 'Robinson, Elva J. H.'},
#    {'name': 'Franks, Nigel R.'},
#    {'name': 'Ellis, Samuel'},
#    {'name': 'Okuda, Saki'},
#    {'name': 'Marshall, James A. R.'}],
#   'contributors': [],
#   'createdDate': '2012-06-28T04:00:54+01:00',
#   'dataProvider': {'id': 140,
#    'name': 'White Rose Research Online',
#    'url': 'https://api.core.ac.uk/v3/data-providers/140',
#    'logo': 'https://api.core.ac.uk/data-providers/140/logo'},
#   'depositedDate': '2011-05-24T00:00:00+01:00',
#   'documentType': 'unknown',
#   'doi': '10.1371/journal.pone.0019981',
#   'downloadUrl': 'https://core.ac.uk/download/5225915.pdf',
#   'fullText': 'This is a repository copy of A Simple Threshold Rule Is Sufficient to Explain Sophisticated Collective Decision-Making.White Rose Research Online URL for this paper:http://eprints.whiterose.ac.uk/63768/Version: Published VersionArticle:Robinson, Elva J. H. orcid.org/0000-0003-4914-9327, Franks, Nigel R., Ellis, Samuel et al.(2 more authors) (2011) A Simple Threshold Rule Is Sufficient to Explain Sophisticated Collective Decision-Making. PLoS ONE. e19981. pp. 1-11. ISSN 1932-6203 https://doi.org/10.1371/journal.pone.0019981eprints@whiterose.ac.ukhttps://eprints.whiterose.ac.uk/Reuse Items deposited in White Rose Research Online are protected by copyright, with all rights reserved unless indicated otherwise. They may be downloaded and/or printed for private study, or other acts as permitted by national copyright laws. The publisher or other rights holders may allow further reproduction and re-use of the full text version. This is indicated by the licence information on the White Rose Research Online record for the item. Takedown If you consider content in White Rose Research Online to be in breach of UK law, please notify us by emailing eprints@whiterose.ac.uk including the URL of the record and the reason for the withdrawal request. A Simple Threshold Rule Is Sufficient to ExplainSophisticated Collective Decision-MakingElva J. H. Robinson1,2*, Nigel R. Franks1, Samuel Ellis1, Saki Okuda1, James A. R. Marshall31 School of Biological Sciences, University of Bristol, Bristol, United Kingdom, 2 York Centre for Complex Systems Analysis, Department of Biology, University of York, York,United Kingdom, 3Department of Computer Science and Kroto Research Institute, University of Sheffield, Sheffield, United KingdomAbstractDecision-making animals can use slow-but-accurate strategies, such as making multiple comparisons, or opt for simpler,faster strategies to find a ‘good enough’ option. Social animals make collective decisions about many group behavioursincluding foraging and migration. The key to the collective choice lies with individual behaviour. We present a case study ofa collective decision-making process (house-hunting ants, Temnothorax albipennis), in which a previously proposed decisionstrategy involved both quality-dependent hesitancy and direct comparisons of nests by scouts. An alternative possibledecision strategy is that scouting ants use a very simple quality-dependent threshold rule to decide whether to recruit nest-mates to a new site or search for alternatives. We use analytical and simulation modelling to demonstrate that this simplerule is sufficient to explain empirical patterns from three studies of collective decision-making in ants, and can accountparsimoniously for apparent comparison by individuals and apparent hesitancy (recruitment latency) effects, when availablenests differ strongly in quality. This highlights the need to carefully design experiments to detect individual comparison. Wepresent empirical data strongly suggesting that best-of-n comparison is not used by individual ants, although individualsequential comparisons are not ruled out. However, by using a simple threshold rule, decision-making groups are able toeffectively compare options, without relying on any form of direct comparison of alternatives by individuals. Thisparsimonious mechanism could promote collective rationality in group decision-making.Citation: Robinson EJH, Franks NR, Ellis S, Okuda S, Marshall JAR (2011) A Simple Threshold Rule Is Sufficient to Explain Sophisticated Collective Decision-Making. PLoS ONE 6(5): e19981. doi:10.1371/journal.pone.0019981Editor: Frederick R. Adler, University of Utah, United States of AmericaReceived December 6, 2010; Accepted April 22, 2011; Published May 24, 2011Copyright: \x02 2011 Robinson et al. This is an open-access article distributed under the terms of the Creative Commons Attribution License, which permitsunrestricted use, distribution, and reproduction in any medium, provid ...
#   'id': 5225915,
#   'identifiers': {'doi': '10.1371/journal.pone.0019981',
#    'oai': 'oai:eprints.whiterose.ac.uk:63768'},
#   'title': 'A Simple Threshold Rule Is Sufficient to Explain Sophisticated Collective Decision-Making',
#   'language': None,
#   'publishedDate': '2011-05-24T00:00:00+01:00',
#   'publisher': "'Public Library of Science (PLoS)'",
#   'references': [],
#   'sourceFulltextUrls': ['https://eprints.whiterose.ac.uk/63768/1/Robinson2011ThresholdModel.pdf'],
#   'updatedDate': '',
#   'yearPublished': '2011',
#   'links': [{'type': 'download',
#     'url': 'https://core.ac.uk/download/5225915.pdf'},
#    {'type': 'reader', 'url': 'https://core.ac.uk/reader/5225915'},
#    {'type': 'thumbnail_m', 'url': 'https://core.ac.uk/image/5225915/medium'},
#    {'type': 'thumbnail_l', 'url': 'https://core.ac.uk/image/5225915/large'},
#    {'type': 'display', 'url': 'https://core.ac.uk/outputs/5225915'}],
#   'abstract': "Decision-making animals can use slow-but-accurate strategies, such as making multiple comparisons, or opt for simpler, faster strategies to find a 'good enough' option. Social animals make collective decisions about many group behaviours including foraging and migration. The key to the collective choice lies with individual behaviour. We present a case study of a collective decision-making process (house-hunting ants, Temnothorax albipennis), in which a previously proposed decision strategy involved both quality-dependent hesitancy and direct comparisons of nests by scouts. An alternative possible decision strategy is that scouting ants use a very simple quality-dependent threshold rule to decide whether to recruit nest-mates to a new site or search for alternatives. We use analytical and simulation modelling to demonstrate that this simple rule is sufficient to explain empirical patterns from three studies of collective decision-making in ants, and can account parsimoniously for apparent comparison by individuals and apparent hesitancy (recruitment latency) effects, when available nests differ strongly in quality. This highlights the need to carefully design experiments to detect individual comparison. We present empirical data strongly suggesting that best-of-n comparison is not used by individual ants, although individual sequential comparisons are not ruled out. However, by using a simple threshold rule, decision-making groups are able to effectively compare options, without relying on any form of direct comparison of alternatives by individuals. This parsimonious mechanism could promote collective rationality in group decision-making",
#   'tags': ['1100', '1300', '2700', '1100', '1300', '2700'],
#   'fulltextStatus': 'disabled',
#   'subjects': ['1100', '1300', '2700'],
#   'oai': 'oai:eprints.whiterose.ac.uk:63768',
#   'deleted': 'ALLOWED',
#   'disabled': False,
#   'journals': None,
#   'repositories': {'id': '140',
#    'openDoarId': 0,
#    'name': 'White Rose Research Online',
#    'urlHomepage': None,
#    'uriJournals': None,
#    'physicalName': 'noname',
#    'roarId': 0,
#    'baseId': 0,
#    'pdfStatus': None,
#    'nrUpdates': 0,
#    'lastUpdateTime': None},
#   'repositoryDocument': {'id': 5225915,
#    'depositedDate': '2011-05-24T00:00:00+01:00',
#    'publishedDate': '2011-05-24T00:00:00+01:00',
#    'updatedDate': '2023-06-15T08:06:09+01:00',
#    'acceptedDate': '2011-05-24T00:00:00+01:00',
#    'createdDate': '2012-06-28T04:00:54+01:00'},
#   'urls': ['https://eprints.whiterose.ac.uk/63768/1/Robinson2011ThresholdModel.pdf'],
#   'lastUpdate': '2023-06-15T08:06:09+01:00'},
#  {'acceptedDate': '',
#   'authors': [{'name': 'Robinson Elva J. H.'},
#    {'name': 'Franks Nigel R.'},
#    {'name': 'Ellis Samuel'},
#    {'name': 'Okuda Saki'},
#    {'name': 'Marshall James A. R.'}],
#   'contributors': [],
#   'createdDate': '2019-06-05T11:44:39+01:00',
#   'dataProvider': {'id': 4785,
#    'name': 'Public Library of Science (PLOS)',
#    'url': 'https://api.core.ac.uk/v3/data-providers/4785',
#    'logo': 'https://api.core.ac.uk/data-providers/4785/logo'},
#   'depositedDate': '',
#   'documentType': '',
#   'doi': '10.1371/journal.pone.0019981',
#   'downloadUrl': 'http://doi.org/10.1371/journal.pone.0019981',
#   'fullText': '',
#   'id': 203720814,
#   'identifiers': {'doi': '10.1371/journal.pone.0019981', 'oai': None},
#   'title': 'A Simple Threshold Rule Is Sufficient to Explain Sophisticated Collective Decision-Making',
#   'language': None,
#   'publishedDate': '',
#   'publisher': 'Public Library of Science',
#   'references': [],
#   'sourceFulltextUrls': ['file:///data/remote/core/dit/data/public_library_of_science/pdf/086/ZnRwOi8vZnRwLm5jYmkubmxtLm5paC5nb3YvcHViL3BtYy9vYV9wYWNrYWdlL2Q4Lzk0L1BNQzMxMDEyMjYudGFyLmd6.pdf'],
#   'updatedDate': '',
#   'yearPublished': '2011',
#   'links': [{'type': 'display',
#     'url': 'https://core.ac.uk/outputs/203720814'}],
#   'abstract': '',
#   'tags': ['Journal'],
#   'fulltextStatus': 'disabled',
#   'subjects': ['Journal'],
#   'oai': '',
#   'deleted': 'ALLOWED',
#   'disabled': False,
#   'journals': None,
#   'repositories': {'id': '4785',
#    'openDoarId': 0,
#    'name': 'Public Library of Science (PLOS)',
#    'urlHomepage': None,
#    'uriJournals': None,
#    'physicalName': 'noname',
#    'roarId': 0,
#    'pdfStatus': None,
#    'nrUpdates': 0,
#    'lastUpdateTime': None},
#   'repositoryDocument': {'id': 203720814,
#    'depositedDate': None,
#    'publishedDate': None,
#    'updatedDate': '2019-06-05T11:44:39+01:00',
#    'acceptedDate': None,
#    'createdDate': '2019-06-05T11:44:39+01:00'},
#   'urls': ['http://doi.org/10.1371/journal.pone.0019981'],
#   'lastUpdate': '2019-06-05T11:44:39+01:00'},
#  {'acceptedDate': '2011-05-24T00:00:00+01:00',
#   'authors': [{'name': 'Elva J. H. Robinson'},
#    {'name': 'Nigel R. Franks'},
#    {'name': 'Samuel Ellis'},
#    {'name': 'Saki Okuda'},
#    {'name': 'James A. R. Marshall'}],
#   'contributors': [],
#   'createdDate': '2019-06-05T20:28:28+01:00',
#   'dataProvider': {'id': 4786,
#    'name': 'MUCC (Crossref)',
#    'url': 'https://api.core.ac.uk/v3/data-providers/4786',
#    'logo': 'https://api.core.ac.uk/data-providers/4786/logo'},
#   'depositedDate': '2011-05-24T00:00:00+01:00',
#   'documentType': '',
#   'doi': '10.1371/journal.pone.0019981',
#   'downloadUrl': 'http://doi.org/10.1371/journal.pone.0019981',
#   'fullText': '',
#   'id': 209066385,
#   'identifiers': {'doi': '10.1371/journal.pone.0019981', 'oai': None},
#   'title': 'A Simple Threshold Rule Is Sufficient to Explain Sophisticated Collective Decision-Making',
#   'language': None,
#   'publishedDate': '',
#   'publisher': 'Public Library of Science (PLoS)',
#   'references': [],
#   'sourceFulltextUrls': [],
#   'updatedDate': '',
#   'yearPublished': '2011',
#   'links': [{'type': 'download',
#     'url': 'http://doi.org/10.1371/journal.pone.0019981'},
#    {'type': 'display', 'url': 'https://core.ac.uk/outputs/209066385'}],
#   'abstract': '',
#   'tags': ['journal-article'],
#   'fulltextStatus': 'disabled',
#   'subjects': ['journal-article'],
#   'oai': '',
#   'deleted': 'ALLOWED',
#   'disabled': False,
#   'journals': None,
#   'repositories': {'id': '4786',
#    'openDoarId': 0,
#    'name': 'MUCC (Crossref)',
#    'urlHomepage': None,
#    'uriJournals': None,
#    'physicalName': 'noname',
#    'roarId': 0,
#    'baseId': 0,
#    'pdfStatus': None,
#    'nrUpdates': 0,
#    'lastUpdateTime': None},
#   'repositoryDocument': {'id': 209066385,
#    'depositedDate': '2011-05-24T00:00:00+01:00',
#    'publishedDate': None,
#    'updatedDate': '2019-06-05T20:28:28+01:00',
#    'acceptedDate': '2011-05-24T00:00:00+01:00',
#    'createdDate': '2019-06-05T20:28:28+01:00'},
#   'urls': ['http://doi.org/10.1371/journal.pone.0019981'],
#   'lastUpdate': '2019-06-05T20:28:28+01:00'},
#  {'acceptedDate': '',
#   'authors': [{'name': 'Robinson, EJH'},
#    {'name': 'Franks, NR'},
#    {'name': 'Ellis, S'},
#    {'name': 'Okuda, S'},
#    {'name': 'Marshall, JAR'}],
#   'contributors': [],
#   'createdDate': '2019-08-10T10:54:01+01:00',
#   'dataProvider': {'id': 286,
#    'name': 'Explore Bristol Research',
#    'url': 'https://api.core.ac.uk/v3/data-providers/286',
#    'logo': 'https://api.core.ac.uk/data-providers/286/logo'},
#   'depositedDate': '',
#   'documentType': '',
#   'doi': '10.1371/journal.pone.0019981',
#   'downloadUrl': 'https://doi.org/10.1371/journal.pone.0019981',
#   'fullText': '',
#   'id': 223321058,
#   'identifiers': {'doi': '10.1371/journal.pone.0019981',
#    'oai': 'oai:research-information.bris.ac.uk:publications/0f3da01c-4f5c-43ee-af67-1358d550362c'},
#   'title': 'A simple threshold rule is sufficient to explain sophisticated collective decision-making',
#   'language': None,
#   'publishedDate': '2011-01-01T00:00:00+00:00',
#   'publisher': "'Public Library of Science (PLoS)'",
#   'references': [],
#   'sourceFulltextUrls': [],
#   'updatedDate': '',
#   'yearPublished': '2011',
#   'links': [{'type': 'display',
#     'url': 'https://core.ac.uk/outputs/223321058'}],
#   'abstract': '',
#   'tags': ['article'],
#   'fulltextStatus': 'disabled',
#   'subjects': ['article'],
#   'oai': 'oai:research-information.bris.ac.uk:publications/0f3da01c-4f5c-43ee-af67-1358d550362c',
#   'deleted': 'ALLOWED',
#   'disabled': False,
#   'journals': None,
#   'repositories': {'id': '286',
#    'openDoarId': 0,
#    'name': 'Explore Bristol Research',
#    'urlHomepage': None,
#    'uriJournals': None,
#    'physicalName': 'noname',
#    'roarId': 0,
#    'baseId': 0,
#    'pdfStatus': None,
#    'nrUpdates': 0,
#    'lastUpdateTime': None},
#   'repositoryDocument': {'id': 223321058,
#    'depositedDate': None,
#    'publishedDate': '2011-01-01T00:00:00+00:00',
#    'updatedDate': '2022-12-14T02:51:01+00:00',
#    'acceptedDate': None,
#    'createdDate': '2019-08-10T10:54:01+01:00'},
#   'urls': ['https://doi.org/10.1371/journal.pone.0019981',
#    'https://research-information.bris.ac.uk/en/publications/0f3da01c-4f5c-43ee-af67-1358d550362c',
#    'https://hdl.handle.net/1983/0f3da01c-4f5c-43ee-af67-1358d550362c'],
#   'lastUpdate': '2022-12-14T02:51:01+00:00'},
#  {'acceptedDate': '2011-05-24T00:00:00+01:00',
#   'authors': [{'name': 'Elva J. H. Robinson'},
#    {'name': 'Nigel R. Franks'},
#    {'name': 'Samuel Ellis'},
#    {'name': 'Saki Okuda'},
#    {'name': 'James A. R. Marshall'},
#    {'name': 'Frederick R. Adler'},
#    {'name': 'JMC Hutchinson'},
#    {'name': 'L Real'},
#    {'name': 'KE Mabry'},
#    {'name': 'LM Kay'},
#    {'name': 'L Chittka'},
#    {'name': 'JG Burns'},
#    {'name': 'A Kacelnik'},
#    {'name': 'TA Langen'},
#    {'name': 'AJ Moore'},
#    {'name': 'JM Amé'},
#    {'name': 'L Conradt'},
#    {'name': 'FR Adler'},
#    {'name': 'L Conradt'},
#    {'name': 'SA Levin'},
#    {'name': 'TD Seeley'},
#    {'name': 'NR Franks'},
#    {'name': 'M Möglich'},
#    {'name': 'SC Pratt'},
#    {'name': 'NR Franks'},
#    {'name': 'EB Mallon'},
#    {'name': 'JAR Marshall'},
#    {'name': 'SC Pratt'},
#    {'name': 'R Planqué'},
#    {'name': 'SC Pratt'},
#    {'name': 'T Sasaki'},
#    {'name': 'EJH Robinson'},
#    {'name': 'NR Franks'},
#    {'name': 'SC Pratt'},
#    {'name': 'A Papoulis'},
#    {'name': 'EJH Robinson'},
#    {'name': 'EJH Robinson'},
#    {'name': 'AD Briscoe'},
#    {'name': 'B Luttbeg'},
#    {'name': 'PR Freeman'},
#    {'name': 'EB Mallon'},
#    {'name': 'PK Visscher'},
#    {'name': 'KM Passino'},
#    {'name': 'PK Visscher'},
#    {'name': 'TD Seeley'},
#    {'name': 'TD Seeley'},
#    {'name': 'TD Seeley'},
#    {'name': 'TD Seeley'},
#    {'name': 'TD Seeley'},
#    {'name': 'JC Nieh'},
#    {'name': 'R Beckers'},
#    {'name': 'VM Schmidt'},
#    {'name': 'JC de Biseau'},
#    {'name': 'JH Fewell'},
#    {'name': 'EO Wilson'},
#    {'name': 'R Dhar'},
#    {'name': 'JAC Uy'},
#    {'name': 'BG Svensson'},
#    {'name': 'BM Dowds'},
#    {'name': 'L Chittka'},
#    {'name': 'S Shafir'},
#    {'name': 'PM Todd'},
#    {'name': 'JAR Marshall'},
#    {'name': 'TD Seeley'},
#    {'name': 'JAR Marshall'},
#    {'name': 'NR Franks'},
#    {'name': 'M Bateson'},
#    {'name': 'JR Doyle'},
#    {'name': 'S Edwards'},
#    {'name': 'NW Calderone'},
#    {'name': 'GE Robinson'},
#    {'name': 'SN Beshers'},
#    {'name': 'N Stroeymeyt'},
#    {'name': 'CIM Healey'},
#    {'name': 'G Théraulaz'},
#    {'name': 'RE Page'},
#    {'name': 'F Ravary'},
#    {'name': 'NR Franks'}],
#   'contributors': [''],
#   'createdDate': '2019-04-01T18:19:00+01:00',
#   'dataProvider': {'id': 4786,
#    'name': 'Crossref',
#    'url': 'https://api.core.ac.uk/v3/data-providers/4786',
#    'logo': 'https://api.core.ac.uk/data-providers/4786/logo'},
#   'depositedDate': '2011-05-24T00:00:00+01:00',
#   'documentType': '',
#   'doi': '10.1371/journal.pone.0019981',
#   'downloadUrl': '',
#   'fullText': '',
#   'id': 193838621,
#   'identifiers': {'doi': '10.1371/journal.pone.0019981', 'oai': None},
#   'title': 'A Simple Threshold Rule Is Sufficient to Explain Sophisticated Collective Decision-Making',
#   'language': None,
#   'publishedDate': '',
#   'publisher': "'Public Library of Science (PLoS)'",
#   'references': [],
#   'sourceFulltextUrls': [],
#   'updatedDate': '',
#   'yearPublished': '',
#   'links': [{'type': 'display',
#     'url': 'https://core.ac.uk/outputs/193838621'}],
#   'abstract': '',
#   'tags': [],
#   'fulltextStatus': 'disabled',
#   'subjects': [],
#   'oai': '',
#   'deleted': 'ALLOWED',
#   'disabled': False,
#   'journals': None,
#   'repositories': {'id': '4786',
#    'openDoarId': 0,
#    'name': 'Crossref',
#    'urlHomepage': None,
#    'uriJournals': None,
#    'physicalName': 'noname',
#    'roarId': 0,
#    'baseId': 0,
#    'pdfStatus': None,
#    'nrUpdates': 0,
#    'lastUpdateTime': None},
#   'repositoryDocument': {'id': 193838621,
#    'depositedDate': '2011-05-24T00:00:00+01:00',
#    'publishedDate': None,
#    'updatedDate': '2021-04-30T13:50:01+01:00',
#    'acceptedDate': '2011-05-24T00:00:00+01:00',
#    'createdDate': '2019-04-01T18:19:00+01:00'},
#   'urls': [],
#   'lastUpdate': '2021-04-30T13:50:01+01:00'},
#  {'acceptedDate': '',
#   'authors': [{'name': 'Elva J H Robinson'},
#    {'name': 'Nigel R Franks'},
#    {'name': 'Samuel Ellis'},
#    {'name': 'Saki Okuda'},
#    {'name': 'James A R Marshall'}],
#   'contributors': [],
#   'createdDate': '2017-10-13T17:10:42+01:00',
#   'dataProvider': {'id': 645,
#    'name': 'Directory of Open Access Journals',
#    'url': 'https://api.core.ac.uk/v3/data-providers/645',
#    'logo': 'https://api.core.ac.uk/data-providers/645/logo'},
#   'depositedDate': '',
#   'documentType': '',
#   'doi': '10.1371/journal.pone.0019981',
#   'downloadUrl': 'https://doaj.org/article/8f7583edf8534c329d87cdd0dda7af14',
#   'fullText': '',
#   'id': 90060283,
#   'identifiers': {'doi': '10.1371/journal.pone.0019981',
#    'oai': 'oai:doaj.org/article:8f7583edf8534c329d87cdd0dda7af14'},
#   'title': 'A simple threshold rule is sufficient to explain sophisticated collective decision-making.',
#   'language': None,
#   'publishedDate': '2011-01-01T00:00:00+00:00',
#   'publisher': "'Public Library of Science (PLoS)'",
#   'references': [],
#   'sourceFulltextUrls': ['https://doaj.org/toc/1932-6203'],
#   'updatedDate': '',
#   'yearPublished': '2011',
#   'links': [{'type': 'display', 'url': 'https://core.ac.uk/outputs/90060283'}],
#   'abstract': "Decision-making animals can use slow-but-accurate strategies, such as making multiple comparisons, or opt for simpler, faster strategies to find a 'good enough' option. Social animals make collective decisions about many group behaviours including foraging and migration. The key to the collective choice lies with individual behaviour. We present a case study of a collective decision-making process (house-hunting ants, Temnothorax albipennis), in which a previously proposed decision strategy involved both quality-dependent hesitancy and direct comparisons of nests by scouts. An alternative possible decision strategy is that scouting ants use a very simple quality-dependent threshold rule to decide whether to recruit nest-mates to a new site or search for alternatives. We use analytical and simulation modelling to demonstrate that this simple rule is sufficient to explain empirical patterns from three studies of collective decision-making in ants, and can account parsimoniously for apparent comparison by individuals and apparent hesitancy (recruitment latency) effects, when available nests differ strongly in quality. This highlights the need to carefully design experiments to detect individual comparison. We present empirical data strongly suggesting that best-of-n comparison is not used by individual ants, although individual sequential comparisons are not ruled out. However, by using a simple threshold rule, decision-making groups are able to effectively compare options, without relying on any form of direct comparison of alternatives by individuals. This parsimonious mechanism could promote collective rationality in group decision-making",
#   'tags': ['article', 'Medicine', 'R', 'Science', 'Q'],
#   'fulltextStatus': 'disabled',
#   'subjects': ['article'],
#   'oai': 'oai:doaj.org/article:8f7583edf8534c329d87cdd0dda7af14',
#   'deleted': 'ALLOWED',
#   'disabled': False,
#   'journals': [{'title': 'PLoS ONE',
#     'identifiers': ['issn:1932-6203', '1932-6203']}],
#   'repositories': {'id': '645',
#    'openDoarId': 0,
#    'name': 'Directory of Open Access Journals',
#    'urlHomepage': None,
#    'uriJournals': None,
#    'physicalName': 'noname',
#    'roarId': 0,
#    'baseId': 0,
#    'pdfStatus': None,
#    'nrUpdates': 0,
#    'lastUpdateTime': None},
#   'repositoryDocument': {'id': 90060283,
#    'depositedDate': None,
#    'publishedDate': '2011-01-01T00:00:00+00:00',
#    'updatedDate': '2022-11-09T14:23:07+00:00',
#    'acceptedDate': None,
#    'createdDate': '2017-10-13T17:10:42+01:00'},
#   'urls': ['https://doaj.org/article/8f7583edf8534c329d87cdd0dda7af14'],
#   'lastUpdate': '2022-11-09T14:23:07+00:00'},
#  {'acceptedDate': '',
#   'authors': [{'name': 'Robinson, EJH'},
#    {'name': 'Franks, NR'},
#    {'name': 'Ellis, S'},
#    {'name': 'Okuda, S'},
#    {'name': 'Marshall, JAR'}],
#   'contributors': [],
#   'createdDate': '2021-02-18T18:14:41+00:00',
#   'dataProvider': {'id': 286,
#    'name': 'Explore Bristol Research',
#    'url': 'https://api.core.ac.uk/v3/data-providers/286',
#    'logo': 'https://api.core.ac.uk/data-providers/286/logo'},
#   'depositedDate': '',
#   'documentType': '',
#   'doi': '10.1371/journal.pone.0019981',
#   'downloadUrl': 'https://doi.org/10.1371/journal.pone.0019981',
#   'fullText': '',
#   'id': 385699218,
#   'identifiers': {'doi': '10.1371/journal.pone.0019981',
#    'oai': 'oai:research-information.bris.ac.uk:openaire_cris_publications/0f3da01c-4f5c-43ee-af67-1358d550362c'},
#   'title': 'A simple threshold rule is sufficient to explain sophisticated collective decision-making',
#   'language': None,
#   'publishedDate': '2011-01-01T00:00:00+00:00',
#   'publisher': "'Public Library of Science (PLoS)'",
#   'references': [],
#   'sourceFulltextUrls': [],
#   'updatedDate': '',
#   'yearPublished': '2011',
#   'links': [{'type': 'display',
#     'url': 'https://core.ac.uk/outputs/385699218'}],
#   'abstract': '',
#   'tags': ['article'],
#   'fulltextStatus': 'disabled',
#   'subjects': ['article'],
#   'oai': 'oai:research-information.bris.ac.uk:openaire_cris_publications/0f3da01c-4f5c-43ee-af67-1358d550362c',
#   'deleted': 'DELETED',
#   'disabled': True,
#   'journals': None,
#   'repositories': {'id': '286',
#    'openDoarId': 0,
#    'name': 'Explore Bristol Research',
#    'urlHomepage': None,
#    'uriJournals': None,
#    'physicalName': 'noname',
#    'roarId': 0,
#    'baseId': 0,
#    'pdfStatus': None,
#    'nrUpdates': 0,
#    'lastUpdateTime': None},
#   'repositoryDocument': {'id': 385699218,
#    'depositedDate': None,
#    'publishedDate': '2011-01-01T00:00:00+00:00',
#    'updatedDate': '2021-10-13T18:56:17+01:00',
#    'acceptedDate': None,
#    'createdDate': '2021-02-18T18:14:41+00:00'},
#   'urls': ['https://doi.org/10.1371/journal.pone.0019981',
#    'http://hdl.handle.net/1983/0f3da01c-4f5c-43ee-af67-1358d550362c',
#    'https://research-information.bris.ac.uk/en/publications/0f3da01c-4f5c-43ee-af67-1358d550362c'],
#   'lastUpdate': '2021-10-13T18:56:17+01:00'}]

# %%
def get_entity(url_fragment):
    headers={"Authorization":"Bearer "+api_key}
    response = requests.get(api_endpoint + url_fragment, headers=headers)
    if response.status_code == 200:
        return response.json(), response.elapsed.total_seconds()
    else:
        print(f"Error code {response.status_code}, {response.content}")

# %%
data_provider, elapsed = get_entity("outputs/5225915")
pretty_json(data_provider)
# Out:
# {
#   "acceptedDate": "2011-05-24T00:00:00+01:00",
#   "authors": [
#     {
#       "name": "Robinson, Elva J. H."
#     },
#     {
#       "name": "Franks, Nigel R."
#     },
#     {
#       "name": "Ellis, Samuel"
#     },
#     {
#       "name": "Okuda, Saki"
#     },
#     {
#       "name": "Marshall, James A. R."
#     }
#   ],
#   "contributors": [],
#   "createdDate": "2012-06-28T04:00:54+01:00",
#   "dataProvider": {
#     "id": 140,
#     "name": "White Rose Research Online",
#     "url": "https://api.core.ac.uk/v3/data-providers/140",
#     "logo": "https://api.core.ac.uk/data-providers/140/logo"
#   },
#   "depositedDate": "2011-05-24T00:00:00+01:00",
#   "documentType": "unknown",
#   "doi": "10.1371/journal.pone.0019981",
#   "downloadUrl": "https://core.ac.uk/download/5225915.pdf",
#   "fullText": "This is a repository copy of A Simple Threshold Rule Is Sufficient to Explain Sophisticated Collective Decision-Making.White Rose Research Online URL for this paper:http://eprints.whiterose.ac.uk/63768/Version: Published VersionArticle:Robinson, Elva J. H. orcid.org/0000-0003-4914-9327, Franks, Nigel R., Ellis, Samuel et al.(2 more authors) (2011) A Simple Threshold Rule Is Sufficient to Explain Sophisticated Collective Decision-Making. PLoS ONE. e19981. pp. 1-11. ISSN 1932-6203 https://doi.org/10.1371/journal.pone.0019981eprints@whiterose.ac.ukhttps://eprints.whiterose.ac.uk/Reuse Items deposited in White Rose Research Online are protected by copyright, with all rights reserved unless indicated otherwise. They may be downloaded and/or printed for private study, or other acts as permitted by national copyright laws. The publisher or other rights holders may allow further reproduction and re-use of the full text version. This is indicated by the licence information on the White Rose Research Online record for the item. Takedown If you consider content in White Rose Research Online to be in breach of UK law, please notify us by emailing eprints@whiterose.ac.uk including the URL of the record and the reason for the withdrawal request. A Simple Threshold Rule Is Sufficient to ExplainSophisticated Collective Decision-MakingElva J. H. Robinson1,2*, Nigel R. Franks1, Samuel Ellis1, Saki Okuda1, James A. R. Marshall31 School of Biological Sciences, University of Bristol, Bristol, United Kingdom, 2 York Centre for Complex Systems Analysis, Department of Biology, University of York, York,United Kingdom, 3Department of Computer Science and Kroto Research Institute, University of Sheffield, Sheffield, United KingdomAbstractDecision-making animals can use slow-but-accurate strategies, such as making multiple comparisons, or opt for simpler,faster strategies to find a \u2018good enough\u2019 option. Social animals make collective decisions about many group behavioursincluding foraging and migration. The key to the collective choice lies with individual behaviour. We present a case study ofa collective decision-making process (house-hunting ants, Temnothorax albipennis), in which a previously proposed decisionstrategy involved both quality-dependent hesitancy and direct comparisons of nests by scouts. An alternative possibledecision strategy is that scouting ants use a very simple quality-dependent threshold rule to decide whether to recruit nest-mates to a new site or search for alternatives. We use analytical and simulation modelling to demonstrate that this simplerule is sufficient to explain empirical patterns from three studies of collective decision-making in ants, and can accountparsimoniously for apparent comparison by individuals and apparent hesitancy (recruitment latency) effects, when availablenests differ strongly in quality. This highlights the need to carefully design experiments to detect individual comparison. Wepresent empirical data strongly suggesting that best-of-n comparison is not used by individual ants, although individualsequential comparisons are not ruled out. However, by using a simple threshold rule, decision-making groups are able toeffectively compare options, without relying on any form of direct comparison of alternatives by individuals. Thisparsimonious mechanism could promote collective rationality in group decision-making.Citation: Robinson EJH, Franks NR, Ellis S, Okuda S, Marshall JAR (2011) A Simple Threshold Rule Is Sufficient to Explain Sophisticated Collective Decision-Making. PLoS ONE 6(5): e19981. doi:10.1371/journal.pone.0019981Editor: Frederick R. Adler, University of Utah, United States of AmericaReceived December 6, 2010; Accepted April 22, 2011; Published May 24, 2011Copyright: \u0002 2011 Robinson et al. This is an open-access article distributed under the terms of the Creative Commons Attribution License, which permitsunrestricted use, distribution, and reproduction in any me ...
#   "id": 5225915,
#   "identifiers": {
#     "doi": "10.1371/journal.pone.0019981",
#     "oai": "oai:eprints.whiterose.ac.uk:63768"
#   },
#   "title": "A Simple Threshold Rule Is Sufficient to Explain Sophisticated Collective Decision-Making",
#   "language": null,
#   "publishedDate": "2011-05-24T00:00:00+01:00",
#   "publisher": "'Public Library of Science (PLoS)'",
#   "references": [],
#   "sourceFulltextUrls": [
#     "https://eprints.whiterose.ac.uk/63768/1/Robinson2011ThresholdModel.pdf"
#   ],
#   "updatedDate": "",
#   "yearPublished": "2011",
#   "links": [
#     {
#       "type": "download",
#       "url": "https://core.ac.uk/download/5225915.pdf"
#     },
#     {
#       "type": "reader",
#       "url": "https://core.ac.uk/reader/5225915"
#     },
#     {
#       "type": "thumbnail_m",
#       "url": "https://core.ac.uk/image/5225915/medium"
#     },
#     {
#       "type": "thumbnail_l",
#       "url": "https://core.ac.uk/image/5225915/large"
#     },
#     {
#       "type": "display",
#       "url": "https://core.ac.uk/outputs/5225915"
#     }
#   ],
#   "abstract": "Decision-making animals can use slow-but-accurate strategies, such as making multiple comparisons, or opt for simpler, faster strategies to find a 'good enough' option. Social animals make collective decisions about many group behaviours including foraging and migration. The key to the collective choice lies with individual behaviour. We present a case study of a collective decision-making process (house-hunting ants, Temnothorax albipennis), in which a previously proposed decision strategy involved both quality-dependent hesitancy and direct comparisons of nests by scouts. An alternative possible decision strategy is that scouting ants use a very simple quality-dependent threshold rule to decide whether to recruit nest-mates to a new site or search for alternatives. We use analytical and simulation modelling to demonstrate that this simple rule is sufficient to explain empirical patterns from three studies of collective decision-making in ants, and can account parsimoniously for apparent comparison by individuals and apparent hesitancy (recruitment latency) effects, when available nests differ strongly in quality. This highlights the need to carefully design experiments to detect individual comparison. We present empirical data strongly suggesting that best-of-n comparison is not used by individual ants, although individual sequential comparisons are not ruled out. However, by using a simple threshold rule, decision-making groups are able to effectively compare options, without relying on any form of direct comparison of alternatives by individuals. This parsimonious mechanism could promote collective rationality in group decision-making",
#   "tags": [
#     "1100",
#     "1300",
#     "2700",
#     "1100",
#     "1300",
#     "2700"
#   ],
#   "fulltextStatus": "enabled",
#   "subjects": [
#     "1100",
#     "1300",
#     "2700"
#   ],
#   "oai": "oai:eprints.whiterose.ac.uk:63768",
#   "deleted": "ALLOWED",
#   "disabled": false,
#   "journals": null,
#   "repositories": {
#     "id": "140",
#     "openDoarId": 0,
#     "name": "White Rose Research Online",
#     "urlHomepage": null,
#     "uriJournals": null,
#     "physicalName": "noname",
#     "roarId": 0,
#     "baseId": 0,
#     "pdfStatus": null,
#     "nrUpdates": 0,
#     "lastUpdateTime": null
#   },
#   "repositoryDocument": {
#     "id": 5225915,
#     "depositedDate": "2011-05-24T00:00:00+01:00",
#     "publishedDate": "2011-05-24T00:00:00+01:00",
#     "updatedDate": "2023-07-10T13:36:49+01:00",
#     "acceptedDate": "2011-05-24T00:00:00+01:00",
#     "createdDate": "2012-06-28T04:00:54+01:00"
#   },
#   "urls": [
#     "https://eprints.whiterose.ac.uk/63768/1/Robinson2011ThresholdModel.pdf"
#   ],
#   "lastUpdate": "2023-07-10T13:36:49+01:00"
# }

# %%
type(data_provider)
# Out:
# dict

# %%
data_provider
# Out:
# dict_keys(['acceptedDate', 'authors', 'contributors', 'createdDate', 'dataProvider', 'depositedDate', 'documentType', 'doi', 'downloadUrl', 'fullText', 'id', 'identifiers', 'title', 'language', 'publishedDate', 'publisher', 'references', 'sourceFulltextUrls', 'updatedDate', 'yearPublished', 'links', 'abstract', 'tags', 'fulltextStatus', 'subjects', 'oai', 'deleted', 'disabled', 'journals', 'repositories', 'repositoryDocument', 'urls', 'lastUpdate'])

# %%
data_provider['publishedDate']
# Out:
# '2011-05-24T00:00:00+01:00'

# %%
data_provider
# Out:
# {'acceptedDate': '2011-05-24T00:00:00+01:00',
#  'authors': [{'name': 'Robinson, Elva J. H.'},
#   {'name': 'Franks, Nigel R.'},
#   {'name': 'Ellis, Samuel'},
#   {'name': 'Okuda, Saki'},
#   {'name': 'Marshall, James A. R.'}],
#  'contributors': [],
#  'createdDate': '2012-06-28T04:00:54+01:00',
#  'dataProvider': {'id': 140,
#   'name': 'White Rose Research Online',
#   'url': 'https://api.core.ac.uk/v3/data-providers/140',
#   'logo': 'https://api.core.ac.uk/data-providers/140/logo'},
#  'depositedDate': '2011-05-24T00:00:00+01:00',
#  'documentType': 'unknown',
#  'doi': '10.1371/journal.pone.0019981',
#  'downloadUrl': 'https://core.ac.uk/download/5225915.pdf',
#  'fullText': 'This is a repository copy of A Simple Threshold Rule Is Sufficient to Explain Sophisticated Collective Decision-Making.White Rose Research Online URL for this paper:http://eprints.whiterose.ac.uk/63768/Version: Published VersionArticle:Robinson, Elva J. H. orcid.org/0000-0003-4914-9327, Franks, Nigel R., Ellis, Samuel et al.(2 more authors) (2011) A Simple Threshold Rule Is Sufficient to Explain Sophisticated Collective Decision-Making. PLoS ONE. e19981. pp. 1-11. ISSN 1932-6203 https://doi.org/10.1371/journal.pone.0019981eprints@whiterose.ac.ukhttps://eprints.whiterose.ac.uk/Reuse Items deposited in White Rose Research Online are protected by copyright, with all rights reserved unless indicated otherwise. They may be downloaded and/or printed for private study, or other acts as permitted by national copyright laws. The publisher or other rights holders may allow further reproduction and re-use of the full text version. This is indicated by the licence information on the White Rose Research Online record for the item. Takedown If you consider content in White Rose Research Online to be in breach of UK law, please notify us by emailing eprints@whiterose.ac.uk including the URL of the record and the reason for the withdrawal request. A Simple Threshold Rule Is Sufficient to ExplainSophisticated Collective Decision-MakingElva J. H. Robinson1,2*, Nigel R. Franks1, Samuel Ellis1, Saki Okuda1, James A. R. Marshall31 School of Biological Sciences, University of Bristol, Bristol, United Kingdom, 2 York Centre for Complex Systems Analysis, Department of Biology, University of York, York,United Kingdom, 3Department of Computer Science and Kroto Research Institute, University of Sheffield, Sheffield, United KingdomAbstractDecision-making animals can use slow-but-accurate strategies, such as making multiple comparisons, or opt for simpler,faster strategies to find a ‘good enough’ option. Social animals make collective decisions about many group behavioursincluding foraging and migration. The key to the collective choice lies with individual behaviour. We present a case study ofa collective decision-making process (house-hunting ants, Temnothorax albipennis), in which a previously proposed decisionstrategy involved both quality-dependent hesitancy and direct comparisons of nests by scouts. An alternative possibledecision strategy is that scouting ants use a very simple quality-dependent threshold rule to decide whether to recruit nest-mates to a new site or search for alternatives. We use analytical and simulation modelling to demonstrate that this simplerule is sufficient to explain empirical patterns from three studies of collective decision-making in ants, and can accountparsimoniously for apparent comparison by individuals and apparent hesitancy (recruitment latency) effects, when availablenests differ strongly in quality. This highlights the need to carefully design experiments to detect individual comparison. Wepresent empirical data strongly suggesting that best-of-n comparison is not used by individual ants, although individualsequential comparisons are not ruled out. However, by using a simple threshold rule, decision-making groups are able toeffectively compare options, without relying on any form of direct comparison of alternatives by individuals. Thisparsimonious mechanism could promote collective rationality in group decision-making.Citation: Robinson EJH, Franks NR, Ellis S, Okuda S, Marshall JAR (2011) A Simple Threshold Rule Is Sufficient to Explain Sophisticated Collective Decision-Making. PLoS ONE 6(5): e19981. doi:10.1371/journal.pone.0019981Editor: Frederick R. Adler, University of Utah, United States of AmericaReceived December 6, 2010; Accepted April 22, 2011; Published May 24, 2011Copyright: \x02 2011 Robinson et al. This is an open-access article distributed under the terms of the Creative Commons Attribution License, which permitsunrestricted use, distribution, and reproduction in any medium, provide ...
#  'id': 5225915,
#  'identifiers': {'doi': '10.1371/journal.pone.0019981',
#   'oai': 'oai:eprints.whiterose.ac.uk:63768'},
#  'title': 'A Simple Threshold Rule Is Sufficient to Explain Sophisticated Collective Decision-Making',
#  'language': None,
#  'publishedDate': '2011-05-24T00:00:00+01:00',
#  'publisher': "'Public Library of Science (PLoS)'",
#  'references': [],
#  'sourceFulltextUrls': ['https://eprints.whiterose.ac.uk/63768/1/Robinson2011ThresholdModel.pdf'],
#  'updatedDate': '',
#  'yearPublished': '2011',
#  'links': [{'type': 'download',
#    'url': 'https://core.ac.uk/download/5225915.pdf'},
#   {'type': 'reader', 'url': 'https://core.ac.uk/reader/5225915'},
#   {'type': 'thumbnail_m', 'url': 'https://core.ac.uk/image/5225915/medium'},
#   {'type': 'thumbnail_l', 'url': 'https://core.ac.uk/image/5225915/large'},
#   {'type': 'display', 'url': 'https://core.ac.uk/outputs/5225915'}],
#  'abstract': "Decision-making animals can use slow-but-accurate strategies, such as making multiple comparisons, or opt for simpler, faster strategies to find a 'good enough' option. Social animals make collective decisions about many group behaviours including foraging and migration. The key to the collective choice lies with individual behaviour. We present a case study of a collective decision-making process (house-hunting ants, Temnothorax albipennis), in which a previously proposed decision strategy involved both quality-dependent hesitancy and direct comparisons of nests by scouts. An alternative possible decision strategy is that scouting ants use a very simple quality-dependent threshold rule to decide whether to recruit nest-mates to a new site or search for alternatives. We use analytical and simulation modelling to demonstrate that this simple rule is sufficient to explain empirical patterns from three studies of collective decision-making in ants, and can account parsimoniously for apparent comparison by individuals and apparent hesitancy (recruitment latency) effects, when available nests differ strongly in quality. This highlights the need to carefully design experiments to detect individual comparison. We present empirical data strongly suggesting that best-of-n comparison is not used by individual ants, although individual sequential comparisons are not ruled out. However, by using a simple threshold rule, decision-making groups are able to effectively compare options, without relying on any form of direct comparison of alternatives by individuals. This parsimonious mechanism could promote collective rationality in group decision-making",
#  'tags': ['1100', '1300', '2700', '1100', '1300', '2700'],
#  'fulltextStatus': 'enabled',
#  'subjects': ['1100', '1300', '2700'],
#  'oai': 'oai:eprints.whiterose.ac.uk:63768',
#  'deleted': 'ALLOWED',
#  'disabled': False,
#  'journals': None,
#  'repositories': {'id': '140',
#   'openDoarId': 0,
#   'name': 'White Rose Research Online',
#   'urlHomepage': None,
#   'uriJournals': None,
#   'physicalName': 'noname',
#   'roarId': 0,
#   'baseId': 0,
#   'pdfStatus': None,
#   'nrUpdates': 0,
#   'lastUpdateTime': None},
#  'repositoryDocument': {'id': 5225915,
#   'depositedDate': '2011-05-24T00:00:00+01:00',
#   'publishedDate': '2011-05-24T00:00:00+01:00',
#   'updatedDate': '2023-06-15T08:06:09+01:00',
#   'acceptedDate': '2011-05-24T00:00:00+01:00',
#   'createdDate': '2012-06-28T04:00:54+01:00'},
#  'urls': ['https://eprints.whiterose.ac.uk/63768/1/Robinson2011ThresholdModel.pdf'],
#  'lastUpdate': '2023-06-15T08:06:09+01:00'}

# %%
data_provider, elapsed = get_entity("outputs/81800077")

# %%
data_provider['references']
# Out:
# []

# %%
data_provider
# Out:
# {'acceptedDate': '2014-07-29T00:00:00+01:00',
#  'authors': [],
#  'contributors': [],
#  'createdDate': '2017-05-03T20:50:51+01:00',
#  'dataProvider': {'id': 2612,
#   'name': 'Springer - Publisher Connector',
#   'url': 'https://api.core.ac.uk/v3/data-providers/2612',
#   'logo': 'https://api.core.ac.uk/data-providers/2612/logo'},
#  'depositedDate': '2014-01-01T00:00:00+00:00',
#  'documentType': 'research',
#  'doi': '10.12942/lrsp-2014-4',
#  'downloadUrl': 'https://core.ac.uk/download/pdf/81800077.pdf',
#  'fullText': "Living Rev. Solar Phys., 11, (2014), 4\nhttp://www.livingreviews.org/lrsp-2014-4\ndoi:10.12942/lrsp-2014-4 IN\x00SOLAR\x00PHYSICS\n, ) 6 ) . ' 2%6)%73\nCoronal Loops:\nObservations and Modeling of Confined Plasma\nFabio Reale\nDipartimento di Fisica & Chimica,\nUniversita` di Palermo,\nPiazza Parlamento 1, 90134 Palermo, Italy\nemail: reale@astropa.unipa.it\nhttp://www.astropa.unipa.it/~reale/\nAccepted: 23 June 2014\nPublished: 29 July 2014\n(Update of lrsp-2010-5)\nAbstract\nCoronal loops are the building blocks of the X-ray bright solar corona. They owe their\nbrightness to the dense confined plasma, and this review focuses on loops mostly as structures\nconfining plasma. After a brief historical overview, the review is divided into two separate but\nnot independent parts: the first illustrates the observational framework, the second reviews\nthe theoretical knowledge. Quiescent loops and their confined plasma are considered and,\ntherefore, topics such as loop oscillations and flaring loops (except for non-solar ones, which\nprovide information on stellar loops) are not specifically addressed here. The observational\nsection discusses the classification, populations, and the morphology of coronal loops, its\nrelationship with the magnetic field, and the loop stranded structure. The section continues\nwith the thermal properties and diagnostics of the loop plasma, according to the classification\ninto hot, warm, and cool loops. Then, temporal analyses of loops and the observations of\nplasma dynamics, hot and cool flows, and waves are illustrated. In the modeling section, some\nbasics of loop physics are provided, supplying fundamental scaling laws and timescales, a useful\ntool for consultation. The concept of loop modeling is introduced and models are divided into\nthose treating loops as monolithic and static, and those resolving loops into thin and dynamic\nstrands. More specific discussions address modeling the loop fine structure and the plasma\nflowing along the loops. Special attention is devoted to the question of loop heating, with\nseparate discussion of wave (AC) and impulsive (DC) heating. Large-scale models including\natmosphere boxes and the magnetic field are also discussed. Finally, a brief discussion about\nstellar coronal loops is followed by highlights and open questions.\nKeywords: Coronal loops, Corona\nThis review is licensed under a Creative Commons\nAttribution-Non-Commercial 3.0 Germany License.\nhttp://creativecommons.org/licenses/by-nc/3.0/de/\nImprint / Terms of Use\nLiving Reviews in Solar Physics is a peer reviewed open access journal published by the Max\nPlanck Institute for Solar System Research, Justus-von-Liebig-Weg 3, 37077 Go¨ttingen, Germany.\nISSN 1614-4961.\nThis review is licensed under a Creative Commons Attribution-Non-Commercial 3.0 Germany\nLicense: http://creativecommons.org/licenses/by-nc/3.0/de/. Figures that have been pre-\nviously published elsewhere may not be reproduced without consent of the original copyright\nholders.\nBecause a Living Reviews article can evolve over time, we recommend to cite the article as follows:\nFabio Reale,\n“Coronal Loops: Observations and Modeling of Confined Plasma”,\nLiving Rev. Solar Phys., 11, (2014), 4. URL (accessed <date>):\nhttp://www.livingreviews.org/lrsp-2014-4\nThe date given as <date> then uniquely identifies the version of the article you are referring to.\nArticle Revisions\nLiving Reviews supports two ways of keeping its articles up-to-date:\nFast-track revision. A fast-track revision provides the author with the opportunity to add short\nnotices of current research results, trends and developments, or important publications to\nthe article. A fast-track revision is refereed by the responsible subject editor. If an article\nhas undergone a fast-track revision, a summary of changes will be listed here.\nMajor update. A major update will include substantial changes and additions and is subject to\nfull external refe ...
#  'id': 81800077,
#  'identifiers': {'doi': '10.12942/lrsp-2014-4', 'oai': None},
#  'title': 'Coronal Loops: Observations and Modeling of Confined Plasma',
#  'language': None,
#  'publishedDate': '',
#  'publisher': 'Springer',
#  'references': [],
#  'sourceFulltextUrls': ['file:///data/core-remote/dit/data/Springer-OA/pdf/ec4/aHR0cDovL2xpbmsuc3ByaW5nZXIuY29tLzEwLjEyOTQyL2xyc3AtMjAxNC00LnBkZg==.pdf'],
#  'updatedDate': '',
#  'yearPublished': '2014',
#  'links': [{'type': 'download',
#    'url': 'https://core.ac.uk/download/pdf/81800077.pdf'},
#   {'type': 'reader', 'url': 'https://core.ac.uk/reader/81800077'},
#   {'type': 'thumbnail_m', 'url': 'https://core.ac.uk/image/81800077/medium'},
#   {'type': 'thumbnail_l', 'url': 'https://core.ac.uk/image/81800077/large'},
#   {'type': 'display', 'url': 'https://core.ac.uk/outputs/81800077'}],
#  'abstract': '',
#  'tags': [],
#  'fulltextStatus': 'enabled',
#  'subjects': [],
#  'oai': '',
#  'deleted': 'ALLOWED',
#  'disabled': False,
#  'journals': None,
#  'repositories': {'id': '2612',
#   'openDoarId': 0,
#   'name': 'Springer - Publisher Connector',
#   'urlHomepage': None,
#   'uriJournals': None,
#   'physicalName': 'noname',
#   'roarId': 0,
#   'pdfStatus': None,
#   'nrUpdates': 0,
#   'lastUpdateTime': None},
#  'repositoryDocument': {'id': 81800077,
#   'depositedDate': '2014-01-01T00:00:00+00:00',
#   'publishedDate': None,
#   'updatedDate': '2017-05-03T20:50:51+01:00',
#   'acceptedDate': '2014-07-29T00:00:00+01:00',
#   'createdDate': '2017-05-03T20:50:51+01:00'},
#  'urls': ['https://link.springer.com/content/pdf/10.12942/lrsp-2014-4.pdf'],
#  'lastUpdate': '2017-05-03T20:50:51+01:00'}

# %%
df = pd.read_csv('/home/roland/Projects/JP_citation_classification/feature_scraping/data/ACT2_dataset.tsv', sep='\t')

# %%
df.cited_abstract.isna().sum()
# Out:
# 960

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   unique_id                 4000 non-null   object
#  1   core_id                   4000 non-null   int64
#  2   citation_offset           3995 non-null   float64
#  3   total_doc_length          4000 non-null   int64
#  4   section_info              4000 non-null   object
#  5   citing_title              4000 non-null   object
#  6   citing_author             4000 non-null   object
#  7   citing_publication_info   3705 non-null   object
#  8   citing_abstract           3992 non-null   object
#  9   cited_title               4000 non-null   object
#  10  cited_author              4000 non-null   object
#  11  cited_abstract            3040 non-null   object
#  12  cited_doi                 3646 non-null   object
#  13  cited_publication_date    3888 non-null   object
#  14  cited_publication_info    3928 non-null   object
#  15  citation_context          4000 non-null   object
#  16  self_citation             3578 non-null   float64
#  17  direct_citations          3932 non-null   float64
#  18  co_mentions               3932 non-null   float64
#  19  citation_class_label      4000 non-null   int64
#  20  citation_influence_label  4000 non-null   int64
# dtypes: float64(4), int64(4), object(13)
# memory usage: 656.4+ KB

# %%
cited_infos = df[['cited_title', 'cited_author', 'cited_abstract', 'cited_doi', 'cited_publication_date', 'cited_publication_info']]

# %%
cited_infos.cited_title[0]
# Out:
# 'The English Village Community Examined in its Relation to the Manorial and Tribal Systems and to the Common or Open Field System of Husbandry'

# %%
def search_open_alex(search_value, search_parameter):
    url = 'https://api.openalex.org/works?filter=' + search_parameter +'.search:' + search_value
    try:
        open_alex_call = requests.get(url=url).json()['results'][0]
        result = open_alex_call
        return result
    except:
        return 0

# %%
x = search_open_alex('The English Village Community Examined in its Relation to the Manorial and Tribal Systems and to the Common or Open Field System of Husbandry', 'display_name')

# %%
type(x)
# Out:
# dict

# %%
cited_infos['oa'] = cited_infos.cited_title.apply(lambda x: search_open_alex(search_value=x, search_parameter = 'display_name'))
# Out:
# <ipython-input-29-8be636e54895>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cited_infos['oa'] = cited_infos.cited_title.apply(lambda x: search_open_alex(search_value=x, search_parameter = 'display_name'))

# %%
rest = cited_infos.loc[cited_infos.oa == 0]

# %%
rest['oa'] = rest.cited_doi.apply(lambda x: search_open_alex(search_value=x, search_parameter = 'doi'))
# Out:
# <ipython-input-43-631b6832f768>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rest['oa'] = rest.cited_doi.apply(lambda x: search_open_alex(search_value=x, search_parameter = 'doi'))

# %%
rest.loc[rest.oa == 0]
# Out:
#                                             cited_title  \
# 2     Wien im Bild historischer Karten Die Entwicklu...
# 5     Les caract res originaux de l histoire rurale ...
# 6     Methods for spatial and temporal land use and ...
# 7     Landschaft hat Geschichte Historische Entwickl...
# 8     Channel planform change on the river dee meand...
# ...                                                 ...
# 3990  Floods, fights and a fluid river: the Viennese...
# 3993  ANABRANCHING RIVERS: THEIR CAUSE, CHARACTER AN...
# 3994               Wien und die fr he Donaukartographie
# 3995  Modelling channel evolution and floodplain mor...
# 3996  Atlas of the Danube River Vienna A history of ...
#
#                                            cited_author  \
# 2                                    ["Ferdinand Opll"]
# 5                                           ["M Bloch"]
# 6     ["Timothy W. Foresman", "Steward T. A. Pickett...
# 7     ["Forschungsinitiative Umweltgeschichte", "K E...
# 8       ["A. M. Gurnell", "S. R. Downward", "R. Jones"]
# ...                                                 ...
# 3990  ["Severin Hohensinner", "Bernhard Lager", "Chr...
# 3993          ["GERALD C. NANSON", "A. DAVID KNIGHTON"]
# 3994                                       ["F Slezak"]
# 3995                                     ["A D Howard"]
# 3996                       ["P Mohilla", "F Michlmayr"]
#
#                                          cited_abstract  \
# 2                                                   NaN
# 5                                                   NaN
# 6     Understanding contemporary urban landscapes re...
# 7                                                   NaN
# 8     Channel planform change was investigated along...
# ...                                                 ...
# 3990  Alluvial rivers can show unpredictable channel...
# 3993                                                NaN
# 3994                                                NaN
# 3995                                                NaN
# 3996                                                NaN
#
#                                               cited_doi  \
# 2                         10.7767/boehlau.9783205114741
# 5                                                   nan
# 6                               10.1023/a:1018583729727
# 7                                                   nan
# 8                                10.1002/rrr.3450090402
# ...                                                 ...
# 3990                          10.1007/s12685-013-0074-2
# 3993  10.1002/(sici)1096-9837(199603)21:3<217::aid-e...
# 3994                          10.1515/9783050074597-010
# 3995                                                nan
# 3996                                                nan
#
#      cited_publication_date  \
# 2                29/06/2004
# 5                      1931
# 6                      1997
# 7                      1999
# 8                   1994-12
# ...                     ...
# 3990                 2013-7
# 3993                 1996-3
# 3994             31/12/1997
# 3995                   1996
# 3996                   1996
#
#                                  cited_publication_info  oa
# 2                                          Jahrhunderts   0
# 5     Les caractères originaux de l'histoire rurale ...   0
# 6                                      Urban Ecosystems   0
# 7                                                CD-ROM   0
# 8               Regulated Rivers: Research & Management   0
# ...                                                 ...  ..
# 3990                                      Water History   0
# 3993              Earth Surface Processes and Landforms   0
# 3994                       Anthropologie und Geschichte   0
# 3995  Modelling channel evolution and floodplain mor...   0
# 3996  Donauatlas Wien: Geschichte der Donauregulieru...   0
#
# [863 rows x 7 columns]

# %%
cited_infos.oa[1]
# Out:
# {'id': 'https://openalex.org/W2332335873',
#  'doi': 'https://doi.org/10.7767/dnrm.1977.22.3.167',
#  'title': 'Die italienischen Begründer der Wiener Donaukartographie',
#  'display_name': 'Die italienischen Begründer der Wiener Donaukartographie',
#  'relevance_score': 279.1719,
#  'publication_year': 1977,
#  'publication_date': '1977-12-01',
#  'ids': {'openalex': 'https://openalex.org/W2332335873',
#   'doi': 'https://doi.org/10.7767/dnrm.1977.22.3.167',
#   'mag': '2332335873'},
#  'language': 'en',
#  'primary_location': {'is_oa': False,
#   'landing_page_url': 'https://doi.org/10.7767/dnrm.1977.22.3.167',
#   'pdf_url': None,
#   'source': {'id': 'https://openalex.org/S4210205521',
#    'display_name': 'Der Donauraum',
#    'issn_l': '0012-5415',
#    'issn': ['0012-5415', '2307-289X'],
#    'is_oa': False,
#    'is_in_doaj': False,
#    'host_organization': 'https://openalex.org/P4310321073',
#    'host_organization_name': 'Böhlau Verlag',
#    'host_organization_lineage': ['https://openalex.org/P4310320561',
#     'https://openalex.org/P4310320014',
#     'https://openalex.org/P4310321073'],
#    'host_organization_lineage_names': ['Brill',
#     'Vandenhoeck & Ruprecht',
#     'Böhlau Verlag'],
#    'type': 'journal'},
#   'license': None,
#   'version': None},
#  'type': 'article',
#  'type_crossref': 'journal-article',
#  'open_access': {'is_oa': False,
#   'oa_status': 'closed',
#   'oa_url': None,
#   'any_repository_has_fulltext': False},
#  'authorships': [{'author_position': 'first',
#    'author': {'id': 'https://openalex.org/A5000788946',
#     'display_name': 'Friedrich Slezak',
#     'orcid': None},
#    'institutions': [],
#    'is_corresponding': True,
#    'raw_affiliation_string': '',
#    'raw_affiliation_strings': []}],
#  'corresponding_author_ids': ['https://openalex.org/A5000788946'],
#  'corresponding_institution_ids': [],
#  'apc_list': None,
#  'apc_paid': None,
#  'cited_by_count': 2,
#  'biblio': {'volume': '22',
#   'issue': '3',
#   'first_page': '167',
#   'last_page': '191'},
#  'is_retracted': False,
#  'is_paratext': False,
#  'concepts': [{'id': 'https://openalex.org/C2780154274',
#    'wikidata': 'https://www.wikidata.org/wiki/Q7126717',
#    'display_name': 'Download',
#    'level': 2,
#    'score': 0.7932223},
#   {'id': 'https://openalex.org/C15708023',
#    'wikidata': 'https://www.wikidata.org/wiki/Q80083',
#    'display_name': 'Humanities',
#    'level': 1,
#    'score': 0.4340405},
#   {'id': 'https://openalex.org/C205649164',
#    'wikidata': 'https://www.wikidata.org/wiki/Q1071',
#    'display_name': 'Geography',
#    'level': 0,
#    'score': 0.35491633},
#   {'id': 'https://openalex.org/C142362112',
#    'wikidata': 'https://www.wikidata.org/wiki/Q735',
#    'display_name': 'Art',
#    'level': 0,
#    'score': 0.28595382},
#   {'id': 'https://openalex.org/C136764020',
#    'wikidata': 'https://www.wikidata.org/wiki/Q466',
#    'display_name': 'World Wide Web',
#    'level': 1,
#    'score': 0.16866177},
#   {'id': 'https://openalex.org/C41008148',
#    'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#    'display_name': 'Computer science',
#    'level': 0,
#    'score': 0.14557734}],
#  'mesh': [],
#  'locations_count': 1,
#  'locations': [{'is_oa': False,
#    'landing_page_url': 'https://doi.org/10.7767/dnrm.1977.22.3.167',
#    'pdf_url': None,
#    'source': {'id': 'https://openalex.org/S4210205521',
#     'display_name': 'Der Donauraum',
#     'issn_l': '0012-5415',
#     'issn': ['0012-5415', '2307-289X'],
#     'is_oa': False,
#     'is_in_doaj': False,
#     'host_organization': 'https://openalex.org/P4310321073',
#     'host_organization_name': 'Böhlau Verlag',
#     'host_organization_lineage': ['https://openalex.org/P4310320561',
#      'https://openalex.org/P4310320014',
#      'https://openalex.org/P4310321073'],
#     'host_organization_lineage_names': ['Brill',
#      'Vandenhoeck & Ruprecht',
#      'Böhlau Verlag'],
#     'type': 'journal'},
#    'license': None,
#    'version': None}],
#  'best_oa_location': None,
#  'sustainable_development_goals': [],
#  'grants': [],
#  'referenced_works_count': 0,
#  'referenced_works': [],
#  'related_works': ['https://openalex.org/W2183842793',
#   'https://openalex.org/W2370840135',
#   'https://openalex.org/W2378987070',
#   'https://openalex.org/W2748952813',
#   'https://openalex.org/W2899084033',
#   'https://openalex.org/W2983541391',
#   'https://openalex.org/W4205554745',
#   'https://openalex.org/W4213324249',
#   'https://openalex.org/W4213341620',
#   'https://openalex.org/W4287615848'],
#  'ngrams_url': 'https://api.openalex.org/works/W2332335873/ngrams',
#  'abstract_inverted_index': {'No': [0],
#   'AccessDie': [1],
#   'italienischen': [2],
#   'Begründer': [3],
#   'der': [4],
#   'Wiener': [5],
#   'DonaukartographieFriedrich': [6],
#   'SlezakFriedrich': [7],
#   'SlezakSearch': [8],
#   'for': [9],
#   'more': [10],
#   'papers': [11],
#   'by': [12],
#   'this': [13],
#   'authorPublished': [14],
#   'Online:Jan': [15],
#   '2019https://doi.org/10.7767/dnrm.1977.22.3.167SectionsPDF/EPUB': [16],
#   'ToolsAdd': [17],
#   'to': [18, 41],
#   'favoritesDownload': [19],
#   'CitationsTrack': [20],
#   'Citations': [21],
#   'ShareShare': [22],
#   'onFacebookTwitterLinkedInRedditEmail': [23],
#   'About': [24],
#   'Previous': [25],
#   'article': [26, 28],
#   'Next': [27],
#   'FiguresReferencesRelatedDetailsCited': [29],
#   'byChanges': [30],
#   'in': [31, 66],
#   'water': [32],
#   'and': [33],
#   'land:': [34],
#   'the': [35, 42, 59],
#   'reconstructed': [36],
#   'Viennese': [37],
#   'riverscape': [38, 62],
#   'from': [39],
#   '1500': [40],
#   'present3': [43],
#   'July': [44, 68],
#   '2013': [45, 69],
#   '|': [46, 70],
#   'Water': [47, 71],
#   'History,': [48, 72],
#   'Vol.': [49, 73],
#   '5,': [50, 74],
#   'No.': [51, 75],
#   '2Two': [52],
#   'steps': [53],
#   'back,': [54],
#   'one': [55],
#   'step': [56],
#   'forward:': [57],
#   'reconstructing': [58],
#   'dynamic': [60],
#   'Danube': [61],
#   'under': [63],
#   'human': [64],
#   'influence': [65],
#   'Vienna3': [67],
#   '2': [76],
#   'Download': [77],
#   'book': [78],
#   'coverVolume': [79],
#   '22Issue': [80],
#   '3December': [81],
#   '1977': [82],
#   'ISSN:': [83],
#   '0012-5415eISSN:': [84],
#   '2307-289XHistoryPublished': [85],
#   'online:January': [86],
#   '2019': [87],
#   'PDF': [88],
#   'download': [89]},
#  'cited_by_api_url': 'https://api.openalex.org/works?filter=cites:W2332335873',
#  'counts_by_year': [{'year': 2013, 'cited_by_count': 2}],
#  'updated_date': '2023-07-20T07:34:04.047488',
#  'created_date': '2016-06-24'}

# %%
cited_infos['abstract_inverted_index'] = df['my_column'].apply(lambda x: extract_abstract_inverted_index(x))
# Out:
# <ipython-input-54-f00db5d53c31>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cited_infos['abstract_inverted_index'] = cited_infos['oa'].apply(lambda x: extract_abstract_inverted_index(x))

# %%
cited_infos.abstract_inverted_index.isna().sum()
# Out:
# 1297

# %%
cited_infos.loc[(cited_infos.cited_abstract.isna() == True) & (cited_infos.oa_abstract.isna() == False)]
# Out:
#                                             cited_title  \
# 4                         From memory to written record
# 18    An agent-based model of collective nest choice...
# 29                 Consensus decision making in animals
# 35    Rationality in collective decision-making by a...
# 39    The effect of prior experience on nest site ev...
# ...                                                 ...
# 3985  The Origin of Stories evolution Cognition and ...
# 3987  Speech and gesture share the same communicatio...
# 3988                 Gesture and the Nature of Language
# 3989  From monkey-like action recognition to human l...
# 3992  Spatio-temporal habitat dynamics in a changing...
#
#                                            cited_author cited_abstract  \
# 4                                       ["M T Clanchy"]            NaN
# 18    ["Stephen C. Pratt", "David J.T. Sumpter", "Ea...            NaN
# 29              ["Larissa Conradt", "Timothy J. Roper"]            NaN
# 35             ["Susan C. Edwards", "Stephen C. Pratt"]            NaN
# 39       ["Christiane I.M. Healey", "Stephen C. Pratt"]            NaN
# ...                                                 ...            ...
# 3985                                         ["B Boyd"]            NaN
# 3987         ["Paolo Bernardis", "Maurizio Gentilucci"]            NaN
# 3988                                  ["D F Armstrong"]            NaN
# 3989                               ["Michael A. Arbib"]            NaN
# 3992  ["S. Hohensinner", "M. Jungwirth", "S. Muhar",...            NaN
#
#                                    cited_doi cited_publication_date  \
# 4                                        NaN                   1993
# 18             10.1016/j.anbehav.2005.01.022                2005-11
# 29                10.1016/j.tree.2005.05.008                 2005-8
# 35                    10.1098/rspb.2009.0981             22/07/2009
# 39             10.1016/j.anbehav.2008.02.016                 2008-9
# ...                                      ...                    ...
# 3985                                     NaN                   2009
# 3987  10.1016/j.neuropsychologia.2005.05.007                 2006-1
# 3988                          10.2307/415935                   1999
# 3989               10.1017/s0140525x05000038                 2005-4
# 3992                        10.1002/rra.1407             21/05/2010
#
#                                  cited_publication_info  \
# 4                         From memory to written record
# 18                                     Animal Behaviour
# 29                        Trends in Ecology & Evolution
# 35    Proceedings of the Royal Society B: Biological...
# 39                                     Animal Behaviour
# ...                                                 ...
# 3985  The Origin of Stories: evolution, Cognition, a...
# 3987                                   Neuropsychologia
# 3988  Original Signs: Gesture, Sign, and the Source ...
# 3989                      Behavioral and Brain Sciences
# 3992                    River Research and Applications
#
#                                                      oa  \
# 4     {'id': 'https://openalex.org/W2071014039', 'do...
# 18    {'id': 'https://openalex.org/W2051178235', 'do...
# 29    {'id': 'https://openalex.org/W2119382550', 'do...
# 35    {'id': 'https://openalex.org/W2155875500', 'do...
# 39    {'id': 'https://openalex.org/W2102592156', 'do...
# ...                                                 ...
# 3985  {'id': 'https://openalex.org/W1604299710', 'do...
# 3987  {'id': 'https://openalex.org/W2057029517', 'do...
# 3988  {'id': 'https://openalex.org/W2061248998', 'do...
# 3989  {'id': 'https://openalex.org/W2156256694', 'do...
# 3992  {'id': 'https://openalex.org/W2001243745', 'do...
#
#                                 abstract_inverted_index  \
# 4     {'Introduction': [0], 'Part': [1, 36], 'I': [2...
# 18    {'Colonies': [0], 'of': [1, 14, 21, 45, 76, 10...
# 29    {'Individual': [0, 145], 'animals': [1, 146, 4...
# 35    {'Economic': [0], 'models': [1], 'of': [2, 35,...
# 39    {'Animals': [0], 'are': [1], 'expected': [2], ...
# ...                                                 ...
# 3985  {'A': [0], 'century': [1], 'and': [2, 36, 53, ...
# 3987  {'Humans': [0], 'speak': [1], 'and': [2, 13, 7...
# 3988  {'This': [0], 'book': [1], 'proposes': [2], 'a...
# 3989  {'The': [0, 47, 146], 'article': [1], 'analyze...
# 3992  {'Modern,': [0], 'holistic': [1], 'concepts': ...
#
#                                                oa_title  \
# 4     From Memory to Written Record: England, 1066-1307
# 18    An agent-based model of collective nest choice...
# 29                 Consensus decision making in animals
# 35    Rationality in collective decision-making by a...
# 39    The effect of prior experience on nest site ev...
# ...                                                 ...
# 3985  On the origin of stories: evolution, cognition...
# 3987  Speech and gesture share the same communicatio...
# 3988                 Gesture and the Nature of Language
# 3989  From monkey-like action recognition to human l...
# 3992  Spatio-temporal habitat dynamics in a changing...
#
#                                             oa_abstract
# 4     Introduction Part I The Making of Records 1 Me...
# 18    Colonies of the ant Temnothorax (formerly Lept...
# 29    Individual animals routinely face decisions th...
# 35    Economic models of animal behaviour assume tha...
# 39    Animals are expected to follow decision-making...
# ...                                                 ...
# 3985  A century and a half after the publication of ...
# 3987  Humans speak and produce symbolic gestures. Do...
# 3988  This book proposes a radical alternative to do...
# 3989  The article analyzes the neural and functional...
# 3992  Modern, holistic concepts dealing with river/f...
#
# [467 rows x 10 columns]

# %%
def extract_title(dictionary):
    if isinstance(dictionary, dict) and 'title' in dictionary:
        return dictionary['title']
    else:
        return None

# %%
cited_infos['oa_title'] = cited_infos['oa'].apply(lambda x: extract_title(x))
# Out:
# <ipython-input-61-bd452f550f5b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cited_infos['oa_title'] = cited_infos['oa'].apply(lambda x: extract_title(x))

# %%
type(cited_infos.abstract_inverted_index[4])
# Out:
# dict

# %%
def generate_full_text(abstract_inverted_index):
    if abstract_inverted_index is None:
        return None  # Return empty string if the input is None

    # Sort the dictionary based on the location indices to ensure proper order
    sorted_index = sorted(abstract_inverted_index.items(), key=lambda x: x[1][0])

    # Reconstruct the full text
    full_text = ""
    for word, locations in sorted_index:
        full_text += word + " "
    
    return full_text.strip()

# %%
cited_infos['oa_abstract'] = cited_infos.abstract_inverted_index.apply(lambda x: generate_full_text(x))
# Out:
# <ipython-input-80-5a4faf410c26>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cited_infos['oa_abstract'] = cited_infos.abstract_inverted_index.apply(lambda x: generate_full_text(x))

# %%
cited_infos.oa_abstract.isna().sum()
# Out:
# 1297

# %%
def extract_display_names(concepts_list):
    if isinstance(concepts_list, list):
        display_names = [concept['display_name'] for concept in concepts_list]
        return ', '.join(display_names)
    else:
        return 'FUCK U'

# %%
cited_infos['concepts'] = cited_infos['oa'].apply(lambda x: x.get('concepts', []) if isinstance(x, dict) else [])
# Out:
# <ipython-input-120-d54053ec7af0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cited_infos['concepts'] = cited_infos['oa'].apply(lambda x: x.get('concepts', []) if isinstance(x, dict) else [])

# %%
cited_infos['concepts'] = cited_infos['concepts'].apply(extract_display_names)
# Out:
# <ipython-input-121-3df2b31b97bc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cited_infos['concepts'] = cited_infos['concepts'].apply(extract_display_names)

# %%
cited_infos.concepts.replace('', np.nan, inplace=True)
# Out:
# <ipython-input-126-25bb3a715689>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cited_infos.concepts.replace('', np.nan, inplace=True)

# %%
cited_infos.concepts
# Out:
# 0       Animal husbandry, Relation (database), Field (...
# 1       Download, Humanities, Geography, Art, World Wi...
# 2                                                     NaN
# 3       Cross section (physics), Section (typography),...
# 4       CONQUEST, Literacy, Mythology, History, Litera...
#                               ...
# 3995                                                  NaN
# 3996                                                  NaN
# 3997                               Political science, Art
# 3998    Channel (broadcasting), Computer science, Tele...
# 3999    Aggregate (composite), Materials science, Slag...
# Name: concepts, Length: 4000, dtype: object

# %%
cited_infos
# Out:
#                                             cited_title  \
# 0     The English Village Community Examined in its ...
# 1     Die italienischen Begründer der Wiener Donauka...
# 2     Wien im Bild historischer Karten Die Entwicklu...
# 3     The hydraulic geometry of stream channels and ...
# 4                         From memory to written record
# ...                                                 ...
# 3995  Modelling channel evolution and floodplain mor...
# 3996  Atlas of the Danube River Vienna A history of ...
# 3997                        Alte Grenzen im Wiener Raum
# 3998  Avulsive channel systems: characteristics and ...
# 3999  Use of Relatively High Fe2O3 Steel Slag as Coa...
#
#                                            cited_author  \
# 0                                  ["Frederic Seebohm"]
# 1                                  ["Friedrich Slezak"]
# 2                                    ["Ferdinand Opll"]
# 3            ["Luna Bergere Leopold", "Thomas Maddock"]
# 4                                       ["M T Clanchy"]
# ...                                                 ...
# 3995                                     ["A D Howard"]
# 3996                       ["P Mohilla", "F Michlmayr"]
# 3997                                         ["F Opll"]
# 3998  ["Keith Richards", "Shobhit Chandra", "Peter F...
# 3999                                      ["H Qasrawi"]
#
#                                          cited_abstract  \
# 0                                                   NaN
# 1     Die Beziehungen der Kaiserstadt an der Donau z...
# 2                                                   NaN
# 3     Some hydraulic characteristics of stream chann...
# 4                                                   NaN
# ...                                                 ...
# 3995                                                NaN
# 3996                                                NaN
# 3997                                                NaN
# 3998                                                NaN
# 3999                                                NaN
#
#                           cited_doi cited_publication_date  \
# 0      10.1017/cbo9781139094443.008                    NaN
# 1        10.7767/dnrm.1977.22.3.167                1977-12
# 2     10.7767/boehlau.9783205114741             29/06/2004
# 3                     10.3133/pp252                   1953
# 4                               NaN                   1993
# ...                             ...                    ...
# 3995                            NaN                   1996
# 3996                            NaN                   1996
# 3997                            NaN                   1986
# 3998  10.1144/gsl.sp.1993.075.01.12                   1993
# 3999              10.14359/51683922                   2012
#
#                                  cited_publication_info  \
# 0     The English Village Community Examined in its ...
# 1                                         Der Donauraum
# 2                                          Jahrhunderts
# 3                  Geological Survey Professional Paper
# 4                         From memory to written record
# ...                                                 ...
# 3995  Modelling channel evolution and floodplain mor...
# 3996  Donauatlas Wien: Geschichte der Donauregulieru...
# 3997  Kommentare zum Historischen Atlas von Wien, Vi...
# 3998   Geological Society, London, Special Publications
# 3999                              ACI Materials Journal
#
#                                                      oa  \
# 0     {'id': 'https://openalex.org/W4247988757', 'do...
# 1     {'id': 'https://openalex.org/W2332335873', 'do...
# 2                                                     0
# 3     {'id': 'https://openalex.org/W1587869157', 'do...
# 4     {'id': 'https://openalex.org/W2071014039', 'do...
# ...                                                 ...
# 3995                                                  0
# 3996                                                  0
# 3997  {'id': 'https://openalex.org/W621383568', 'doi...
# 3998  {'id': 'https://openalex.org/W2145807268', 'do...
# 3999  {'id': 'https://openalex.org/W2259052191', 'do...
#
#                                 abstract_inverted_index  \
# 0                                                  None
# 1     {'No': [0], 'AccessDie': [1], 'italienischen':...
# 2                                                  None
# 3     {'Some': [0], 'hydraulic': [1], 'characteristi...
# 4     {'Introduction': [0], 'Part': [1, 36], 'I': [2...
# ...                                                 ...
# 3995                                               None
# 3996                                               None
# 3997                                               None
# 3998                                               None
# 3999                                               None
#
#                                                oa_title  \
# 0     The English Village Community Examined in its ...
# 1     Die italienischen Begründer der Wiener Donauka...
# 2                                                  None
# 3     The hydraulic geometry of stream channels and ...
# 4     From Memory to Written Record: England, 1066-1307
# ...                                                 ...
# 3995                                               None
# 3996                                               None
# 3997                        Alte Grenzen im Wiener Raum
# 3998  Avulsive channel systems: characteristics and ...
# 3999  Use of Relatively High Fe2O3 Steel Slag as Coa...
#
#                                             oa_abstract  \
# 0                                                  None
# 1     No AccessDie italienischen Begründer der Wiene...
# 2                                                  None
# 3     Some hydraulic characteristics of stream chann...
# 4     Introduction Part I The Making of Records 1 Me...
# ...                                                 ...
# 3995                                               None
# 3996                                               None
# 3997                                               None
# 3998                                               None
# 3999                                               None
#
#                                                concepts
# 0     Animal husbandry, Relation (database), Field (...
# 1     Download, Humanities, Geography, Art, World Wi...
# 2                                                   NaN
# 3     Cross section (physics), Section (typography),...
# 4     CONQUEST, Literacy, Mythology, History, Litera...
# ...                                                 ...
# 3995                                                NaN
# 3996                                                NaN
# 3997                             Political science, Art
# 3998  Channel (broadcasting), Computer science, Tele...
# 3999  Aggregate (composite), Materials science, Slag...
#
# [4000 rows x 11 columns]

# %%
cited_infos['cited_abstract'].fillna(cited_infos['oa_abstract'], inplace=True)
# Out:
# <ipython-input-130-f0460fda3de7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cited_infos['cited_abstract'].fillna(cited_infos['oa_abstract'], inplace=True)

# %%
cited_infos.cited_abstract.isna().sum()
# Out:
# 493

# %%
df.core_id.value_counts()
# Out:
# 93144659     120
# 81800077      93
# 82852800      86
# 81068384      74
# 52040220      58
#             ...
# 46954401       1
# 2191277        1
# 19783337       1
# 2185862        1
# 187054721      1
# Name: core_id, Length: 229, dtype: int64

# %%
cited_infos
# Out:
#                                             cited_title  \
# 0     The English Village Community Examined in its ...
# 1     Die italienischen Begründer der Wiener Donauka...
# 2     Wien im Bild historischer Karten Die Entwicklu...
# 3     The hydraulic geometry of stream channels and ...
# 4                         From memory to written record
# ...                                                 ...
# 3995  Modelling channel evolution and floodplain mor...
# 3996  Atlas of the Danube River Vienna A history of ...
# 3997                        Alte Grenzen im Wiener Raum
# 3998  Avulsive channel systems: characteristics and ...
# 3999  Use of Relatively High Fe2O3 Steel Slag as Coa...
#
#                                            cited_author  \
# 0                                  ["Frederic Seebohm"]
# 1                                  ["Friedrich Slezak"]
# 2                                    ["Ferdinand Opll"]
# 3            ["Luna Bergere Leopold", "Thomas Maddock"]
# 4                                       ["M T Clanchy"]
# ...                                                 ...
# 3995                                     ["A D Howard"]
# 3996                       ["P Mohilla", "F Michlmayr"]
# 3997                                         ["F Opll"]
# 3998  ["Keith Richards", "Shobhit Chandra", "Peter F...
# 3999                                      ["H Qasrawi"]
#
#                                          cited_abstract  \
# 0                                                  None
# 1     Die Beziehungen der Kaiserstadt an der Donau z...
# 2                                                  None
# 3     Some hydraulic characteristics of stream chann...
# 4     Introduction Part I The Making of Records 1 Me...
# ...                                                 ...
# 3995                                               None
# 3996                                               None
# 3997                                               None
# 3998                                               None
# 3999                                               None
#
#                           cited_doi cited_publication_date  \
# 0      10.1017/cbo9781139094443.008                    NaN
# 1        10.7767/dnrm.1977.22.3.167                1977-12
# 2     10.7767/boehlau.9783205114741             29/06/2004
# 3                     10.3133/pp252                   1953
# 4                               NaN                   1993
# ...                             ...                    ...
# 3995                            NaN                   1996
# 3996                            NaN                   1996
# 3997                            NaN                   1986
# 3998  10.1144/gsl.sp.1993.075.01.12                   1993
# 3999              10.14359/51683922                   2012
#
#                                  cited_publication_info  \
# 0     The English Village Community Examined in its ...
# 1                                         Der Donauraum
# 2                                          Jahrhunderts
# 3                  Geological Survey Professional Paper
# 4                         From memory to written record
# ...                                                 ...
# 3995  Modelling channel evolution and floodplain mor...
# 3996  Donauatlas Wien: Geschichte der Donauregulieru...
# 3997  Kommentare zum Historischen Atlas von Wien, Vi...
# 3998   Geological Society, London, Special Publications
# 3999                              ACI Materials Journal
#
#                                                      oa  \
# 0     {'id': 'https://openalex.org/W4247988757', 'do...
# 1     {'id': 'https://openalex.org/W2332335873', 'do...
# 2                                                     0
# 3     {'id': 'https://openalex.org/W1587869157', 'do...
# 4     {'id': 'https://openalex.org/W2071014039', 'do...
# ...                                                 ...
# 3995                                                  0
# 3996                                                  0
# 3997  {'id': 'https://openalex.org/W621383568', 'doi...
# 3998  {'id': 'https://openalex.org/W2145807268', 'do...
# 3999  {'id': 'https://openalex.org/W2259052191', 'do...
#
#                                 abstract_inverted_index  \
# 0                                                  None
# 1     {'No': [0], 'AccessDie': [1], 'italienischen':...
# 2                                                  None
# 3     {'Some': [0], 'hydraulic': [1], 'characteristi...
# 4     {'Introduction': [0], 'Part': [1, 36], 'I': [2...
# ...                                                 ...
# 3995                                               None
# 3996                                               None
# 3997                                               None
# 3998                                               None
# 3999                                               None
#
#                                                oa_title  \
# 0     The English Village Community Examined in its ...
# 1     Die italienischen Begründer der Wiener Donauka...
# 2                                                  None
# 3     The hydraulic geometry of stream channels and ...
# 4     From Memory to Written Record: England, 1066-1307
# ...                                                 ...
# 3995                                               None
# 3996                                               None
# 3997                        Alte Grenzen im Wiener Raum
# 3998  Avulsive channel systems: characteristics and ...
# 3999  Use of Relatively High Fe2O3 Steel Slag as Coa...
#
#                                             oa_abstract  \
# 0                                                  None
# 1     No AccessDie italienischen Begründer der Wiene...
# 2                                                  None
# 3     Some hydraulic characteristics of stream chann...
# 4     Introduction Part I The Making of Records 1 Me...
# ...                                                 ...
# 3995                                               None
# 3996                                               None
# 3997                                               None
# 3998                                               None
# 3999                                               None
#
#                                                concepts
# 0     Animal husbandry, Relation (database), Field (...
# 1     Download, Humanities, Geography, Art, World Wi...
# 2                                                   NaN
# 3     Cross section (physics), Section (typography),...
# 4     CONQUEST, Literacy, Mythology, History, Litera...
# ...                                                 ...
# 3995                                                NaN
# 3996                                                NaN
# 3997                             Political science, Art
# 3998  Channel (broadcasting), Computer science, Tele...
# 3999  Aggregate (composite), Materials science, Slag...
#
# [4000 rows x 11 columns]

# %%
citing_paper = df[['core_id', 'citing_title']].drop_duplicates('core_id')

# %%
citing_paper['oa'] = citing_paper.citing_title.apply(lambda x: search_open_alex(x, 'display_name'))

# %%
citing_paper
# Out:
#         core_id                                       citing_title  \
# 0      81153632  Two steps back, one step forward: reconstructi...
# 13     50694047  Reproducibility of tender point examination in...
# 15      5225915  A Simple Threshold Rule Is Sufficient to Expla...
# 53     82875399  Interpreting Null Findings from Trials of Alco...
# 67     82218905  Effects of rabeprazole on the antiplatelet eff...
# ...         ...                                                ...
# 3856   52040210  Governance costs in foreign direct investments...
# 3912   82867877  Pathology and pathogenesis of vascular cogniti...
# 3913    1385821  Policy and practice in the use of root cause a...
# 3936   82867364  Wandering tales: evolutionary origins of menta...
# 3999  187054721  Towards Sustainable Self-Compacting Concrete: ...
#
#                                                      oa
# 0                                                     0
# 13    {'id': 'https://openalex.org/W2118076555', 'do...
# 15    {'id': 'https://openalex.org/W2142581949', 'do...
# 53    {'id': 'https://openalex.org/W2112943852', 'do...
# 67    {'id': 'https://openalex.org/W1993013707', 'do...
# ...                                                 ...
# 3856  {'id': 'https://openalex.org/W2012543815', 'do...
# 3912  {'id': 'https://openalex.org/W2054985387', 'do...
# 3913  {'id': 'https://openalex.org/W2059046137', 'do...
# 3936  {'id': 'https://openalex.org/W2002852594', 'do...
# 3999  {'id': 'https://openalex.org/W2791771689', 'do...
#
# [229 rows x 3 columns]

# %%
test = citing_paper.loc[citing_paper.oa == 0]

# %%
test.to_csv('test.csv')

# %%
def get_core(id):
    id = str(id)
    data_provider, elapsed = get_entity("outputs/" + id)
    return data_provider

# %%
get_core(78263683)
# Out:
# {'acceptedDate': '2016-05-26T00:00:00+01:00',
#  'authors': [{'name': 'Gurgiser, Wolfgang'},
#   {'name': 'Juen, Irmgard'},
#   {'name': 'Singer, Katrin'},
#   {'name': 'Neuburger, Martina'},
#   {'name': 'Schauwecker, Simone'},
#   {'name': 'Hofer, Marlis'},
#   {'name': 'Kaser, Georg'}],
#  'contributors': [],
#  'createdDate': '2017-02-26T12:47:44+00:00',
#  'dataProvider': {'id': 345,
#   'name': 'ZORA',
#   'url': 'https://api.core.ac.uk/v3/data-providers/345',
#   'logo': 'https://api.core.ac.uk/data-providers/345/logo'},
#  'depositedDate': '2016-05-26T00:00:00+01:00',
#  'documentType': 'unknown',
#  'doi': '10.5194/esd-7-499-2016',
#  'downloadUrl': 'http://www.zora.uzh.ch/127499/1/2016_Gurgiser_etal_2016_earth_syst_dynam.pdf',
#  'fullText': '',
#  'id': 78263683,
#  'identifiers': {'doi': '10.5194/esd-7-499-2016',
#   'oai': 'oai:www.zora.uzh.ch:127499'},
#  'title': "Comparing peasants' perceptions of precipitation change with precipitation records in the tropical Callejón de Huaylas, Peru",
#  'language': None,
#  'publishedDate': '2016-01-01T00:00:00+00:00',
#  'publisher': "'Copernicus GmbH'",
#  'references': [],
#  'sourceFulltextUrls': ['http://www.zora.uzh.ch/127499/1/2016_Gurgiser_etal_2016_earth_syst_dynam.pdf'],
#  'updatedDate': '',
#  'yearPublished': '2016',
#  'links': [{'type': 'display', 'url': 'https://core.ac.uk/outputs/78263683'}],
#  'abstract': 'Pronounced hygric seasonality determines the regional climate and, thus, the characteristics of rained agriculture in the Peruvian Callejón de Huaylas (Cordillera Blanca). Peasants in the Cuenca Auqui on the eastern slopes above the city of Huaraz attribute recently experienced challenges in agricultural production mainly to perceived changes in precipitation patterns. Statistical analyses of daily precipitation records at nearby Recuay (1964 to 2013) and Huaraz (1996 to 2013) stations do not corroborate the perceived changes. Either insufficient temporal resolution of available precipitation records or other environmental and sociopolitical factors impacting traditional farming methods may be the reason for the lack of concordance between the two information sources investigated in this study',
#  'tags': ['Journal Article',
#   'PeerReviewed',
#   'info:eu-repo/semantics/article',
#   'info:eu-repo/semantics/publishedVersion',
#   'Institute of Geography',
#   '910 Geography & travel',
#   'General Earth and Planetary Sciences'],
#  'fulltextStatus': 'enabled',
#  'subjects': ['Journal Article',
#   'PeerReviewed',
#   'info:eu-repo/semantics/article',
#   'info:eu-repo/semantics/publishedVersion'],
#  'oai': 'oai:www.zora.uzh.ch:127499',
#  'deleted': 'ALLOWED',
#  'disabled': False,
#  'journals': None,
#  'repositories': {'id': '345',
#   'openDoarId': 0,
#   'name': 'ZORA',
#   'urlHomepage': None,
#   'uriJournals': None,
#   'physicalName': 'noname',
#   'roarId': 0,
#   'baseId': 0,
#   'pdfStatus': None,
#   'nrUpdates': 0,
#   'lastUpdateTime': None},
#  'repositoryDocument': {'id': 78263683,
#   'depositedDate': '2016-05-26T00:00:00+01:00',
#   'publishedDate': '2016-01-01T00:00:00+00:00',
#   'updatedDate': '2023-05-07T13:49:29+01:00',
#   'acceptedDate': '2016-05-26T00:00:00+01:00',
#   'createdDate': '2017-02-26T12:47:44+00:00'},
#  'urls': ['https://www.zora.uzh.ch/id/eprint/127499/',
#   'https://www.zora.uzh.ch/id/eprint/127499/1/2016_Gurgiser_etal_2016_earth_syst_dynam.pdf'],
#  'lastUpdate': '2023-05-07T13:49:29+01:00'}

# %%
search_open_alex('W1918047623', 'id')
# Out:
# 0

# %%
anno = pd.read_csv('book.csv', sep=";").drop(columns= 'Column1')

# %%
anno
# Out:
#       core_id                                       citing_title           oa
# 0    81153632  Two steps back, one step forward: reconstructi...  W2026588215
# 1    81158461  The see-saw mechanism: Neutrino mixing, leptog...  W2895630496
# 2    36200578  Evolutionary History of the Live-Bearing Endem...  W1527348357
# 3    36209468  Response of Atmospheric Structure to Global Wa...  W2102148809
# 4    20349879  Markedly divergent estimates of Amazon forest ...  W2136830425
# 5    33740162  Interaction Effects of Light, Temperature and ...   W239601108
# 6    82105846  Evidence on the role of prebiotics, probiotics...  W1984774224
# 7    76526352  From a Robotic Vacuum Cleaner to a Robot Compa...  W2014991815
# 8   186893859  Case Report Molecular Profiling: A Case of ZBT...  W2609015272
# 9   186894183  Clinical Study Circulating Prostate Cells Foun...  W2093703180
# 10  186916832  Creating Under Pressure: Effects of Divided At...  W2488736146
# 11  186934554                                 Iss. 1 , Article 3  W2963768963
# 12  186951833                                       Moraza & pea  W2143896537
# 13  186964628  Psychology, Counseling Psychology, and Profess...  W2588327033
# 14  186969301  Open-access repositories worldwide, 2005-2012:...  W1903577351
# 15  186976602  Genetically differentiated races and speciatio...  W2038485931
# 16  187053631        REE Geochemistry of Euphrates River, Turkey  W2402358716
# 17  187054197  Case Report Is It Possible to Maintain Conscio...  W2272641857
# 18  187054964  Clinical Study Peritoneal Dialysis as a First ...  W2002765470
# 19  159766439  Peer review and citation data in predicting un...  W2804711044
# 20   52119449  Patients Experience of the Outcomes of Engagin...  W1555847513
# 21   81091491  High incidence and increasing prevalence of mu...  W1916685456
# 22   41236113  M-HEALTH AND HEALTH PROMOTION: THE DIGITAL CYB...  W2095298352
# 23  146503003  Sleep not just protects memories against forge...  W1016472498
# 24   18509190  Diffusion of personalised services among Dutch...  W2076890655
# 25   55853555  WHAT DETERMINES CARPOOLING TO WORKPLACES IN BE...  W2037877423
# 26   29413232  Routine Mental Health Outcome Measurement in t...  W2016691762
# 27   82846198  Voice, (inter-)subjectivity, and real time rec...  W1975640693
# 28      67538  On the tau function associated with the genera...  W1555044566
# 29   82403724  Life, hierarchy, and the thermodynamic machine...  W2094995388
# 30   82862948  Reversing autism by targeting downstream mTOR ...  W1999692166
# 31   36045385  Mobile Termination, Network Externalities, and...  W3125239992
# 32   81857737  From Implications to Dimensions: Science, Medi...  W2129168766
# 33   81768818  Identifying restrictions in the order of accum...  W2069086572
# 34   82888546  Methodological considerations for the neurophe...  W2111638249
# 35   55846727  Methodological Bias Can Lead the Cochrane Coll...  W2141316339
# 36      14579  THE RELATION BETWEEN CONTENT AND STRUCTURE IN ...  W2094373498
# 37   30320693  Title: For geographies of children, young peop...  W2128832269
# 38   81288194  On universality of critical behavior in the fo...  W2096951672
# 39   36208885  Molecule-Based Magnetic Coolers: Measurement, ...  W2113383178
# 40    9634246  Identification of damaged proteins in human se...  W2068113221
# 41   24938638  Emission-line stars in the LMC: the Armagh sur...  W2249518736
# 42   82854048  Episodic eolian sand deposition in the past 40...  W2118051982
# 43   82152711  Potential Vulnerabilities of Neuronal Reward, ...  W2087874796
# 44   30780864  Viral infection of human lung macrophages incr...  W1972631957
# 45    9323912  Parental Characteristics, Family Structure and...  W2056333597
# 46   78263683  Comparing peasants perceptions of precipitatio...  W1918047623
# 47   11291499  Securitization of mortgage debt, domestic lend...  W1573159499
# 48   12030665  Does employment protection lead to unemploymen...  W3123464791

# %%
def search_oa_id(search_value):
    search_value = str(search_value)
    url = 'https://api.openalex.org/' + search_value
    try:
        open_alex_call = requests.get(url=url).json()#['results'][0]
        result = open_alex_call
        return result
    except:
        return 0

# %%
anno['new_data'] = anno.oa.apply(lambda x: search_oa_id(x))

# %%
anno
# Out:
#       core_id                                       citing_title           oa  \
# 0    81153632  Two steps back, one step forward: reconstructi...  W2026588215
# 1    81158461  The see-saw mechanism: Neutrino mixing, leptog...  W2895630496
# 2    36200578  Evolutionary History of the Live-Bearing Endem...  W1527348357
# 3    36209468  Response of Atmospheric Structure to Global Wa...  W2102148809
# 4    20349879  Markedly divergent estimates of Amazon forest ...  W2136830425
# 5    33740162  Interaction Effects of Light, Temperature and ...   W239601108
# 6    82105846  Evidence on the role of prebiotics, probiotics...  W1984774224
# 7    76526352  From a Robotic Vacuum Cleaner to a Robot Compa...  W2014991815
# 8   186893859  Case Report Molecular Profiling: A Case of ZBT...  W2609015272
# 9   186894183  Clinical Study Circulating Prostate Cells Foun...  W2093703180
# 10  186916832  Creating Under Pressure: Effects of Divided At...  W2488736146
# 11  186934554                                 Iss. 1 , Article 3  W2963768963
# 12  186951833                                       Moraza & pea  W2143896537
# 13  186964628  Psychology, Counseling Psychology, and Profess...  W2588327033
# 14  186969301  Open-access repositories worldwide, 2005-2012:...  W1903577351
# 15  186976602  Genetically differentiated races and speciatio...  W2038485931
# 16  187053631        REE Geochemistry of Euphrates River, Turkey  W2402358716
# 17  187054197  Case Report Is It Possible to Maintain Conscio...  W2272641857
# 18  187054964  Clinical Study Peritoneal Dialysis as a First ...  W2002765470
# 19  159766439  Peer review and citation data in predicting un...  W2804711044
# 20   52119449  Patients Experience of the Outcomes of Engagin...  W1555847513
# 21   81091491  High incidence and increasing prevalence of mu...  W1916685456
# 22   41236113  M-HEALTH AND HEALTH PROMOTION: THE DIGITAL CYB...  W2095298352
# 23  146503003  Sleep not just protects memories against forge...  W1016472498
# 24   18509190  Diffusion of personalised services among Dutch...  W2076890655
# 25   55853555  WHAT DETERMINES CARPOOLING TO WORKPLACES IN BE...  W2037877423
# 26   29413232  Routine Mental Health Outcome Measurement in t...  W2016691762
# 27   82846198  Voice, (inter-)subjectivity, and real time rec...  W1975640693
# 28      67538  On the tau function associated with the genera...  W1555044566
# 29   82403724  Life, hierarchy, and the thermodynamic machine...  W2094995388
# 30   82862948  Reversing autism by targeting downstream mTOR ...  W1999692166
# 31   36045385  Mobile Termination, Network Externalities, and...  W3125239992
# 32   81857737  From Implications to Dimensions: Science, Medi...  W2129168766
# 33   81768818  Identifying restrictions in the order of accum...  W2069086572
# 34   82888546  Methodological considerations for the neurophe...  W2111638249
# 35   55846727  Methodological Bias Can Lead the Cochrane Coll...  W2141316339
# 36      14579  THE RELATION BETWEEN CONTENT AND STRUCTURE IN ...  W2094373498
# 37   30320693  Title: For geographies of children, young peop...  W2128832269
# 38   81288194  On universality of critical behavior in the fo...  W2096951672
# 39   36208885  Molecule-Based Magnetic Coolers: Measurement, ...  W2113383178
# 40    9634246  Identification of damaged proteins in human se...  W2068113221
# 41   24938638  Emission-line stars in the LMC: the Armagh sur...  W2249518736
# 42   82854048  Episodic eolian sand deposition in the past 40...  W2118051982
# 43   82152711  Potential Vulnerabilities of Neuronal Reward, ...  W2087874796
# 44   30780864  Viral infection of human lung macrophages incr...  W1972631957
# 45    9323912  Parental Characteristics, Family Structure and...  W2056333597
# 46   78263683  Comparing peasants perceptions of precipitatio...  W1918047623
# 47   11291499  Securitization of mortgage debt, domestic lend...  W1573159499
# 48   12030665  Does employment protection lead to unemploymen...  W3123464791
#
#                                              new_data
# 0   {'id': 'https://openalex.org/W2026588215', 'do...
# 1   {'id': 'https://openalex.org/W2895630496', 'do...
# 2   {'id': 'https://openalex.org/W1527348357', 'do...
# 3   {'id': 'https://openalex.org/W2102148809', 'do...
# 4   {'id': 'https://openalex.org/W2136830425', 'do...
# 5   {'id': 'https://openalex.org/W239601108', 'doi...
# 6   {'id': 'https://openalex.org/W1984774224', 'do...
# 7   {'id': 'https://openalex.org/W2014991815', 'do...
# 8   {'id': 'https://openalex.org/W2609015272', 'do...
# 9   {'id': 'https://openalex.org/W2093703180', 'do...
# 10  {'id': 'https://openalex.org/W2488736146', 'do...
# 11  {'id': 'https://openalex.org/W2963768963', 'do...
# 12  {'id': 'https://openalex.org/W2143896537', 'do...
# 13  {'id': 'https://openalex.org/W2588327033', 'do...
# 14  {'id': 'https://openalex.org/W1903577351', 'do...
# 15  {'id': 'https://openalex.org/W2038485931', 'do...
# 16  {'id': 'https://openalex.org/W2402358716', 'do...
# 17  {'id': 'https://openalex.org/W2272641857', 'do...
# 18  {'id': 'https://openalex.org/W2002765470', 'do...
# 19  {'id': 'https://openalex.org/W2804711044', 'do...
# 20  {'id': 'https://openalex.org/W1555847513', 'do...
# 21  {'id': 'https://openalex.org/W1916685456', 'do...
# 22  {'id': 'https://openalex.org/W2095298352', 'do...
# 23  {'id': 'https://openalex.org/W1016472498', 'do...
# 24  {'id': 'https://openalex.org/W2076890655', 'do...
# 25  {'id': 'https://openalex.org/W2037877423', 'do...
# 26  {'id': 'https://openalex.org/W2016691762', 'do...
# 27  {'id': 'https://openalex.org/W1975640693', 'do...
# 28  {'id': 'https://openalex.org/W1555044566', 'do...
# 29  {'id': 'https://openalex.org/W2094995388', 'do...
# 30  {'id': 'https://openalex.org/W1999692166', 'do...
# 31  {'id': 'https://openalex.org/W3125239992', 'do...
# 32  {'id': 'https://openalex.org/W2129168766', 'do...
# 33  {'id': 'https://openalex.org/W2069086572', 'do...
# 34  {'id': 'https://openalex.org/W2111638249', 'do...
# 35  {'id': 'https://openalex.org/W2141316339', 'do...
# 36  {'id': 'https://openalex.org/W2094373498', 'do...
# 37  {'id': 'https://openalex.org/W2128832269', 'do...
# 38  {'id': 'https://openalex.org/W2096951672', 'do...
# 39  {'id': 'https://openalex.org/W2113383178', 'do...
# 40  {'id': 'https://openalex.org/W2068113221', 'do...
# 41  {'id': 'https://openalex.org/W2249518736', 'do...
# 42  {'id': 'https://openalex.org/W2118051982', 'do...
# 43  {'id': 'https://openalex.org/W2087874796', 'do...
# 44  {'id': 'https://openalex.org/W1972631957', 'do...
# 45  {'id': 'https://openalex.org/W2056333597', 'do...
# 46  {'id': 'https://openalex.org/W1918047623', 'do...
# 47  {'id': 'https://openalex.org/W1573159499', 'do...
# 48  {'id': 'https://openalex.org/W3123464791', 'do...

# %%
citing_paper = pd.merge(left = citing_paper, right = anno[['core_id', 'new_data']], on = 'core_id', how = 'left')

# %%
citing_paper.oa.replace(0, np.nan, inplace=True)

# %%
citing_paper.oa.isna().sum()
# Out:
# 0

# %%
citing_paper['oa'].fillna(citing_paper['new_data'], inplace=True)

# %%
citing_paper
# Out:
#        core_id                                       citing_title  \
# 0     81153632  Two steps back, one step forward: reconstructi...
# 1     50694047  Reproducibility of tender point examination in...
# 2      5225915  A Simple Threshold Rule Is Sufficient to Expla...
# 3     82875399  Interpreting Null Findings from Trials of Alco...
# 4     82218905  Effects of rabeprazole on the antiplatelet eff...
# ..         ...                                                ...
# 224   52040210  Governance costs in foreign direct investments...
# 225   82867877  Pathology and pathogenesis of vascular cogniti...
# 226    1385821  Policy and practice in the use of root cause a...
# 227   82867364  Wandering tales: evolutionary origins of menta...
# 228  187054721  Towards Sustainable Self-Compacting Concrete: ...
#
#                                                     oa  \
# 0    {'id': 'https://openalex.org/W2026588215', 'do...
# 1    {'id': 'https://openalex.org/W2118076555', 'do...
# 2    {'id': 'https://openalex.org/W2142581949', 'do...
# 3    {'id': 'https://openalex.org/W2112943852', 'do...
# 4    {'id': 'https://openalex.org/W1993013707', 'do...
# ..                                                 ...
# 224  {'id': 'https://openalex.org/W2012543815', 'do...
# 225  {'id': 'https://openalex.org/W2054985387', 'do...
# 226  {'id': 'https://openalex.org/W2059046137', 'do...
# 227  {'id': 'https://openalex.org/W2002852594', 'do...
# 228  {'id': 'https://openalex.org/W2791771689', 'do...
#
#                                               new_data
# 0    {'id': 'https://openalex.org/W2026588215', 'do...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 224                                                NaN
# 225                                                NaN
# 226                                                NaN
# 227                                                NaN
# 228                                                NaN
#
# [229 rows x 4 columns]

# %%
next_try = cited_infos.loc[cited_infos.oa == 0]

# %%
def search_open_alex(search_value, search_parameter):
    url = 'https://api.openalex.org/works?filter=' + search_parameter +'.search:' + search_value
    try:
        open_alex_call = requests.get(url=url).json()['results'][0]
        result = open_alex_call
        return result
    except:
        return 0

# %%
next_try#.cited_doi.isna().sum()
# Out:
#                                             cited_title  \
# 2     Wien im Bild historischer Karten Die Entwicklu...
# 5     Les caract res originaux de l histoire rurale ...
# 6     Methods for spatial and temporal land use and ...
# 7     Landschaft hat Geschichte Historische Entwickl...
# 8     Channel planform change on the river dee meand...
# ...                                                 ...
# 3990  Floods, fights and a fluid river: the Viennese...
# 3993  ANABRANCHING RIVERS: THEIR CAUSE, CHARACTER AN...
# 3994               Wien und die fr he Donaukartographie
# 3995  Modelling channel evolution and floodplain mor...
# 3996  Atlas of the Danube River Vienna A history of ...
#
#                                            cited_author  \
# 2                                    ["Ferdinand Opll"]
# 5                                           ["M Bloch"]
# 6     ["Timothy W. Foresman", "Steward T. A. Pickett...
# 7     ["Forschungsinitiative Umweltgeschichte", "K E...
# 8       ["A. M. Gurnell", "S. R. Downward", "R. Jones"]
# ...                                                 ...
# 3990  ["Severin Hohensinner", "Bernhard Lager", "Chr...
# 3993          ["GERALD C. NANSON", "A. DAVID KNIGHTON"]
# 3994                                       ["F Slezak"]
# 3995                                     ["A D Howard"]
# 3996                       ["P Mohilla", "F Michlmayr"]
#
#                                          cited_abstract  \
# 2                                                  None
# 5                                                  None
# 6     Understanding contemporary urban landscapes re...
# 7                                                  None
# 8     Channel planform change was investigated along...
# ...                                                 ...
# 3990  Alluvial rivers can show unpredictable channel...
# 3993                                               None
# 3994                                               None
# 3995                                               None
# 3996                                               None
#
#                                               cited_doi  \
# 2                         10.7767/boehlau.9783205114741
# 5                                                   NaN
# 6                               10.1023/a:1018583729727
# 7                                                   NaN
# 8                                10.1002/rrr.3450090402
# ...                                                 ...
# 3990                          10.1007/s12685-013-0074-2
# 3993  10.1002/(sici)1096-9837(199603)21:3<217::aid-e...
# 3994                          10.1515/9783050074597-010
# 3995                                                NaN
# 3996                                                NaN
#
#      cited_publication_date  \
# 2                29/06/2004
# 5                      1931
# 6                      1997
# 7                      1999
# 8                   1994-12
# ...                     ...
# 3990                 2013-7
# 3993                 1996-3
# 3994             31/12/1997
# 3995                   1996
# 3996                   1996
#
#                                  cited_publication_info oa  \
# 2                                          Jahrhunderts  0
# 5     Les caractères originaux de l'histoire rurale ...  0
# 6                                      Urban Ecosystems  0
# 7                                                CD-ROM  0
# 8               Regulated Rivers: Research & Management  0
# ...                                                 ... ..
# 3990                                      Water History  0
# 3993              Earth Surface Processes and Landforms  0
# 3994                       Anthropologie und Geschichte  0
# 3995  Modelling channel evolution and floodplain mor...  0
# 3996  Donauatlas Wien: Geschichte der Donauregulieru...  0
#
#      abstract_inverted_index oa_title oa_abstract concepts
# 2                       None     None        None      NaN
# 5                       None     None        None      NaN
# 6                       None     None        None      NaN
# 7                       None     None        None      NaN
# 8                       None     None        None      NaN
# ...                      ...      ...         ...      ...
# 3990                    None     None        None      NaN
# 3993                    None     None        None      NaN
# 3994                    None     None        None      NaN
# 3995                    None     None        None      NaN
# 3996                    None     None        None      NaN
#
# [863 rows x 11 columns]

# %%
def search_oa_doi(search_value):
    search_value = str(search_value)
    url = 'https://api.openalex.org/works/https://doi.org/' + search_value
    try:
        open_alex_call = requests.get(url=url).json()#['results'][0]
        result = open_alex_call
        return result
    except:
        return 0

# %%
next_try['oa'] = next_try.cited_doi.apply(lambda x: search_oa_doi(x))
# Out:
# <ipython-input-229-8a95867417ed>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   next_try['oa'] = next_try.cited_doi.apply(lambda x: search_oa_doi(x))

# %%
next_try.loc[next_try.oa != 0]
# Out:
#                                             cited_title  \
# 2     Wien im Bild historischer Karten Die Entwicklu...
# 6     Methods for spatial and temporal land use and ...
# 8     Channel planform change on the river dee meand...
# 12    Hydromorphological characteristics of the Danu...
# 14    Pressure pain threshold in pain-free subjects,...
# ...                                                 ...
# 3970  Patterns of Brain Activity Supporting Autobiog...
# 3984  The brain s default network anatomy function a...
# 3990  Floods, fights and a fluid river: the Viennese...
# 3993  ANABRANCHING RIVERS: THEIR CAUSE, CHARACTER AN...
# 3994               Wien und die fr he Donaukartographie
#
#                                            cited_author  \
# 2                                    ["Ferdinand Opll"]
# 6     ["Timothy W. Foresman", "Steward T. A. Pickett...
# 8       ["A. M. Gurnell", "S. R. Downward", "R. Jones"]
# 12    ["S. Hohensinner", "H. Habersack", "M. Jungwir...
# 14            ["Gerald Granges", "Geoffrey Littlejohn"]
# ...                                                 ...
# 3970            ["R. Nathan Spreng", "Cheryl L. Grady"]
# 3984  ["Randy L. Buckner", "Jessica R. Andrews-Hanna...
# 3990  ["Severin Hohensinner", "Bernhard Lager", "Chr...
# 3993          ["GERALD C. NANSON", "A. DAVID KNIGHTON"]
# 3994                                       ["F Slezak"]
#
#                                          cited_abstract  \
# 2                                                  None
# 6     Understanding contemporary urban landscapes re...
# 8     Channel planform change was investigated along...
# 12                                                 None
# 14    We hypothesized that change in pain threshold ...
# ...                                                 ...
# 3970                                               None
# 3984                                               None
# 3990  Alluvial rivers can show unpredictable channel...
# 3993                                               None
# 3994                                               None
#
#                                               cited_doi  \
# 2                         10.7767/boehlau.9783205114741
# 6                               10.1023/a:1018583729727
# 8                                10.1002/rrr.3450090402
# 12                                      10.1002/rra.719
# 14                               10.1002/art.1780360510
# ...                                                 ...
# 3970                            10.1162/jocn.2009.21282
# 3984                            10.1196/annals.1440.011
# 3990                          10.1007/s12685-013-0074-2
# 3993  10.1002/(sici)1096-9837(199603)21:3<217::aid-e...
# 3994                          10.1515/9783050074597-010
#
#      cited_publication_date                      cited_publication_info  \
# 2                29/06/2004                                Jahrhunderts
# 6                      1997                            Urban Ecosystems
# 8                   1994-12     Regulated Rivers: Research & Management
# 12               10/12/2003             River Research and Applications
# 14                   1993-5                      Arthritis & Rheumatism
# ...                     ...                                         ...
# 3970             01/06/2010           Journal of Cognitive Neuroscience
# 3984                 2008-3  Annals of the New York Academy of Sciences
# 3990                 2013-7                               Water History
# 3993                 1996-3       Earth Surface Processes and Landforms
# 3994             31/12/1997                Anthropologie und Geschichte
#
#                                                      oa  \
# 2     {'id': 'https://openalex.org/W1590955822', 'do...
# 6     {'id': 'https://openalex.org/W2129426812', 'do...
# 8     {'id': 'https://openalex.org/W2153361544', 'do...
# 12    {'id': 'https://openalex.org/W2043145277', 'do...
# 14    {'id': 'https://openalex.org/W2066620877', 'do...
# ...                                                 ...
# 3970  {'id': 'https://openalex.org/W2009594384', 'do...
# 3984  {'id': 'https://openalex.org/W2136435696', 'do...
# 3990  {'id': 'https://openalex.org/W2070146044', 'do...
# 3993  {'id': 'https://openalex.org/W2097996280', 'do...
# 3994  {'id': 'https://openalex.org/W4250409433', 'do...
#
#      abstract_inverted_index oa_title oa_abstract concepts
# 2                       None     None        None      NaN
# 6                       None     None        None      NaN
# 8                       None     None        None      NaN
# 12                      None     None        None      NaN
# 14                      None     None        None      NaN
# ...                      ...      ...         ...      ...
# 3970                    None     None        None      NaN
# 3984                    None     None        None      NaN
# 3990                    None     None        None      NaN
# 3993                    None     None        None      NaN
# 3994                    None     None        None      NaN
#
# [671 rows x 11 columns]

# %%
next_try['oa_new'] = next_try.oa
# Out:
# <ipython-input-235-100eea276438>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   next_try['oa_new'] = next_try.oa

# %%
cited_infos.merge(next_try['oa_new'], on
# Out:
#                                             cited_title  \
# 0     The English Village Community Examined in its ...
# 1     Die italienischen Begründer der Wiener Donauka...
# 2     Wien im Bild historischer Karten Die Entwicklu...
# 3     The hydraulic geometry of stream channels and ...
# 4                         From memory to written record
# ...                                                 ...
# 3995  Modelling channel evolution and floodplain mor...
# 3996  Atlas of the Danube River Vienna A history of ...
# 3997                        Alte Grenzen im Wiener Raum
# 3998  Avulsive channel systems: characteristics and ...
# 3999  Use of Relatively High Fe2O3 Steel Slag as Coa...
#
#                                            cited_author  \
# 0                                  ["Frederic Seebohm"]
# 1                                  ["Friedrich Slezak"]
# 2                                    ["Ferdinand Opll"]
# 3            ["Luna Bergere Leopold", "Thomas Maddock"]
# 4                                       ["M T Clanchy"]
# ...                                                 ...
# 3995                                     ["A D Howard"]
# 3996                       ["P Mohilla", "F Michlmayr"]
# 3997                                         ["F Opll"]
# 3998  ["Keith Richards", "Shobhit Chandra", "Peter F...
# 3999                                      ["H Qasrawi"]
#
#                                          cited_abstract  \
# 0                                                  None
# 1     Die Beziehungen der Kaiserstadt an der Donau z...
# 2                                                  None
# 3     Some hydraulic characteristics of stream chann...
# 4     Introduction Part I The Making of Records 1 Me...
# ...                                                 ...
# 3995                                               None
# 3996                                               None
# 3997                                               None
# 3998                                               None
# 3999                                               None
#
#                           cited_doi cited_publication_date  \
# 0      10.1017/cbo9781139094443.008                    NaN
# 1        10.7767/dnrm.1977.22.3.167                1977-12
# 2     10.7767/boehlau.9783205114741             29/06/2004
# 3                     10.3133/pp252                   1953
# 4                               NaN                   1993
# ...                             ...                    ...
# 3995                            NaN                   1996
# 3996                            NaN                   1996
# 3997                            NaN                   1986
# 3998  10.1144/gsl.sp.1993.075.01.12                   1993
# 3999              10.14359/51683922                   2012
#
#                                  cited_publication_info  \
# 0     The English Village Community Examined in its ...
# 1                                         Der Donauraum
# 2                                          Jahrhunderts
# 3                  Geological Survey Professional Paper
# 4                         From memory to written record
# ...                                                 ...
# 3995  Modelling channel evolution and floodplain mor...
# 3996  Donauatlas Wien: Geschichte der Donauregulieru...
# 3997  Kommentare zum Historischen Atlas von Wien, Vi...
# 3998   Geological Society, London, Special Publications
# 3999                              ACI Materials Journal
#
#                                                      oa  \
# 0     {'id': 'https://openalex.org/W4247988757', 'do...
# 1     {'id': 'https://openalex.org/W2332335873', 'do...
# 2                                                     0
# 3     {'id': 'https://openalex.org/W1587869157', 'do...
# 4     {'id': 'https://openalex.org/W2071014039', 'do...
# ...                                                 ...
# 3995                                                  0
# 3996                                                  0
# 3997  {'id': 'https://openalex.org/W621383568', 'doi...
# 3998  {'id': 'https://openalex.org/W2145807268', 'do...
# 3999  {'id': 'https://openalex.org/W2259052191', 'do...
#
#                                 abstract_inverted_index  \
# 0                                                  None
# 1     {'No': [0], 'AccessDie': [1], 'italienischen':...
# 2                                                  None
# 3     {'Some': [0], 'hydraulic': [1], 'characteristi...
# 4     {'Introduction': [0], 'Part': [1, 36], 'I': [2...
# ...                                                 ...
# 3995                                               None
# 3996                                               None
# 3997                                               None
# 3998                                               None
# 3999                                               None
#
#                                                oa_title  \
# 0     The English Village Community Examined in its ...
# 1     Die italienischen Begründer der Wiener Donauka...
# 2                                                  None
# 3     The hydraulic geometry of stream channels and ...
# 4     From Memory to Written Record: England, 1066-1307
# ...                                                 ...
# 3995                                               None
# 3996                                               None
# 3997                        Alte Grenzen im Wiener Raum
# 3998  Avulsive channel systems: characteristics and ...
# 3999  Use of Relatively High Fe2O3 Steel Slag as Coa...
#
#                                             oa_abstract  \
# 0                                                  None
# 1     No AccessDie italienischen Begründer der Wiene...
# 2                                                  None
# 3     Some hydraulic characteristics of stream chann...
# 4     Introduction Part I The Making of Records 1 Me...
# ...                                                 ...
# 3995                                               None
# 3996                                               None
# 3997                                               None
# 3998                                               None
# 3999                                               None
#
#                                                concepts
# 0     Animal husbandry, Relation (database), Field (...
# 1     Download, Humanities, Geography, Art, World Wi...
# 2                                                   NaN
# 3     Cross section (physics), Section (typography),...
# 4     CONQUEST, Literacy, Mythology, History, Litera...
# ...                                                 ...
# 3995                                                NaN
# 3996                                                NaN
# 3997                             Political science, Art
# 3998  Channel (broadcasting), Computer science, Tele...
# 3999  Aggregate (composite), Materials science, Slag...
#
# [4000 rows x 11 columns]

# %%
final = pd.merge(left=cited_infos, right=next_try['oa_new'], left_index=True, right_index=True, how = 'left')

# %%
final.oa.replace(0, np.nan, inplace=True)

# %%
final['oa'].fillna(final['oa_new'], inplace=True)

# %%
final.loc[final.oa != 0]
# Out:
#                                             cited_title  \
# 0     The English Village Community Examined in its ...
# 1     Die italienischen Begründer der Wiener Donauka...
# 2     Wien im Bild historischer Karten Die Entwicklu...
# 3     The hydraulic geometry of stream channels and ...
# 4                         From memory to written record
# ...                                                 ...
# 3993  ANABRANCHING RIVERS: THEIR CAUSE, CHARACTER AN...
# 3994               Wien und die fr he Donaukartographie
# 3997                        Alte Grenzen im Wiener Raum
# 3998  Avulsive channel systems: characteristics and ...
# 3999  Use of Relatively High Fe2O3 Steel Slag as Coa...
#
#                                            cited_author  \
# 0                                  ["Frederic Seebohm"]
# 1                                  ["Friedrich Slezak"]
# 2                                    ["Ferdinand Opll"]
# 3            ["Luna Bergere Leopold", "Thomas Maddock"]
# 4                                       ["M T Clanchy"]
# ...                                                 ...
# 3993          ["GERALD C. NANSON", "A. DAVID KNIGHTON"]
# 3994                                       ["F Slezak"]
# 3997                                         ["F Opll"]
# 3998  ["Keith Richards", "Shobhit Chandra", "Peter F...
# 3999                                      ["H Qasrawi"]
#
#                                          cited_abstract  \
# 0                                                  None
# 1     Die Beziehungen der Kaiserstadt an der Donau z...
# 2                                                  None
# 3     Some hydraulic characteristics of stream chann...
# 4     Introduction Part I The Making of Records 1 Me...
# ...                                                 ...
# 3993                                               None
# 3994                                               None
# 3997                                               None
# 3998                                               None
# 3999                                               None
#
#                                               cited_doi  \
# 0                          10.1017/cbo9781139094443.008
# 1                            10.7767/dnrm.1977.22.3.167
# 2                         10.7767/boehlau.9783205114741
# 3                                         10.3133/pp252
# 4                                                   NaN
# ...                                                 ...
# 3993  10.1002/(sici)1096-9837(199603)21:3<217::aid-e...
# 3994                          10.1515/9783050074597-010
# 3997                                                NaN
# 3998                      10.1144/gsl.sp.1993.075.01.12
# 3999                                  10.14359/51683922
#
#      cited_publication_date  \
# 0                       NaN
# 1                   1977-12
# 2                29/06/2004
# 3                      1953
# 4                      1993
# ...                     ...
# 3993                 1996-3
# 3994             31/12/1997
# 3997                   1986
# 3998                   1993
# 3999                   2012
#
#                                  cited_publication_info  \
# 0     The English Village Community Examined in its ...
# 1                                         Der Donauraum
# 2                                          Jahrhunderts
# 3                  Geological Survey Professional Paper
# 4                         From memory to written record
# ...                                                 ...
# 3993              Earth Surface Processes and Landforms
# 3994                       Anthropologie und Geschichte
# 3997  Kommentare zum Historischen Atlas von Wien, Vi...
# 3998   Geological Society, London, Special Publications
# 3999                              ACI Materials Journal
#
#                                                      oa  \
# 0     {'id': 'https://openalex.org/W4247988757', 'do...
# 1     {'id': 'https://openalex.org/W2332335873', 'do...
# 2     {'id': 'https://openalex.org/W1590955822', 'do...
# 3     {'id': 'https://openalex.org/W1587869157', 'do...
# 4     {'id': 'https://openalex.org/W2071014039', 'do...
# ...                                                 ...
# 3993  {'id': 'https://openalex.org/W2097996280', 'do...
# 3994  {'id': 'https://openalex.org/W4250409433', 'do...
# 3997  {'id': 'https://openalex.org/W621383568', 'doi...
# 3998  {'id': 'https://openalex.org/W2145807268', 'do...
# 3999  {'id': 'https://openalex.org/W2259052191', 'do...
#
#                                 abstract_inverted_index  \
# 0                                                  None
# 1     {'No': [0], 'AccessDie': [1], 'italienischen':...
# 2                                                  None
# 3     {'Some': [0], 'hydraulic': [1], 'characteristi...
# 4     {'Introduction': [0], 'Part': [1, 36], 'I': [2...
# ...                                                 ...
# 3993                                               None
# 3994                                               None
# 3997                                               None
# 3998                                               None
# 3999                                               None
#
#                                                oa_title  \
# 0     The English Village Community Examined in its ...
# 1     Die italienischen Begründer der Wiener Donauka...
# 2                                                  None
# 3     The hydraulic geometry of stream channels and ...
# 4     From Memory to Written Record: England, 1066-1307
# ...                                                 ...
# 3993                                               None
# 3994                                               None
# 3997                        Alte Grenzen im Wiener Raum
# 3998  Avulsive channel systems: characteristics and ...
# 3999  Use of Relatively High Fe2O3 Steel Slag as Coa...
#
#                                             oa_abstract  \
# 0                                                  None
# 1     No AccessDie italienischen Begründer der Wiene...
# 2                                                  None
# 3     Some hydraulic characteristics of stream chann...
# 4     Introduction Part I The Making of Records 1 Me...
# ...                                                 ...
# 3993                                               None
# 3994                                               None
# 3997                                               None
# 3998                                               None
# 3999                                               None
#
#                                                concepts  \
# 0     Animal husbandry, Relation (database), Field (...
# 1     Download, Humanities, Geography, Art, World Wi...
# 2                                                   NaN
# 3     Cross section (physics), Section (typography),...
# 4     CONQUEST, Literacy, Mythology, History, Litera...
# ...                                                 ...
# 3993                                                NaN
# 3994                                                NaN
# 3997                             Political science, Art
# 3998  Channel (broadcasting), Computer science, Tele...
# 3999  Aggregate (composite), Materials science, Slag...
#
#                                                  oa_new
# 0                                                   NaN
# 1                                                   NaN
# 2     {'id': 'https://openalex.org/W1590955822', 'do...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3993  {'id': 'https://openalex.org/W2097996280', 'do...
# 3994  {'id': 'https://openalex.org/W4250409433', 'do...
# 3997                                                NaN
# 3998                                                NaN
# 3999                                                NaN
#
# [3808 rows x 12 columns]

# %%
def extract_abstract_inverted_index(dictionary):
    if isinstance(dictionary, dict) and 'abstract_inverted_index' in dictionary:
        return dictionary['abstract_inverted_index']
    else:
        return None

# %%
final['abstract_inverted_index'] = final.oa.apply(lambda x: extract_abstract_inverted_index(x))

# %%
final.abstract_inverted_index.isna().sum()
# Out:
# 778

# %%
def generate_full_text(abstract_inverted_index):
    if abstract_inverted_index is None:
        return None  # Return empty string if the input is None

    # Sort the dictionary based on the location indices to ensure proper order
    sorted_index = sorted(abstract_inverted_index.items(), key=lambda x: x[1][0])

    # Reconstruct the full text
    full_text = ""
    for word, locations in sorted_index:
        full_text += word + " "
    
    return full_text.strip()

# %%
final.oa_abstract.isna().sum()
# Out:
# 1297

# %%
final['oa_abstract'] = final.abstract_inverted_index.apply(lambda x: generate_full_text(x))

# %%
final.oa_abstract.isna().sum()
# Out:
# 778

# %%
final.cited_abstract.isna().sum()
# Out:
# 493

# %%
final['cited_abstract'].fillna(final['oa_abstract'], inplace=True)

# %%
final.cited_abstract.isna().sum()
# Out:
# 329

# %%
def extract_display_names(concepts_list):
    if isinstance(concepts_list, list):
        display_names = [concept['display_name'] for concept in concepts_list]
        return ', '.join(display_names)
    else:
        return None

# %%
final['concepts'] = final['oa'].apply(lambda x: x.get('concepts', []) if isinstance(x, dict) else [])

# %%
final['concepts'] = final['concepts'].apply(extract_display_names)

# %%
final.concepts.replace('', np.nan, inplace=True)

# %%
final = final.drop(columns = ['oa_new', 'abstract_inverted_index', 'oa_title', 'oa_abstract'])

# %%
final.rename(columns={'oa': 'cited_oa', 'concepts': 'cited_concepts'}, inplace=True)

# %%
final.cited_oa.replace(0, np.nan, inplace=True)

# %%
citing_paper.rename(columns={'oa': 'citing_oa'}, inplace=True)

# %%
df = pd.merge(left = df, right = final[['cited_abstract', 'cited_oa', 'cited_concepts']], left_index=True, right_index=True, how = 'left')

# %%
#sanity check

# %%
len(df.loc[(df.cited_abstract_x == df.cited_abstract_y) == False]) == df.cited_abstract_x.isna().sum()
# Out:
# True

# %%
df.rename(columns={'cited_abstract_y': 'cited_abstract'}, inplace=True)

# %%
df = df.drop(columns=['cited_abstract_x'])

# %%
df.cited_abstract.isna().sum()
# Out:
# 329

# %%
df = pd.merge(left = df, right = citing_paper[['core_id', 'citing_oa']], on = 'core_id', how = 'left')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4000 entries, 0 to 3999
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   unique_id                 4000 non-null   object
#  1   core_id                   4000 non-null   int64
#  2   citation_offset           3995 non-null   float64
#  3   total_doc_length          4000 non-null   int64
#  4   section_info              4000 non-null   object
#  5   citing_title              4000 non-null   object
#  6   citing_author             4000 non-null   object
#  7   citing_publication_info   3705 non-null   object
#  8   citing_abstract           3992 non-null   object
#  9   cited_title               4000 non-null   object
#  10  cited_author              4000 non-null   object
#  11  cited_doi                 3646 non-null   object
#  12  cited_publication_date    3888 non-null   object
#  13  cited_publication_info    3928 non-null   object
#  14  citation_context          4000 non-null   object
#  15  self_citation             3578 non-null   float64
#  16  direct_citations          3932 non-null   float64
#  17  co_mentions               3932 non-null   float64
#  18  citation_class_label      4000 non-null   int64
#  19  citation_influence_label  4000 non-null   int64
#  20  cited_abstract            3671 non-null   object
#  21  cited_oa                  3808 non-null   object
#  22  cited_concepts            3808 non-null   object
#  23  citing_oa                 4000 non-null   object
# dtypes: float64(4), int64(4), object(16)
# memory usage: 781.2+ KB

# %%
df.loc[df.citing_abstract.isna() == True].core_id.value_counts()
# Out:
# 20652885    8
# Name: core_id, dtype: int64

# %%
df['citing_concepts'] = df['citing_oa'].apply(lambda x: x.get('concepts', []) if isinstance(x, dict) else [])

# %%
df['citing_concepts'] = df['citing_concepts'].apply(extract_display_names)

# %%
original.isna().sum()
# Out:
# unique_id                     0
# core_id                       0
# citation_offset               5
# total_doc_length              0
# section_info                  0
# citing_title                  0
# citing_author                 0
# citing_publication_info     295
# citing_abstract               8
# cited_title                   0
# cited_author                  0
# cited_abstract              960
# cited_doi                   354
# cited_publication_date      112
# cited_publication_info       72
# citation_context              0
# self_citation               422
# direct_citations             68
# co_mentions                  68
# citation_class_label          0
# citation_influence_label      0
# dtype: int64

# %%
df.isna().sum()
# Out:
# unique_id                     0
# core_id                       0
# citation_offset               5
# total_doc_length              0
# section_info                  0
# citing_title                  0
# citing_author                 0
# citing_publication_info     295
# citing_abstract               8
# cited_title                   0
# cited_author                  0
# cited_doi                   354
# cited_publication_date      112
# cited_publication_info       72
# citation_context              0
# self_citation               422
# direct_citations             68
# co_mentions                  68
# citation_class_label          0
# citation_influence_label      0
# cited_abstract              329
# cited_oa                    192
# cited_concepts              192
# citing_oa                     0
# citing_concepts               0
# dtype: int64

# %%
original = pd.read_csv('/home/roland/Projects/JP_citation_classification/feature_scraping/data/ACT2_dataset.tsv', sep='\t')

# %%
df.to_csv('open_alex_enrichment.csv', index = False)
